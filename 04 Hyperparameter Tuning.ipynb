# %%
# =========================
# 0) Imports & constants
# =========================
import os, re, glob, time, json
import numpy as np
import pandas as pd

SEED = 42
TARGET_COLS = [
    "task_achievement",
    "coherence_and_cohesion",
    "lexical_resource",
    "grammatical_range",
]
N_COMPONENTS_PCA = 256
ANCHOR_DIR = "./Anchors"
OPTUNA_TRIALS = 500        # reduce/increase as needed
TEMP_SOFTMAX = 20.0        # anchor similarity temperature
TOPK_ANCHORS = 5
VAL_SIZE = 0.2              # single 80:20 split for speed\


train_emb = pd.read_csv("train_embeddings.csv")
test_emb  = pd.read_csv("test_embeddings.csv")
train_df  = pd.read_csv("train_feature_eng.csv")
test_df   = pd.read_csv("test_feature_eng.csv")

# %%
# ==========================
# These code snippets are commented out as they were part of the original code 
# but migrated to Feature Engineering Notebook for consistency
# ==========================

# import numpy as np
# import pandas as pd
# import re
# import nltk
# from nltk import word_tokenize, pos_tag
# from collections import Counter
# from sentence_transformers import SentenceTransformer, util
# from nltk.corpus import wordnet as wn

# nltk.download("wordnet")
# nltk.download("omw-1.4")

# # ---------- Helper: Lexical sophistication ----------
# import requests

# url = "https://raw.githubusercontent.com/first20hours/google-10000-english/master/20k.txt"
# response = requests.get(url)
# response.raise_for_status()  # Raise an error if the request fails
# COMMON_WORDS = set(response.text.split()[:2000])

# def lexical_sophistication(tokens):
#     rare_words = [t for t in tokens if t.lower() not in COMMON_WORDS]
#     return len(rare_words) / len(tokens) if tokens else 0

# # ---------- Helper: Root & Corrected TTR ----------
# def root_ttr(tokens):
#     return len(set(tokens)) / np.sqrt(len(tokens)) if tokens else 0

# def corrected_ttr(tokens):
#     return len(set(tokens)) / np.sqrt(2 * len(tokens)) if tokens else 0

# # ---------- Helper: MATTR ----------
# def mattr(tokens, window_size=50):
#     if len(tokens) < window_size:
#         return len(set(tokens)) / len(tokens)
#     scores = []
#     for i in range(len(tokens) - window_size + 1):
#         window = tokens[i:i+window_size]
#         scores.append(len(set(window)) / window_size)
#     return np.mean(scores)

# # ---------- Helper: Complex sentence ratio ----------
# def complex_sentence_ratio(text):
#     sentences = nltk.sent_tokenize(text)
#     complex_count = sum(1 for s in sentences if len(re.findall(r"\b(and|but|or|because|which|although)\b", s.lower())) >= 2)
#     return complex_count / len(sentences) if sentences else 0

# # ---------- Helper: Hypernym depth ----------
# def avg_hypernym_depth(tokens):
#     depths = []
#     for t in tokens:
#         synsets = wn.synsets(t)
#         if synsets:
#             depths.append(max((s.min_depth() for s in synsets), default=0))
#     return np.mean(depths) if depths else 0

# # ---------- Helper: Topic drift ----------
# def topic_drift(text, model):
#     paras = [p.strip() for p in text.split("\n") if p.strip()]
#     if len(paras) < 2:
#         return 0
#     emb_start = model.encode([paras[0]], convert_to_tensor=True)
#     emb_end = model.encode([paras[-1]], convert_to_tensor=True)
#     return 1 - util.cos_sim(emb_start, emb_end).item()

# # ---------- Helper: Alliteration ratio ----------
# def alliteration_ratio(tokens):
#     if len(tokens) < 2:
#         return 0
#     count = sum(1 for i in range(len(tokens)-1) if tokens[i][0].lower() == tokens[i+1][0].lower())
#     return count / (len(tokens)-1)

# # ---------- Helper: Hedging words ----------
# HEDGING_WORDS = {"might", "maybe", "perhaps", "possibly", "could", "should"}
# def hedging_count(tokens):
#     return sum(1 for t in tokens if t.lower() in HEDGING_WORDS)

# # ---------- Helper: Emotive words ----------
# EMOTIVE_WORDS = {"love", "hate", "happy", "sad", "angry", "excited", "worried", "proud"}
# def emotive_count(tokens):
#     return sum(1 for t in tokens if t.lower() in EMOTIVE_WORDS)

# # ---------- Main function ----------
# def add_extra_features(df, text_col="essay_clean", prompt_col="prompt_clean"):
#     sbert = SentenceTransformer("sentence-transformers/paraphrase-MiniLM-L6-v2")
#     new_feats = {
#         "root_ttr": [],
#         "corrected_ttr": [],
#         "mattr": [],
#         "lexical_sophistication": [],
#         "complex_sentence_ratio": [],
#         "avg_hypernym_depth": [],
#         "topic_drift": [],
#         "alliteration_ratio": [],
#         "hedging_count": [],
#         "emotive_count": []
#     }

#     for text, prompt in zip(df[text_col], df[prompt_col]):
#         tokens = [t for t in word_tokenize(text) if t.isalpha()]
#         new_feats["root_ttr"].append(root_ttr(tokens))
#         new_feats["corrected_ttr"].append(corrected_ttr(tokens))
#         new_feats["mattr"].append(mattr(tokens))
#         new_feats["lexical_sophistication"].append(lexical_sophistication(tokens))
#         new_feats["complex_sentence_ratio"].append(complex_sentence_ratio(text))
#         new_feats["avg_hypernym_depth"].append(avg_hypernym_depth(tokens))
#         new_feats["topic_drift"].append(topic_drift(text, sbert))
#         new_feats["alliteration_ratio"].append(alliteration_ratio(tokens))
#         new_feats["hedging_count"].append(hedging_count(tokens))
#         new_feats["emotive_count"].append(emotive_count(tokens))

#     return pd.concat([df, pd.DataFrame(new_feats)], axis=1)


# train_df = add_extra_features(train_df)
# test_df = add_extra_features(test_df)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/semiqolonn/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /home/semiqolonn/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/314 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
# =========================
# 1) Load data & PCA(emb)
# =========================
from sklearn.decomposition import PCA

pca = PCA(n_components=N_COMPONENTS_PCA, random_state=SEED)
train_emb_pca = pca.fit_transform(train_emb)
test_emb_pca  = pca.transform(test_emb)
print(f"[PCA] explained_variance_sum = {pca.explained_variance_ratio_.sum():.4f}")

y = train_df[TARGET_COLS].copy()
drop_train = ["prompt","essay","essay_clean","prompt_clean","merged_text"] + TARGET_COLS
drop_test  = ["prompt","essay","essay_clean","prompt_clean","merged_text"]

X_train_core = train_df.drop(columns=drop_train, errors="ignore").reset_index(drop=True)
X_test_core  = test_df.drop(columns=drop_test, errors="ignore").reset_index(drop=True)

train_emb_df = pd.DataFrame(train_emb_pca, columns=[f"emb_{i}" for i in range(N_COMPONENTS_PCA)])
test_emb_df  = pd.DataFrame(test_emb_pca,  columns=[f"emb_{i}" for i in range(N_COMPONENTS_PCA)])

train = pd.concat([X_train_core, train_emb_df], axis=1)
test  = pd.concat([X_test_core,  test_emb_df],  axis=1)

X_mat  = train.values.astype(np.float32)
Y_mat  = y.values.astype(np.float32)  # may contain NaN
X_test = test.values.astype(np.float32)

print("Shapes -> X:", X_mat.shape, " Y:", Y_mat.shape, " X_test:", X_test.shape)
# Out:
# [PCA] explained_variance_sum = 0.9116
# Shapes -> X: (9912, 321)  Y: (9912, 4)  X_test: (473, 321)

# %%
# =========================
# 2) Load anchors
# =========================
def _read_pred_vec(path: str, n_expected_rows: int) -> np.ndarray:
    df = pd.read_csv(path)
    drop_unnamed = [c for c in df.columns if str(c).startswith("Unnamed")]
    if drop_unnamed:
        df = df.drop(columns=drop_unnamed)
    cols = [c for c in TARGET_COLS if c in df.columns]
    if len(cols) == 4:
        df = df[cols]
    else:
        df = df.iloc[:, -4:]
        df.columns = TARGET_COLS
    if len(df) != n_expected_rows:
        raise ValueError(f"{os.path.basename(path)} rows={len(df)} != expected {n_expected_rows}")
    return df.values.astype(np.float32).ravel()

def load_anchor_submissions(anchor_dir=ANCHOR_DIR, n_expected_rows=None):
    anchors = []
    for p in sorted(glob.glob(os.path.join(anchor_dir, "*.csv"))):
        m = re.match(r"(\d+)\.csv$", os.path.basename(p))
        if not m:
            continue
        lb = float(m.group(1)) / 100.0
        vec = _read_pred_vec(p, n_expected_rows)
        anchors.append({"name": os.path.basename(p), "lb": lb, "vec": vec})
    if len(anchors) < 3:
        raise ValueError("Need >=3 anchors")
    return anchors

ANCHORS = load_anchor_submissions(n_expected_rows=test.shape[0])
print("Anchors:", [(a["name"], a["lb"], len(a["vec"])) for a in ANCHORS])
# Out:
# Anchors: [('11.csv', 0.11, 1892), ('15.csv', 0.15, 1892), ('17.csv', 0.17, 1892), ('51.csv', 0.51, 1892), ('78.csv', 0.78, 1892), ('86.csv', 0.86, 1892)]

# %%
# =========================
# 3) Utils
# =========================
from sklearn.metrics import mean_squared_error
from numpy.linalg import norm
from sklearn.model_selection import train_test_split

def mean_rmse_across_targets(y_true, y_pred):
    rmses = []
    for i in range(y_true.shape[1]):
        m = ~np.isnan(y_true[:, i])
        if m.any():
            rmses.append(np.sqrt(mean_squared_error(y_true[m, i], y_pred[m, i])))
    return float(np.mean(rmses)) if rmses else float("inf")

def predict_lb_from_anchors(test_vec: np.ndarray, anchors, temp: float, k: int):
    tvn = norm(test_vec) + 1e-12
    sims = []
    for a in anchors:
        avn = norm(a["vec"]) + 1e-12
        sims.append(float(np.dot(test_vec, a["vec"]) / (tvn * avn)))
    sims = np.array(sims, dtype=np.float32)
    idx = np.argsort(-sims)[:min(k, len(sims))]
    sims_k = sims[idx]
    lbs_k  = np.array([anchors[i]["lb"] for i in idx], dtype=np.float32)
    w = np.exp(sims_k * temp); w /= w.sum()
    pred_lb = float((w * lbs_k).sum())
    top_info = list(zip([anchors[i]["name"] for i in idx], sims_k, lbs_k))
    return pred_lb, top_info

# %%
# =========================
# 4) GPU-safe base params for tuning
# =========================
from catboost import CatBoostRegressor, Pool

BASE_PARAMS_GPU = dict(
    loss_function="MultiRMSE",
    eval_metric="MultiRMSE",
    task_type="GPU",
    devices="0",
    iterations=2000,
    learning_rate=0.05,
    depth=8,
    l2_leaf_reg=3.0,
    bootstrap_type="Bayesian",
    bagging_temperature=1.0,
    border_count=128,
    min_data_in_leaf=5,
    random_seed=SEED,
    use_best_model=True,
    verbose=False,
)

def train_val_and_test_once(params, X_tr, Y_tr, X_va, Y_va, X_test, es_rounds=200, gpu=True):
    base = BASE_PARAMS_GPU.copy() if gpu else {**BASE_PARAMS_GPU, "task_type": "CPU"}
    m = CatBoostRegressor(**{**base, **params})
    tr_pool = Pool(X_tr, label=Y_tr)
    va_pool = Pool(X_va, label=Y_va)
    m.fit(tr_pool, eval_set=va_pool, early_stopping_rounds=es_rounds, use_best_model=True)
    va_pred = m.predict(X_va)
    val_rmse = mean_rmse_across_targets(Y_va, va_pred)
    test_pred = m.predict(X_test).astype(np.float32).ravel()
    return val_rmse, test_pred

# %%
# =========================
# 5) Optuna tuning (GPU-safe) using anchors
# =========================
import optuna

mask_cc = ~np.isnan(Y_mat).any(axis=1)
X_cc = X_mat[mask_cc]
Y_cc = Y_mat[mask_cc]
X_tr, X_va, Y_tr, Y_va = train_test_split(X_cc, Y_cc, test_size=VAL_SIZE, random_state=SEED, shuffle=True)

def tune_with_anchor_lb(X_tr, Y_tr, X_va, Y_va, X_test, n_trials=OPTUNA_TRIALS, temp=TEMP_SOFTMAX, k=TOPK_ANCHORS):
    study = optuna.create_study(direction="minimize")

    def objective(trial: optuna.Trial):
        params = {
            "iterations": trial.suggest_int("iterations", 800, 3000),
            "depth": trial.suggest_int("depth", 4, 10),
            "learning_rate": trial.suggest_float("learning_rate", 1e-3, 0.2, log=True),
            "l2_leaf_reg": trial.suggest_float("l2_leaf_reg", 1e-2, 30.0, log=True),
            "bagging_temperature": trial.suggest_float("bagging_temperature", 0.1, 2.0),
            "boosting_type": "Plain",          # ✅ GPU-safe
            "bootstrap_type": "Poisson",       # ✅ safer for GPU
            "loss_function": "MultiRMSE",      # ✅ supported

        }
        try:
            val_rmse, test_vec = train_val_and_test_once(params, X_tr, Y_tr, X_va, Y_va, X_test, gpu=True)
        except Exception as e:
            print("[GPU failed, falling back to CPU]:", e)
            val_rmse, test_vec = train_val_and_test_once(params, X_tr, Y_tr, X_va, Y_va, X_test, gpu=False)

        assert len(test_vec) == len(ANCHORS[0]["vec"]), f"Vector mismatch {len(test_vec)} vs {len(ANCHORS[0]['vec'])}"
        pred_lb, top = predict_lb_from_anchors(test_vec, ANCHORS, temp=temp, k=k)

        trial.set_user_attr("val_rmse", float(val_rmse))
        trial.set_user_attr("anchor_similar", top)
        return float(pred_lb)

    study.optimize(objective, n_trials=n_trials, show_progress_bar=True)
    return study

study = tune_with_anchor_lb(X_tr, Y_tr, X_va, Y_va, X_test)
print("Best predicted LB:", study.best_value)
print("Best params:", study.best_trial.params)
# Out:
# [I 2025-08-12 14:49:18,920] A new study created in memory with name: no-name-4f2dbea0-b858-42a2-8782-176c38ea2df2
#   0%|          | 0/500 [00:00<?, ?it/s]
# [I 2025-08-12 14:49:50,934] Trial 0 finished with value: 0.5092242360115051 and parameters: {'iterations': 1145, 'depth': 9, 'learning_rate': 0.0010902463703813343, 'l2_leaf_reg': 4.595503123609981, 'bagging_temperature': 0.3397220528396424}. Best is trial 0 with value: 0.5092242360115051.
# [I 2025-08-12 14:49:58,880] Trial 1 finished with value: 0.5034897923469543 and parameters: {'iterations': 2290, 'depth': 5, 'learning_rate': 0.0035537535861948546, 'l2_leaf_reg': 0.021257020489828447, 'bagging_temperature': 0.9718735962318823}. Best is trial 1 with value: 0.5034897923469543.
# [I 2025-08-12 14:50:03,325] Trial 2 finished with value: 0.4999849200248718 and parameters: {'iterations': 1262, 'depth': 5, 'learning_rate': 0.018014828526503834, 'l2_leaf_reg': 0.5331002966678468, 'bagging_temperature': 1.8435907718884936}. Best is trial 2 with value: 0.4999849200248718.
# [I 2025-08-12 14:50:10,058] Trial 3 finished with value: 0.5012486577033997 and parameters: {'iterations': 2934, 'depth': 9, 'learning_rate': 0.10129619799836587, 'l2_leaf_reg': 0.018072407969510363, 'bagging_temperature': 1.908911424453323}. Best is trial 2 with value: 0.4999849200248718.
# [I 2025-08-12 14:50:15,470] Trial 4 finished with value: 0.4975125193595886 and parameters: {'iterations': 1833, 'depth': 5, 'learning_rate': 0.02596320034893078, 'l2_leaf_reg': 0.03541729354720542, 'bagging_temperature': 1.4976963954847247}. Best is trial 4 with value: 0.4975125193595886.
# [I 2025-08-12 14:50:23,314] Trial 5 finished with value: 0.49613210558891296 and parameters: {'iterations': 1965, 'depth': 6, 'learning_rate': 0.02601072155830082, 'l2_leaf_reg': 0.017537985348904033, 'bagging_temperature': 0.18526360891890467}. Best is trial 5 with value: 0.49613210558891296.
# [I 2025-08-12 14:50:30,924] Trial 6 finished with value: 0.4972248375415802 and parameters: {'iterations': 2330, 'depth': 8, 'learning_rate': 0.04354559065907383, 'l2_leaf_reg': 0.08728915922229309, 'bagging_temperature': 1.9549866653420809}. Best is trial 5 with value: 0.49613210558891296.
# [I 2025-08-12 14:50:35,005] Trial 7 finished with value: 0.5046239495277405 and parameters: {'iterations': 1161, 'depth': 5, 'learning_rate': 0.004452115041858525, 'l2_leaf_reg': 0.013909760147377303, 'bagging_temperature': 1.0302883380841246}. Best is trial 5 with value: 0.49613210558891296.
# [I 2025-08-12 14:50:41,966] Trial 8 finished with value: 0.5044729113578796 and parameters: {'iterations': 2975, 'depth': 4, 'learning_rate': 0.002503598213632926, 'l2_leaf_reg': 0.8275489362297015, 'bagging_temperature': 0.7988258328897817}. Best is trial 5 with value: 0.49613210558891296.
# [I 2025-08-12 14:50:43,979] Trial 9 finished with value: 0.5001690983772278 and parameters: {'iterations': 1915, 'depth': 4, 'learning_rate': 0.07599239113275497, 'l2_leaf_reg': 6.322931837392734, 'bagging_temperature': 1.095915368091734}. Best is trial 5 with value: 0.49613210558891296.
# [I 2025-08-12 14:50:58,979] Trial 10 finished with value: 0.4984791874885559 and parameters: {'iterations': 1669, 'depth': 7, 'learning_rate': 0.008751775794782726, 'l2_leaf_reg': 0.20714185352192913, 'bagging_temperature': 0.11612021131055869}. Best is trial 5 with value: 0.49613210558891296.
# [I 2025-08-12 14:51:04,303] Trial 11 finished with value: 0.49793264269828796 and parameters: {'iterations': 2334, 'depth': 7, 'learning_rate': 0.04300764565130565, 'l2_leaf_reg': 0.06236541690503879, 'bagging_temperature': 0.5186794865351849}. Best is trial 5 with value: 0.49613210558891296.
# [I 2025-08-12 14:51:07,842] Trial 12 finished with value: 0.5020635724067688 and parameters: {'iterations': 2387, 'depth': 8, 'learning_rate': 0.19685690733926245, 'l2_leaf_reg': 0.11686205554121651, 'bagging_temperature': 1.4557386899904676}. Best is trial 5 with value: 0.49613210558891296.
# [I 2025-08-12 14:51:26,714] Trial 13 finished with value: 0.49716466665267944 and parameters: {'iterations': 2616, 'depth': 10, 'learning_rate': 0.03775201924938474, 'l2_leaf_reg': 0.3067633236654513, 'bagging_temperature': 1.5388298424937996}. Best is trial 5 with value: 0.49613210558891296.
# [I 2025-08-12 14:52:37,850] Trial 14 finished with value: 0.4968120753765106 and parameters: {'iterations': 2743, 'depth': 10, 'learning_rate': 0.008410487645013204, 'l2_leaf_reg': 1.4711604122529478, 'bagging_temperature': 1.5554835651337415}. Best is trial 5 with value: 0.49613210558891296.
# [I 2025-08-12 14:52:46,633] Trial 15 finished with value: 0.5007439255714417 and parameters: {'iterations': 1616, 'depth': 6, 'learning_rate': 0.01066173324884158, 'l2_leaf_reg': 2.562536095488184, 'bagging_temperature': 1.2945224432611677}. Best is trial 5 with value: 0.49613210558891296.
# [I 2025-08-12 14:54:55,409] Trial 16 finished with value: 0.50026535987854 and parameters: {'iterations': 2672, 'depth': 10, 'learning_rate': 0.0086760544436932, 'l2_leaf_reg': 29.840497314624955, 'bagging_temperature': 0.7033997353037148}. Best is trial 5 with value: 0.49613210558891296.
# [I 2025-08-12 14:55:03,412] Trial 17 finished with value: 0.49944332242012024 and parameters: {'iterations': 876, 'depth': 7, 'learning_rate': 0.01790861881116649, 'l2_leaf_reg': 1.9552259265696856, 'bagging_temperature': 1.7031560629278033}. Best is trial 5 with value: 0.49613210558891296.
# [I 2025-08-12 14:55:14,198] Trial 18 finished with value: 0.5040812492370605 and parameters: {'iterations': 2006, 'depth': 6, 'learning_rate': 0.0052789057468784996, 'l2_leaf_reg': 15.077811660181561, 'bagging_temperature': 0.1488928165224293}. Best is trial 5 with value: 0.49613210558891296.
# [I 2025-08-12 14:56:28,078] Trial 19 finished with value: 0.5027742385864258 and parameters: {'iterations': 2638, 'depth': 9, 'learning_rate': 0.001472070733347259, 'l2_leaf_reg': 0.7940383698183757, 'bagging_temperature': 1.2522951293323248}. Best is trial 5 with value: 0.49613210558891296.
# [I 2025-08-12 14:56:38,060] Trial 20 finished with value: 0.4990884065628052 and parameters: {'iterations': 2086, 'depth': 6, 'learning_rate': 0.01338020118891073, 'l2_leaf_reg': 1.7460145460081735, 'bagging_temperature': 0.6474270314180055}. Best is trial 5 with value: 0.49613210558891296.
# [I 2025-08-12 14:57:00,630] Trial 21 finished with value: 0.4956699311733246 and parameters: {'iterations': 2663, 'depth': 10, 'learning_rate': 0.035316766437164124, 'l2_leaf_reg': 0.2816805326126861, 'bagging_temperature': 1.6630568091080484}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 14:57:23,999] Trial 22 finished with value: 0.4973735213279724 and parameters: {'iterations': 2785, 'depth': 10, 'learning_rate': 0.026309940514985346, 'l2_leaf_reg': 0.24784124006915745, 'bagging_temperature': 1.7113622800562802}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 14:57:29,036] Trial 23 finished with value: 0.4998951554298401 and parameters: {'iterations': 2484, 'depth': 8, 'learning_rate': 0.07482048832587235, 'l2_leaf_reg': 0.010632001010323635, 'bagging_temperature': 1.321677789497971}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 14:57:46,204] Trial 24 finished with value: 0.4978736340999603 and parameters: {'iterations': 2138, 'depth': 9, 'learning_rate': 0.02568002043123728, 'l2_leaf_reg': 1.117235455750481, 'bagging_temperature': 1.6743198724116808}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 14:58:42,956] Trial 25 finished with value: 0.49768969416618347 and parameters: {'iterations': 2793, 'depth': 10, 'learning_rate': 0.00763402738205202, 'l2_leaf_reg': 0.45177619146699194, 'bagging_temperature': 0.3689711861112076}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 14:58:48,931] Trial 26 finished with value: 0.49863767623901367 and parameters: {'iterations': 1557, 'depth': 8, 'learning_rate': 0.05650010587006187, 'l2_leaf_reg': 0.03545541122117949, 'bagging_temperature': 1.155823440469803}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 14:58:56,111] Trial 27 finished with value: 0.4980722665786743 and parameters: {'iterations': 2510, 'depth': 9, 'learning_rate': 0.13292467505154526, 'l2_leaf_reg': 0.14175250470041145, 'bagging_temperature': 0.8853766862229232}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 14:59:43,496] Trial 28 finished with value: 0.4977433383464813 and parameters: {'iterations': 2169, 'depth': 10, 'learning_rate': 0.017019737862392307, 'l2_leaf_reg': 4.174996983976397, 'bagging_temperature': 1.445279491622897}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 14:59:55,055] Trial 29 finished with value: 0.49889007210731506 and parameters: {'iterations': 2842, 'depth': 9, 'learning_rate': 0.030690952339014078, 'l2_leaf_reg': 0.04907817363647193, 'bagging_temperature': 1.6186946465233836}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 15:00:04,637] Trial 30 finished with value: 0.5029013156890869 and parameters: {'iterations': 1772, 'depth': 6, 'learning_rate': 0.006344327170804234, 'l2_leaf_reg': 5.150861341588935, 'bagging_temperature': 0.3284137020121046}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 15:00:22,923] Trial 31 finished with value: 0.49691107869148254 and parameters: {'iterations': 2633, 'depth': 10, 'learning_rate': 0.04385260228081955, 'l2_leaf_reg': 0.3565529403956577, 'bagging_temperature': 1.5533420451653261}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 15:00:39,478] Trial 32 finished with value: 0.49774372577667236 and parameters: {'iterations': 1374, 'depth': 10, 'learning_rate': 0.05396434316410546, 'l2_leaf_reg': 0.4110511503154979, 'bagging_temperature': 1.8574081447558823}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 15:01:09,273] Trial 33 finished with value: 0.4973069429397583 and parameters: {'iterations': 2488, 'depth': 9, 'learning_rate': 0.012586296763896674, 'l2_leaf_reg': 0.9213630606974696, 'bagging_temperature': 1.8097209839080999}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 15:01:38,001] Trial 34 finished with value: 0.496799498796463 and parameters: {'iterations': 2737, 'depth': 10, 'learning_rate': 0.020280321455042993, 'l2_leaf_reg': 0.16069493511850869, 'bagging_temperature': 1.4036571017693762}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 15:02:05,648] Trial 35 finished with value: 0.4976418614387512 and parameters: {'iterations': 2823, 'depth': 10, 'learning_rate': 0.017822684836284505, 'l2_leaf_reg': 0.023620161630178535, 'bagging_temperature': 1.3002013740179428}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 15:03:28,044] Trial 36 finished with value: 0.4977937340736389 and parameters: {'iterations': 2953, 'depth': 9, 'learning_rate': 0.0029347377262926386, 'l2_leaf_reg': 0.15570892125120714, 'bagging_temperature': 1.40316982805879}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 15:03:39,440] Trial 37 finished with value: 0.49749478697776794 and parameters: {'iterations': 2219, 'depth': 8, 'learning_rate': 0.022319837994517772, 'l2_leaf_reg': 0.08434218542966557, 'bagging_temperature': 0.9464466407268052}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 15:04:02,813] Trial 38 finished with value: 0.49826422333717346 and parameters: {'iterations': 841, 'depth': 9, 'learning_rate': 0.011369075685286752, 'l2_leaf_reg': 0.6289087860401319, 'bagging_temperature': 1.1790373361821926}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 15:04:08,750] Trial 39 finished with value: 0.4977523386478424 and parameters: {'iterations': 2735, 'depth': 6, 'learning_rate': 0.032758522421575745, 'l2_leaf_reg': 1.3491189810760185, 'bagging_temperature': 1.794712918733379}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 15:04:19,124] Trial 40 finished with value: 0.5020458102226257 and parameters: {'iterations': 2990, 'depth': 5, 'learning_rate': 0.00433538531043664, 'l2_leaf_reg': 0.02514509861885018, 'bagging_temperature': 1.930535647481756}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 15:04:35,958] Trial 41 finished with value: 0.4973600506782532 and parameters: {'iterations': 2591, 'depth': 10, 'learning_rate': 0.05237978363917373, 'l2_leaf_reg': 0.35198959153948073, 'bagging_temperature': 1.5892167538267972}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 15:05:00,859] Trial 42 finished with value: 0.4977690875530243 and parameters: {'iterations': 2390, 'depth': 10, 'learning_rate': 0.021693626203770928, 'l2_leaf_reg': 0.19918417104938135, 'bagging_temperature': 1.9927024822741646}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 15:05:15,538] Trial 43 finished with value: 0.4974702000617981 and parameters: {'iterations': 2873, 'depth': 10, 'learning_rate': 0.07338986962652046, 'l2_leaf_reg': 0.600785724794877, 'bagging_temperature': 1.526865924844817}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 15:05:29,881] Trial 44 finished with value: 0.498688668012619 and parameters: {'iterations': 2713, 'depth': 10, 'learning_rate': 0.10456624178127058, 'l2_leaf_reg': 2.9125176256192766, 'bagging_temperature': 1.3943926511626552}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 15:05:43,179] Trial 45 finished with value: 0.4977852702140808 and parameters: {'iterations': 2556, 'depth': 9, 'learning_rate': 0.0306424954966178, 'l2_leaf_reg': 0.10021618510878612, 'bagging_temperature': 1.7623866386436355}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 15:05:47,057] Trial 46 finished with value: 0.49750417470932007 and parameters: {'iterations': 2346, 'depth': 5, 'learning_rate': 0.04092365411477253, 'l2_leaf_reg': 0.06075088760547246, 'bagging_temperature': 1.6292015801457935}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 15:06:12,850] Trial 47 finished with value: 0.49734264612197876 and parameters: {'iterations': 1447, 'depth': 10, 'learning_rate': 0.021792218560994128, 'l2_leaf_reg': 0.20952715668899222, 'bagging_temperature': 1.541563789800866}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 15:06:27,201] Trial 48 finished with value: 0.49665960669517517 and parameters: {'iterations': 2255, 'depth': 7, 'learning_rate': 0.015126731970043604, 'l2_leaf_reg': 0.3234121663960672, 'bagging_temperature': 1.2021463515098239}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 15:06:37,178] Trial 49 finished with value: 0.4985889792442322 and parameters: {'iterations': 1956, 'depth': 7, 'learning_rate': 0.015641890731919447, 'l2_leaf_reg': 0.043505869732507654, 'bagging_temperature': 1.0205022899259342}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 15:06:53,775] Trial 50 finished with value: 0.4981246590614319 and parameters: {'iterations': 1845, 'depth': 7, 'learning_rate': 0.00870080866118161, 'l2_leaf_reg': 0.016230530979126304, 'bagging_temperature': 1.1034912919029232}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 15:07:06,088] Trial 51 finished with value: 0.49839648604393005 and parameters: {'iterations': 2258, 'depth': 6, 'learning_rate': 0.010226918575446579, 'l2_leaf_reg': 0.3266073037296089, 'bagging_temperature': 1.3722583709519902}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 15:07:20,381] Trial 52 finished with value: 0.4970075786113739 and parameters: {'iterations': 2447, 'depth': 7, 'learning_rate': 0.014202669760432829, 'l2_leaf_reg': 0.5082321844785368, 'bagging_temperature': 1.2102649590689412}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 15:07:35,081] Trial 53 finished with value: 0.4971843361854553 and parameters: {'iterations': 2660, 'depth': 8, 'learning_rate': 0.03687904476003787, 'l2_leaf_reg': 9.253825567575701, 'bagging_temperature': 1.446762514358873}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 15:07:38,307] Trial 54 finished with value: 0.4979539215564728 and parameters: {'iterations': 2015, 'depth': 4, 'learning_rate': 0.04744625440982287, 'l2_leaf_reg': 0.2571377349728489, 'bagging_temperature': 1.5338609290917495}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 15:07:54,726] Trial 55 finished with value: 0.49779433012008667 and parameters: {'iterations': 2722, 'depth': 9, 'learning_rate': 0.025793554689543776, 'l2_leaf_reg': 0.709631017063607, 'bagging_temperature': 1.326673503705366}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 15:08:26,239] Trial 56 finished with value: 0.4974936842918396 and parameters: {'iterations': 2576, 'depth': 10, 'learning_rate': 0.020601788997811676, 'l2_leaf_reg': 1.4157079296087605, 'bagging_temperature': 1.7107702673682195}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 15:08:30,719] Trial 57 finished with value: 0.4970453977584839 and parameters: {'iterations': 2419, 'depth': 7, 'learning_rate': 0.06322647914811554, 'l2_leaf_reg': 0.15053075123803192, 'bagging_temperature': 1.4890717479079456}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 15:08:42,315] Trial 58 finished with value: 0.49672576785087585 and parameters: {'iterations': 2909, 'depth': 8, 'learning_rate': 0.036623771472747764, 'l2_leaf_reg': 2.6664926176502646, 'bagging_temperature': 0.747017279474451}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 15:09:21,836] Trial 59 finished with value: 0.49827277660369873 and parameters: {'iterations': 2870, 'depth': 8, 'learning_rate': 0.006761415578872056, 'l2_leaf_reg': 2.705732778858909, 'bagging_temperature': 0.6161368629582883}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 15:09:26,854] Trial 60 finished with value: 0.4988851249217987 and parameters: {'iterations': 2917, 'depth': 6, 'learning_rate': 0.0351589956144233, 'l2_leaf_reg': 2.0314724612099915, 'bagging_temperature': 0.38104802874677807}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 15:09:34,173] Trial 61 finished with value: 0.49835461378097534 and parameters: {'iterations': 2745, 'depth': 7, 'learning_rate': 0.029028080246207302, 'l2_leaf_reg': 1.1379591867315348, 'bagging_temperature': 0.24306071110854988}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 15:09:53,113] Trial 62 finished with value: 0.49613383412361145 and parameters: {'iterations': 2680, 'depth': 10, 'learning_rate': 0.0465623549674636, 'l2_leaf_reg': 0.464775734737334, 'bagging_temperature': 0.8183151340851741}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 15:10:06,057] Trial 63 finished with value: 0.4993457794189453 and parameters: {'iterations': 1772, 'depth': 10, 'learning_rate': 0.08826691904359768, 'l2_leaf_reg': 0.8334437403543168, 'bagging_temperature': 0.7480461193016532}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 15:11:23,333] Trial 64 finished with value: 0.5059000253677368 and parameters: {'iterations': 2798, 'depth': 9, 'learning_rate': 0.0010242406150036297, 'l2_leaf_reg': 3.2887659315245816, 'bagging_temperature': 0.8523438712975455}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 15:11:26,841] Trial 65 finished with value: 0.503146231174469 and parameters: {'iterations': 977, 'depth': 5, 'learning_rate': 0.014487010730148438, 'l2_leaf_reg': 6.989186446729035, 'bagging_temperature': 0.5991225507755045}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 15:11:50,301] Trial 66 finished with value: 0.49735724925994873 and parameters: {'iterations': 2529, 'depth': 8, 'learning_rate': 0.01055264034698797, 'l2_leaf_reg': 0.5018979145402334, 'bagging_temperature': 0.4808779939118114}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 15:12:04,603] Trial 67 finished with value: 0.49795815348625183 and parameters: {'iterations': 2910, 'depth': 10, 'learning_rate': 0.06492437215010463, 'l2_leaf_reg': 0.011482029883862281, 'bagging_temperature': 0.9450661111972416}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 15:12:11,866] Trial 68 finished with value: 0.4984702169895172 and parameters: {'iterations': 2679, 'depth': 6, 'learning_rate': 0.018561380658804826, 'l2_leaf_reg': 0.07202913891112331, 'bagging_temperature': 0.526013996275045}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 15:12:28,613] Trial 69 finished with value: 0.4969989061355591 and parameters: {'iterations': 2130, 'depth': 9, 'learning_rate': 0.025017646525214942, 'l2_leaf_reg': 0.2636855475523294, 'bagging_temperature': 1.0799678327972952}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 15:12:51,492] Trial 70 finished with value: 0.49713099002838135 and parameters: {'iterations': 2976, 'depth': 10, 'learning_rate': 0.04032033097263214, 'l2_leaf_reg': 1.9776149676688444, 'bagging_temperature': 0.7763369112082281}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 15:13:09,629] Trial 71 finished with value: 0.4969710111618042 and parameters: {'iterations': 2621, 'depth': 10, 'learning_rate': 0.047203367699186004, 'l2_leaf_reg': 0.41914380051380484, 'bagging_temperature': 1.224503167397446}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 15:15:32,490] Trial 72 finished with value: 0.5005547404289246 and parameters: {'iterations': 2788, 'depth': 10, 'learning_rate': 0.0014375174622125511, 'l2_leaf_reg': 0.20050620101465874, 'bagging_temperature': 1.5898016947971372}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 15:15:46,446] Trial 73 finished with value: 0.496697336435318 and parameters: {'iterations': 2315, 'depth': 9, 'learning_rate': 0.03443894511999488, 'l2_leaf_reg': 0.35201803922791014, 'bagging_temperature': 0.6828043475815068}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 15:16:07,118] Trial 74 finished with value: 0.4976113736629486 and parameters: {'iterations': 2322, 'depth': 9, 'learning_rate': 0.027124602917857572, 'l2_leaf_reg': 3.7786382601716446, 'bagging_temperature': 0.687497964269646}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 15:16:15,931] Trial 75 finished with value: 0.49763068556785583 and parameters: {'iterations': 2053, 'depth': 8, 'learning_rate': 0.03463824948796887, 'l2_leaf_reg': 0.1383752971985509, 'bagging_temperature': 0.8272954964042405}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 15:16:48,788] Trial 76 finished with value: 0.49758878350257874 and parameters: {'iterations': 2191, 'depth': 9, 'learning_rate': 0.012204271646873207, 'l2_leaf_reg': 1.5006153134762459, 'bagging_temperature': 0.22755093118263856}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 15:17:08,829] Trial 77 finished with value: 0.4979627728462219 and parameters: {'iterations': 2467, 'depth': 9, 'learning_rate': 0.019391184108097387, 'l2_leaf_reg': 0.9148118049118389, 'bagging_temperature': 0.905811969738487}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 15:17:40,486] Trial 78 finished with value: 0.49760177731513977 and parameters: {'iterations': 2257, 'depth': 10, 'learning_rate': 0.01633017272444038, 'l2_leaf_reg': 0.2919834342990068, 'bagging_temperature': 0.7148176386705082}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 15:18:10,403] Trial 79 finished with value: 0.4991054832935333 and parameters: {'iterations': 1917, 'depth': 8, 'learning_rate': 0.005484704834985988, 'l2_leaf_reg': 0.6184762768455194, 'bagging_temperature': 1.0079443312649636}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 15:18:37,545] Trial 80 finished with value: 0.4963686466217041 and parameters: {'iterations': 2881, 'depth': 10, 'learning_rate': 0.02345609409035573, 'l2_leaf_reg': 0.1082770766691131, 'bagging_temperature': 0.5305793879659342}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 15:19:02,084] Trial 81 finished with value: 0.4970132112503052 and parameters: {'iterations': 2876, 'depth': 10, 'learning_rate': 0.023926665434809237, 'l2_leaf_reg': 0.0320654908517724, 'bagging_temperature': 0.5458378428235395}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 15:19:21,687] Trial 82 finished with value: 0.4985191226005554 and parameters: {'iterations': 2761, 'depth': 10, 'learning_rate': 0.031124932273483088, 'l2_leaf_reg': 0.11935908227287703, 'bagging_temperature': 0.48883289454143114}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 15:19:36,792] Trial 83 finished with value: 0.4984065592288971 and parameters: {'iterations': 2833, 'depth': 10, 'learning_rate': 0.05723723177738518, 'l2_leaf_reg': 0.22478927888171538, 'bagging_temperature': 0.6566973209743704}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 15:19:57,109] Trial 84 finished with value: 0.49677032232284546 and parameters: {'iterations': 2710, 'depth': 10, 'learning_rate': 0.03825131930988103, 'l2_leaf_reg': 0.3762058913033815, 'bagging_temperature': 0.42823305401164535}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 15:20:08,413] Trial 85 finished with value: 0.49696820974349976 and parameters: {'iterations': 2704, 'depth': 9, 'learning_rate': 0.0485733568410467, 'l2_leaf_reg': 0.39628488277932467, 'bagging_temperature': 0.10168106968244633}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 15:20:26,860] Trial 86 finished with value: 0.4978949725627899 and parameters: {'iterations': 2932, 'depth': 10, 'learning_rate': 0.03743481243077939, 'l2_leaf_reg': 0.16730550285313028, 'bagging_temperature': 0.42661901291768267}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 15:20:46,079] Trial 87 finished with value: 0.49598491191864014 and parameters: {'iterations': 1657, 'depth': 10, 'learning_rate': 0.04303024511200298, 'l2_leaf_reg': 0.10562265572473188, 'bagging_temperature': 0.33326916382422467}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 15:21:04,602] Trial 88 finished with value: 0.4966700077056885 and parameters: {'iterations': 1592, 'depth': 10, 'learning_rate': 0.040667802081869195, 'l2_leaf_reg': 0.10410785862537052, 'bagging_temperature': 0.2668956144610643}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 15:21:15,324] Trial 89 finished with value: 0.49823668599128723 and parameters: {'iterations': 1625, 'depth': 9, 'learning_rate': 0.04285567800628646, 'l2_leaf_reg': 0.10150937549655437, 'bagging_temperature': 0.2646635746628563}. Best is trial 21 with value: 0.4956699311733246.
# [I 2025-08-12 15:21:32,563] Trial 90 finished with value: 0.49469348788261414 and parameters: {'iterations': 1542, 'depth': 10, 'learning_rate': 0.060833652548271416, 'l2_leaf_reg': 0.05493586565560408, 'bagging_temperature': 0.15830448425078986}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:21:45,866] Trial 91 finished with value: 0.49968013167381287 and parameters: {'iterations': 1470, 'depth': 10, 'learning_rate': 0.06571938070159765, 'l2_leaf_reg': 0.055886920483026514, 'bagging_temperature': 0.16285452327878988}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:21:58,569] Trial 92 finished with value: 0.49876898527145386 and parameters: {'iterations': 1284, 'depth': 10, 'learning_rate': 0.08417478485151571, 'l2_leaf_reg': 0.03966796999758677, 'bagging_temperature': 0.33429252942942095}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:22:12,125] Trial 93 finished with value: 0.5002750158309937 and parameters: {'iterations': 1701, 'depth': 10, 'learning_rate': 0.056370921383995305, 'l2_leaf_reg': 0.07274125141465936, 'bagging_temperature': 0.2897508228551425}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:22:33,369] Trial 94 finished with value: 0.4973393976688385 and parameters: {'iterations': 1487, 'depth': 10, 'learning_rate': 0.028461450237338787, 'l2_leaf_reg': 0.029447957330030184, 'bagging_temperature': 0.19919744916045232}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:22:49,358] Trial 95 finished with value: 0.4951038360595703 and parameters: {'iterations': 1577, 'depth': 9, 'learning_rate': 0.032985894246281844, 'l2_leaf_reg': 0.018051271385660192, 'bagging_temperature': 0.15781549932827943}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:23:01,407] Trial 96 finished with value: 0.4978415369987488 and parameters: {'iterations': 1580, 'depth': 10, 'learning_rate': 0.11554305399636712, 'l2_leaf_reg': 0.02172881297448002, 'bagging_temperature': 0.14322733985432626}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:23:05,159] Trial 97 finished with value: 0.49752721190452576 and parameters: {'iterations': 1708, 'depth': 6, 'learning_rate': 0.04889050940047475, 'l2_leaf_reg': 0.017056474106752578, 'bagging_temperature': 0.18707865755647043}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:23:12,339] Trial 98 finished with value: 0.4967077970504761 and parameters: {'iterations': 1352, 'depth': 7, 'learning_rate': 0.03237286062125019, 'l2_leaf_reg': 0.013136296405900546, 'bagging_temperature': 0.3132563244073023}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:23:30,491] Trial 99 finished with value: 0.49658602476119995 and parameters: {'iterations': 1544, 'depth': 10, 'learning_rate': 0.042936152590562875, 'l2_leaf_reg': 0.1204241705475069, 'bagging_temperature': 0.41434659849576017}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:23:52,817] Trial 100 finished with value: 0.49881452322006226 and parameters: {'iterations': 1528, 'depth': 10, 'learning_rate': 0.022959609891039515, 'l2_leaf_reg': 0.1012765874235932, 'bagging_temperature': 0.3780703358635016}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:24:11,614] Trial 101 finished with value: 0.495663583278656 and parameters: {'iterations': 1642, 'depth': 10, 'learning_rate': 0.044214889860238256, 'l2_leaf_reg': 0.08054075159315062, 'bagging_temperature': 0.2769762265217611}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:24:29,956] Trial 102 finished with value: 0.4961370825767517 and parameters: {'iterations': 1413, 'depth': 10, 'learning_rate': 0.044913567781539744, 'l2_leaf_reg': 0.08276486222579443, 'bagging_temperature': 0.20849211925786804}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:24:45,253] Trial 103 finished with value: 0.49591124057769775 and parameters: {'iterations': 1368, 'depth': 10, 'learning_rate': 0.06938777916278772, 'l2_leaf_reg': 0.07464583347601136, 'bagging_temperature': 0.2117481832186583}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:24:58,352] Trial 104 finished with value: 0.49952271580696106 and parameters: {'iterations': 1400, 'depth': 10, 'learning_rate': 0.07421574102576585, 'l2_leaf_reg': 0.07901524214383258, 'bagging_temperature': 0.2141597269777963}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:25:13,840] Trial 105 finished with value: 0.4963781535625458 and parameters: {'iterations': 1250, 'depth': 10, 'learning_rate': 0.06185399616137037, 'l2_leaf_reg': 0.04740997786939067, 'bagging_temperature': 0.13761996164183873}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:25:29,236] Trial 106 finished with value: 0.49699199199676514 and parameters: {'iterations': 1111, 'depth': 10, 'learning_rate': 0.05862441673906023, 'l2_leaf_reg': 0.053334964039845945, 'bagging_temperature': 0.15099848039983188}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:25:39,732] Trial 107 finished with value: 0.4982376992702484 and parameters: {'iterations': 1177, 'depth': 10, 'learning_rate': 0.1841163146920952, 'l2_leaf_reg': 0.026278082575923206, 'bagging_temperature': 0.11922343468706458}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:25:52,583] Trial 108 finished with value: 0.49867185950279236 and parameters: {'iterations': 1280, 'depth': 10, 'learning_rate': 0.08527444943797204, 'l2_leaf_reg': 0.04816768446434513, 'bagging_temperature': 0.28164470435195504}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:26:09,136] Trial 109 finished with value: 0.4965059161186218 and parameters: {'iterations': 1342, 'depth': 10, 'learning_rate': 0.051117609232421465, 'l2_leaf_reg': 0.062285001822578435, 'bagging_temperature': 0.16767418297138711}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:26:23,689] Trial 110 finished with value: 0.49711742997169495 and parameters: {'iterations': 1180, 'depth': 10, 'learning_rate': 0.0691448720005376, 'l2_leaf_reg': 0.03714049417336897, 'bagging_temperature': 0.23837847756299635}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:26:38,289] Trial 111 finished with value: 0.49889639019966125 and parameters: {'iterations': 1403, 'depth': 10, 'learning_rate': 0.051161153603529186, 'l2_leaf_reg': 0.06515598507236514, 'bagging_temperature': 0.17916352636559005}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:26:52,625] Trial 112 finished with value: 0.4983384609222412 and parameters: {'iterations': 1637, 'depth': 10, 'learning_rate': 0.060282212982141224, 'l2_leaf_reg': 0.01921032925442046, 'bagging_temperature': 0.1332212837355465}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:27:08,083] Trial 113 finished with value: 0.4981728792190552 and parameters: {'iterations': 1794, 'depth': 10, 'learning_rate': 0.05331550729080331, 'l2_leaf_reg': 0.08499257657980228, 'bagging_temperature': 0.29716997071838525}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:27:25,279] Trial 114 finished with value: 0.497507780790329 and parameters: {'iterations': 1219, 'depth': 10, 'learning_rate': 0.04445646323798922, 'l2_leaf_reg': 0.044877223762095374, 'bagging_temperature': 0.3402667808849007}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:27:38,792] Trial 115 finished with value: 0.49865224957466125 and parameters: {'iterations': 1492, 'depth': 10, 'learning_rate': 0.07088433484073403, 'l2_leaf_reg': 0.06476204508173476, 'bagging_temperature': 0.20820323343561442}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:27:51,535] Trial 116 finished with value: 0.49948635697364807 and parameters: {'iterations': 1323, 'depth': 10, 'learning_rate': 0.08033415837956519, 'l2_leaf_reg': 0.03176277873519508, 'bagging_temperature': 0.24743778780376285}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:28:03,316] Trial 117 finished with value: 0.4999930262565613 and parameters: {'iterations': 1076, 'depth': 10, 'learning_rate': 0.09983516936075076, 'l2_leaf_reg': 0.08424021276487702, 'bagging_temperature': 0.1692075074129567}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:28:23,923] Trial 118 finished with value: 0.497428834438324 and parameters: {'iterations': 1442, 'depth': 10, 'learning_rate': 0.029575480170408043, 'l2_leaf_reg': 0.014617621702045579, 'bagging_temperature': 0.11011944445823389}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:28:36,797] Trial 119 finished with value: 0.49725431203842163 and parameters: {'iterations': 1678, 'depth': 10, 'learning_rate': 0.09389166488547061, 'l2_leaf_reg': 0.010063541902113782, 'bagging_temperature': 0.349330690320411}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:28:47,576] Trial 120 finished with value: 0.49787572026252747 and parameters: {'iterations': 1416, 'depth': 9, 'learning_rate': 0.04446347748161235, 'l2_leaf_reg': 0.1815585272796583, 'bagging_temperature': 0.20588406541888382}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:29:05,639] Trial 121 finished with value: 0.49605390429496765 and parameters: {'iterations': 1359, 'depth': 10, 'learning_rate': 0.04508807519877678, 'l2_leaf_reg': 0.12396771430869304, 'bagging_temperature': 0.44327061167625514}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:29:21,498] Trial 122 finished with value: 0.49767017364501953 and parameters: {'iterations': 1329, 'depth': 10, 'learning_rate': 0.052742176691390245, 'l2_leaf_reg': 0.06105766677826314, 'bagging_temperature': 0.3771774788835261}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:29:36,741] Trial 123 finished with value: 0.4971218705177307 and parameters: {'iterations': 1525, 'depth': 10, 'learning_rate': 0.062289270433473924, 'l2_leaf_reg': 0.1330194589334433, 'bagging_temperature': 0.4748287678659724}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:29:56,282] Trial 124 finished with value: 0.4976096749305725 and parameters: {'iterations': 1263, 'depth': 10, 'learning_rate': 0.03352488212465924, 'l2_leaf_reg': 0.07137080829235015, 'bagging_temperature': 0.565966477765963}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:30:13,015] Trial 125 finished with value: 0.497698038816452 and parameters: {'iterations': 1734, 'depth': 10, 'learning_rate': 0.04766269401115165, 'l2_leaf_reg': 0.09334030795378356, 'bagging_temperature': 0.31559683034892944}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:30:29,782] Trial 126 finished with value: 0.4984331727027893 and parameters: {'iterations': 1221, 'depth': 10, 'learning_rate': 0.04088343478857879, 'l2_leaf_reg': 0.11423535582382847, 'bagging_temperature': 0.2428117233882377}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:30:49,177] Trial 127 finished with value: 0.4970874488353729 and parameters: {'iterations': 1366, 'depth': 10, 'learning_rate': 0.03668973710884381, 'l2_leaf_reg': 0.055927652447593276, 'bagging_temperature': 0.17788831950683526}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:31:09,659] Trial 128 finished with value: 0.49845796823501587 and parameters: {'iterations': 1651, 'depth': 10, 'learning_rate': 0.02671031948478621, 'l2_leaf_reg': 0.04262227849301571, 'bagging_temperature': 0.10664286721139839}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:31:20,547] Trial 129 finished with value: 0.49628058075904846 and parameters: {'iterations': 1324, 'depth': 9, 'learning_rate': 0.05333247824309028, 'l2_leaf_reg': 0.1297199363429059, 'bagging_temperature': 0.4062521809463664}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:31:29,317] Trial 130 finished with value: 0.4987605810165405 and parameters: {'iterations': 1047, 'depth': 9, 'learning_rate': 0.0635902732123173, 'l2_leaf_reg': 0.13220965195442047, 'bagging_temperature': 0.44830706166015066}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:31:45,641] Trial 131 finished with value: 0.49721959233283997 and parameters: {'iterations': 1324, 'depth': 10, 'learning_rate': 0.05435432906429053, 'l2_leaf_reg': 0.09018512396096118, 'bagging_temperature': 0.2754349285772973}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:31:48,882] Trial 132 finished with value: 0.49766916036605835 and parameters: {'iterations': 1851, 'depth': 4, 'learning_rate': 0.05004962553402654, 'l2_leaf_reg': 0.07272635703150575, 'bagging_temperature': 0.21985946294298664}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:32:00,120] Trial 133 finished with value: 0.49701932072639465 and parameters: {'iterations': 1443, 'depth': 9, 'learning_rate': 0.04453992319830348, 'l2_leaf_reg': 0.16336817644532836, 'bagging_temperature': 0.39180141094377874}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:32:13,101] Trial 134 finished with value: 0.4987804889678955 and parameters: {'iterations': 1216, 'depth': 10, 'learning_rate': 0.07671185353134069, 'l2_leaf_reg': 0.05491461319288269, 'bagging_temperature': 0.1538453956439696}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:32:32,643] Trial 135 finished with value: 0.496236115694046 and parameters: {'iterations': 1515, 'depth': 10, 'learning_rate': 0.03987054072417409, 'l2_leaf_reg': 0.10801426006272119, 'bagging_temperature': 0.31032357475134587}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:32:51,384] Trial 136 finished with value: 0.4972323477268219 and parameters: {'iterations': 1581, 'depth': 10, 'learning_rate': 0.03836624902321675, 'l2_leaf_reg': 0.104496265626822, 'bagging_temperature': 0.35133490354011243}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:33:04,965] Trial 137 finished with value: 0.4979134798049927 and parameters: {'iterations': 1520, 'depth': 9, 'learning_rate': 0.030093346876233704, 'l2_leaf_reg': 0.23044380534758488, 'bagging_temperature': 0.29602077487423684}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:33:25,746] Trial 138 finished with value: 0.4962916672229767 and parameters: {'iterations': 1472, 'depth': 10, 'learning_rate': 0.034958643155813984, 'l2_leaf_reg': 0.12640785765847187, 'bagging_temperature': 0.41216189651950286}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:33:47,169] Trial 139 finished with value: 0.4969141483306885 and parameters: {'iterations': 1499, 'depth': 10, 'learning_rate': 0.03186651568054539, 'l2_leaf_reg': 0.1786546656481475, 'bagging_temperature': 0.45772540115024823}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:34:05,306] Trial 140 finished with value: 0.4986061155796051 and parameters: {'iterations': 1601, 'depth': 10, 'learning_rate': 0.034690429470164305, 'l2_leaf_reg': 0.14708327225017628, 'bagging_temperature': 0.4106869284418959}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:34:23,025] Trial 141 finished with value: 0.4981556236743927 and parameters: {'iterations': 1421, 'depth': 10, 'learning_rate': 0.03950281062172048, 'l2_leaf_reg': 0.1248916174925634, 'bagging_temperature': 0.5007018949005395}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:34:40,595] Trial 142 finished with value: 0.4965837895870209 and parameters: {'iterations': 1463, 'depth': 10, 'learning_rate': 0.04591871774000431, 'l2_leaf_reg': 0.08543178107155279, 'bagging_temperature': 0.5789972611692892}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:35:03,164] Trial 143 finished with value: 0.49788904190063477 and parameters: {'iterations': 1378, 'depth': 10, 'learning_rate': 0.025289802409967446, 'l2_leaf_reg': 0.11086744258287846, 'bagging_temperature': 0.33084533469755995}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:35:18,127] Trial 144 finished with value: 0.498726487159729 and parameters: {'iterations': 1568, 'depth': 10, 'learning_rate': 0.058484118823996054, 'l2_leaf_reg': 0.2750643926665317, 'bagging_temperature': 0.26099851223311105}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:35:38,127] Trial 145 finished with value: 0.4957199692726135 and parameters: {'iterations': 1297, 'depth': 10, 'learning_rate': 0.03980503200312028, 'l2_leaf_reg': 0.07801800315909674, 'bagging_temperature': 0.38449712011187037}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:35:55,262] Trial 146 finished with value: 0.49797648191452026 and parameters: {'iterations': 1543, 'depth': 10, 'learning_rate': 0.041238341813479164, 'l2_leaf_reg': 0.07774543866891821, 'bagging_temperature': 0.37783560524666726}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:36:18,330] Trial 147 finished with value: 0.49696868658065796 and parameters: {'iterations': 1317, 'depth': 10, 'learning_rate': 0.0281461217698846, 'l2_leaf_reg': 0.14081901956741896, 'bagging_temperature': 0.5348281904600126}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:36:31,183] Trial 148 finished with value: 0.4973132610321045 and parameters: {'iterations': 1477, 'depth': 9, 'learning_rate': 0.034089670479199495, 'l2_leaf_reg': 0.09190118144190254, 'bagging_temperature': 0.41352946072514}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:36:50,701] Trial 149 finished with value: 0.4973088502883911 and parameters: {'iterations': 1678, 'depth': 10, 'learning_rate': 0.03634834407674895, 'l2_leaf_reg': 0.19087324267677264, 'bagging_temperature': 0.2994897233612437}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:37:14,044] Trial 150 finished with value: 0.4977482259273529 and parameters: {'iterations': 1620, 'depth': 10, 'learning_rate': 0.023892800796820494, 'l2_leaf_reg': 0.123515703421753, 'bagging_temperature': 0.3497338883633251}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:37:27,068] Trial 151 finished with value: 0.5001540184020996 and parameters: {'iterations': 1262, 'depth': 10, 'learning_rate': 0.0685507440785768, 'l2_leaf_reg': 0.09854020074827936, 'bagging_temperature': 1.8802921055790336}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:37:41,653] Trial 152 finished with value: 0.49934378266334534 and parameters: {'iterations': 1304, 'depth': 10, 'learning_rate': 0.04896640006472048, 'l2_leaf_reg': 0.049516451701320824, 'bagging_temperature': 0.4534432025562079}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:37:55,449] Trial 153 finished with value: 0.4997674226760864 and parameters: {'iterations': 1223, 'depth': 10, 'learning_rate': 0.05523791772411219, 'l2_leaf_reg': 0.07190079986459667, 'bagging_temperature': 0.21117626166280268}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:38:11,896] Trial 154 finished with value: 0.49833598732948303 and parameters: {'iterations': 1365, 'depth': 10, 'learning_rate': 0.041638321252216635, 'l2_leaf_reg': 0.019086303351376132, 'bagging_temperature': 0.2549010300981527}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:38:30,066] Trial 155 finished with value: 0.4963836967945099 and parameters: {'iterations': 1400, 'depth': 10, 'learning_rate': 0.045655059016652816, 'l2_leaf_reg': 0.15589825214902553, 'bagging_temperature': 0.5071771408892886}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:38:50,180] Trial 156 finished with value: 0.49764519929885864 and parameters: {'iterations': 1263, 'depth': 10, 'learning_rate': 0.03174236260233857, 'l2_leaf_reg': 0.02604343794661889, 'bagging_temperature': 0.3135030007908839}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:39:16,729] Trial 157 finished with value: 0.4970887005329132 and parameters: {'iterations': 1450, 'depth': 10, 'learning_rate': 0.02092345132464159, 'l2_leaf_reg': 0.08257454308105887, 'bagging_temperature': 0.14016746628689697}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:39:21,244] Trial 158 finished with value: 0.49714159965515137 and parameters: {'iterations': 1761, 'depth': 5, 'learning_rate': 0.037947374456132346, 'l2_leaf_reg': 0.11112040922762577, 'bagging_temperature': 0.1847692359554357}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:39:35,654] Trial 159 finished with value: 0.49850717186927795 and parameters: {'iterations': 1378, 'depth': 10, 'learning_rate': 0.05847475777831504, 'l2_leaf_reg': 0.03520319964032415, 'bagging_temperature': 0.6273834916089773}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:39:50,186] Trial 160 finished with value: 0.4972018897533417 and parameters: {'iterations': 1506, 'depth': 10, 'learning_rate': 0.06518686304499907, 'l2_leaf_reg': 0.012814959876195213, 'bagging_temperature': 0.24063846887446638}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 15:40:06,252] Trial 161 finished with value: 0.4983395040035248 and parameters: {'iterations': 1138, 'depth': 10, 'learning_rate': 0.045769502071177, 'l2_leaf_reg': 0.15118817122385425, 'bagging_temperature': 0.43008254496579323}. Best is trial 90 with value: 0.49469348788261414.
# ...
# [I 2025-08-12 17:09:32,996] Trial 447 finished with value: 0.4974406957626343 and parameters: {'iterations': 2043, 'depth': 10, 'learning_rate': 0.03472372432301246, 'l2_leaf_reg': 0.07127065007508443, 'bagging_temperature': 0.35560826860253214}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 17:09:52,325] Trial 448 finished with value: 0.49502766132354736 and parameters: {'iterations': 2478, 'depth': 10, 'learning_rate': 0.05120785841478977, 'l2_leaf_reg': 0.08426073286009592, 'bagging_temperature': 0.14920945084766074}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 17:10:09,287] Trial 449 finished with value: 0.4964931905269623 and parameters: {'iterations': 2412, 'depth': 10, 'learning_rate': 0.056136386909648645, 'l2_leaf_reg': 0.08492095661723746, 'bagging_temperature': 0.14234687013409153}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 17:10:15,344] Trial 450 finished with value: 0.49800539016723633 and parameters: {'iterations': 2476, 'depth': 8, 'learning_rate': 0.06299742257311297, 'l2_leaf_reg': 0.0691312831870067, 'bagging_temperature': 0.1748572869135386}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 17:10:33,077] Trial 451 finished with value: 0.4983537793159485 and parameters: {'iterations': 2585, 'depth': 10, 'learning_rate': 0.038462082022558734, 'l2_leaf_reg': 0.08643177489717215, 'bagging_temperature': 0.13486166816272183}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 17:10:51,098] Trial 452 finished with value: 0.4955295920372009 and parameters: {'iterations': 2463, 'depth': 10, 'learning_rate': 0.0512889872257231, 'l2_leaf_reg': 0.06251636346878833, 'bagging_temperature': 0.19807667884630203}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 17:11:07,505] Trial 453 finished with value: 0.49678874015808105 and parameters: {'iterations': 2412, 'depth': 10, 'learning_rate': 0.04991110539870638, 'l2_leaf_reg': 0.060799191134833314, 'bagging_temperature': 0.19343074739686017}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 17:11:21,668] Trial 454 finished with value: 0.4993797242641449 and parameters: {'iterations': 2452, 'depth': 10, 'learning_rate': 0.05402617339079928, 'l2_leaf_reg': 0.041983522770132294, 'bagging_temperature': 0.16467290848246183}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 17:11:34,694] Trial 455 finished with value: 0.4995374381542206 and parameters: {'iterations': 2369, 'depth': 10, 'learning_rate': 0.06684053593010486, 'l2_leaf_reg': 0.05259088143325371, 'bagging_temperature': 0.21088131676368854}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 17:11:51,219] Trial 456 finished with value: 0.49759572744369507 and parameters: {'iterations': 2497, 'depth': 10, 'learning_rate': 0.045668967488845254, 'l2_leaf_reg': 0.06673568775886543, 'bagging_temperature': 0.13718506674360756}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 17:12:07,187] Trial 457 finished with value: 0.49678951501846313 and parameters: {'iterations': 2431, 'depth': 10, 'learning_rate': 0.056874411162853446, 'l2_leaf_reg': 0.07947815110554253, 'bagging_temperature': 0.23463699194568988}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 17:12:21,613] Trial 458 finished with value: 0.4993462562561035 and parameters: {'iterations': 2309, 'depth': 10, 'learning_rate': 0.04890429906027174, 'l2_leaf_reg': 0.0473235894688793, 'bagging_temperature': 0.16758697745929574}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 17:12:38,446] Trial 459 finished with value: 0.4977073073387146 and parameters: {'iterations': 2460, 'depth': 10, 'learning_rate': 0.04423208542684721, 'l2_leaf_reg': 0.05770020913355813, 'bagging_temperature': 0.10106503147451554}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 17:12:53,473] Trial 460 finished with value: 0.4988015592098236 and parameters: {'iterations': 2510, 'depth': 10, 'learning_rate': 0.05370075147831674, 'l2_leaf_reg': 0.07475139279191445, 'bagging_temperature': 1.58275243095076}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 17:13:08,414] Trial 461 finished with value: 0.4990815222263336 and parameters: {'iterations': 2433, 'depth': 10, 'learning_rate': 0.051686614473785863, 'l2_leaf_reg': 0.09121956033194681, 'bagging_temperature': 0.19152566169381896}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 17:13:21,819] Trial 462 finished with value: 0.49938657879829407 and parameters: {'iterations': 2514, 'depth': 10, 'learning_rate': 0.061554671653598854, 'l2_leaf_reg': 0.023513113308624187, 'bagging_temperature': 0.2687099829722608}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 17:13:31,611] Trial 463 finished with value: 0.4992399215698242 and parameters: {'iterations': 1418, 'depth': 9, 'learning_rate': 0.04373355855392573, 'l2_leaf_reg': 0.06310389796943178, 'bagging_temperature': 0.2200794330400749}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 17:13:44,515] Trial 464 finished with value: 0.4983973801136017 and parameters: {'iterations': 2465, 'depth': 10, 'learning_rate': 0.0789067456416048, 'l2_leaf_reg': 0.10391084619013848, 'bagging_temperature': 0.13203802849040114}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 17:14:02,473] Trial 465 finished with value: 0.4967734217643738 and parameters: {'iterations': 1490, 'depth': 10, 'learning_rate': 0.04070390896917848, 'l2_leaf_reg': 0.031115087103113958, 'bagging_temperature': 0.24674809836060388}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 17:14:18,339] Trial 466 finished with value: 0.49769020080566406 and parameters: {'iterations': 2385, 'depth': 10, 'learning_rate': 0.04888729397023696, 'l2_leaf_reg': 0.010107806208233167, 'bagging_temperature': 0.17773721833464476}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 17:14:33,243] Trial 467 finished with value: 0.49810558557510376 and parameters: {'iterations': 2537, 'depth': 10, 'learning_rate': 0.05673875403512785, 'l2_leaf_reg': 0.03829168128790674, 'bagging_temperature': 0.10038988992798792}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 17:15:20,813] Trial 468 finished with value: 0.4974604845046997 and parameters: {'iterations': 1351, 'depth': 10, 'learning_rate': 0.008294371191751356, 'l2_leaf_reg': 0.05149976352747967, 'bagging_temperature': 0.2753737565784729}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 17:15:39,136] Trial 469 finished with value: 0.4956481158733368 and parameters: {'iterations': 1446, 'depth': 10, 'learning_rate': 0.04574942979235631, 'l2_leaf_reg': 0.07218887171224739, 'bagging_temperature': 0.21795597146172402}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 17:15:58,079] Trial 470 finished with value: 0.4965060353279114 and parameters: {'iterations': 1453, 'depth': 10, 'learning_rate': 0.038927239051344084, 'l2_leaf_reg': 0.07103709748097353, 'bagging_temperature': 0.23469666848923418}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 17:16:16,900] Trial 471 finished with value: 0.4956463575363159 and parameters: {'iterations': 1400, 'depth': 10, 'learning_rate': 0.04440385966617003, 'l2_leaf_reg': 0.08429059721097223, 'bagging_temperature': 0.29187925651706}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 17:16:30,301] Trial 472 finished with value: 0.49913573265075684 and parameters: {'iterations': 1422, 'depth': 10, 'learning_rate': 0.06834748331892926, 'l2_leaf_reg': 0.09393553490137248, 'bagging_temperature': 1.4204255179028913}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 17:16:46,769] Trial 473 finished with value: 0.49749502539634705 and parameters: {'iterations': 1390, 'depth': 10, 'learning_rate': 0.046217751382473436, 'l2_leaf_reg': 0.059711851546014924, 'bagging_temperature': 0.28962463331248683}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 17:17:02,454] Trial 474 finished with value: 0.49747878313064575 and parameters: {'iterations': 1322, 'depth': 10, 'learning_rate': 0.05360289889571066, 'l2_leaf_reg': 0.08210965190260977, 'bagging_temperature': 1.8397142972443385}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 17:17:23,781] Trial 475 finished with value: 0.49788111448287964 and parameters: {'iterations': 1264, 'depth': 9, 'learning_rate': 0.014423592741426357, 'l2_leaf_reg': 0.06657501740648859, 'bagging_temperature': 0.2078210990522453}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 17:17:41,240] Trial 476 finished with value: 0.49707964062690735 and parameters: {'iterations': 1370, 'depth': 10, 'learning_rate': 0.04636689654896477, 'l2_leaf_reg': 0.10438497200950338, 'bagging_temperature': 0.3106690055696704}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 17:18:20,073] Trial 477 finished with value: 0.4974047541618347 and parameters: {'iterations': 1393, 'depth': 10, 'learning_rate': 0.011173638147915313, 'l2_leaf_reg': 0.046564934214146994, 'bagging_temperature': 0.27727265829221415}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 17:18:36,301] Trial 478 finished with value: 0.49559393525123596 and parameters: {'iterations': 1474, 'depth': 10, 'learning_rate': 0.06006972526413039, 'l2_leaf_reg': 0.08893934118907816, 'bagging_temperature': 0.6996761805748497}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 17:18:49,287] Trial 479 finished with value: 0.5000796318054199 and parameters: {'iterations': 1463, 'depth': 10, 'learning_rate': 0.0665729731189168, 'l2_leaf_reg': 0.08022925927293112, 'bagging_temperature': 0.20444905853480783}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 17:19:02,494] Trial 480 finished with value: 0.49831900000572205 and parameters: {'iterations': 1421, 'depth': 10, 'learning_rate': 0.07303409538376733, 'l2_leaf_reg': 0.06691286725492991, 'bagging_temperature': 0.7432945952959094}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 17:19:16,132] Trial 481 finished with value: 0.49929165840148926 and parameters: {'iterations': 1458, 'depth': 10, 'learning_rate': 0.0618568032887719, 'l2_leaf_reg': 0.05719401351792544, 'bagging_temperature': 0.17039271683530016}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 17:19:31,015] Trial 482 finished with value: 0.49805861711502075 and parameters: {'iterations': 1348, 'depth': 10, 'learning_rate': 0.060371617838050125, 'l2_leaf_reg': 0.08877898198953511, 'bagging_temperature': 0.8906294312530864}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 17:19:47,246] Trial 483 finished with value: 0.49628061056137085 and parameters: {'iterations': 1437, 'depth': 10, 'learning_rate': 0.059305354132963346, 'l2_leaf_reg': 0.07580926207696624, 'bagging_temperature': 0.6603504476885413}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 17:20:03,608] Trial 484 finished with value: 0.4965301752090454 and parameters: {'iterations': 2790, 'depth': 10, 'learning_rate': 0.05423591656379399, 'l2_leaf_reg': 0.054477418151583405, 'bagging_temperature': 0.5626852021886326}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 17:20:19,058] Trial 485 finished with value: 0.4978446662425995 and parameters: {'iterations': 1482, 'depth': 10, 'learning_rate': 0.051678462299149915, 'l2_leaf_reg': 0.06844691103613997, 'bagging_temperature': 0.6859581028867527}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 17:20:33,257] Trial 486 finished with value: 0.4965667128562927 and parameters: {'iterations': 1384, 'depth': 10, 'learning_rate': 0.08033480959287234, 'l2_leaf_reg': 0.09354952338613519, 'bagging_temperature': 0.2278972122155736}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 17:20:47,213] Trial 487 finished with value: 0.4978778660297394 and parameters: {'iterations': 1194, 'depth': 10, 'learning_rate': 0.06981221742178088, 'l2_leaf_reg': 0.03954687920807756, 'bagging_temperature': 1.079846094988794}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 17:21:04,107] Trial 488 finished with value: 0.49749934673309326 and parameters: {'iterations': 1481, 'depth': 10, 'learning_rate': 0.044690987953322464, 'l2_leaf_reg': 0.11456476466126465, 'bagging_temperature': 0.19762323096919074}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 17:22:04,053] Trial 489 finished with value: 0.4975142180919647 and parameters: {'iterations': 1282, 'depth': 10, 'learning_rate': 0.00633514504131257, 'l2_leaf_reg': 0.04675023343702052, 'bagging_temperature': 0.8549982381383221}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 17:22:18,214] Trial 490 finished with value: 0.49950334429740906 and parameters: {'iterations': 2250, 'depth': 10, 'learning_rate': 0.051569752116594515, 'l2_leaf_reg': 0.06284285873841136, 'bagging_temperature': 0.2568858579703682}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 17:22:32,692] Trial 491 finished with value: 0.4980379343032837 and parameters: {'iterations': 1406, 'depth': 10, 'learning_rate': 0.05907443845207546, 'l2_leaf_reg': 0.0792965701690041, 'bagging_temperature': 0.16103433317267501}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 17:22:55,860] Trial 492 finished with value: 0.4973861873149872 and parameters: {'iterations': 1504, 'depth': 10, 'learning_rate': 0.03891583377507331, 'l2_leaf_reg': 2.1797263169450285, 'bagging_temperature': 0.5970897781749485}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 17:23:12,626] Trial 493 finished with value: 0.4966244697570801 and parameters: {'iterations': 2343, 'depth': 10, 'learning_rate': 0.04817664300363598, 'l2_leaf_reg': 0.05231429148655162, 'bagging_temperature': 0.22669994315370343}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 17:23:27,859] Trial 494 finished with value: 0.49941298365592957 and parameters: {'iterations': 1319, 'depth': 10, 'learning_rate': 0.04278048211254209, 'l2_leaf_reg': 0.1441671805506718, 'bagging_temperature': 1.1916511346313903}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 17:23:47,652] Trial 495 finished with value: 0.49662017822265625 and parameters: {'iterations': 1432, 'depth': 10, 'learning_rate': 0.03604567062043961, 'l2_leaf_reg': 0.10177966642507211, 'bagging_temperature': 0.2785368009721433}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 17:23:57,246] Trial 496 finished with value: 0.4976152777671814 and parameters: {'iterations': 1356, 'depth': 9, 'learning_rate': 0.058070408442855416, 'l2_leaf_reg': 0.07176263298887672, 'bagging_temperature': 0.19131779444844874}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 17:24:11,486] Trial 497 finished with value: 0.4998231828212738 and parameters: {'iterations': 1521, 'depth': 10, 'learning_rate': 0.05115819825842215, 'l2_leaf_reg': 0.0880852651603186, 'bagging_temperature': 0.14823714512816677}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 17:24:27,392] Trial 498 finished with value: 0.49859854578971863 and parameters: {'iterations': 1549, 'depth': 10, 'learning_rate': 0.043418620884056174, 'l2_leaf_reg': 0.05765202429705593, 'bagging_temperature': 0.24708284326650468}. Best is trial 90 with value: 0.49469348788261414.
# [I 2025-08-12 17:24:41,236] Trial 499 finished with value: 0.4987102150917053 and parameters: {'iterations': 2133, 'depth': 10, 'learning_rate': 0.06377928168940444, 'l2_leaf_reg': 0.12318399796493773, 'bagging_temperature': 0.3145555586136817}. Best is trial 90 with value: 0.49469348788261414.
# Best predicted LB: 0.49469348788261414
# Best params: {'iterations': 1542, 'depth': 10, 'learning_rate': 0.060833652548271416, 'l2_leaf_reg': 0.05493586565560408, 'bagging_temperature': 0.15830448425078986}

# %%
# =========================
# 6) Final CPU refit (with rsm + grow_policy + feature_border_type)
# =========================
FINAL_PARAMS = {
    "loss_function": "MultiRMSEWithMissingValues",
    "eval_metric": "MultiRMSEWithMissingValues",
    "task_type": "CPU",
    "iterations":  study.best_trial.params.get("iterations", 2000),
    "learning_rate": study.best_trial.params.get("learning_rate", 0.05),
    "depth": study.best_trial.params.get("depth", 8),
    "l2_leaf_reg": study.best_trial.params.get("l2_leaf_reg", 3.0),
    "rsm": 0.93,  # put your tuned or fixed value here
    "grow_policy": "SymmetricTree",
    "bootstrap_type": "Bayesian",
    "bagging_temperature": study.best_trial.params.get("bagging_temperature", 1.0),
    "border_count": 128,
    "feature_border_type": "GreedyLogSum",
    "min_data_in_leaf": 5,
    "random_seed": SEED,
    "use_best_model": False,
    "verbose": 200,
}

final_model = CatBoostRegressor(**FINAL_PARAMS)
final_model.fit(Pool(X_mat, label=Y_mat))

ts = int(time.time())
model_path = f"final_model_{ts}.cbm"
final_model.save_model(model_path)
print("Saved CatBoost model:", model_path)

param_path = f"best_params_{ts}.json"
with open(param_path, "w") as f:
    json.dump(study.best_trial.params, f, indent=2)
print("Saved best params:", param_path)

pred_test = final_model.predict(X_test)
# Out:
# 0:	learn: 2.3266656	total: 195ms	remaining: 5m
# 200:	learn: 0.9987869	total: 39.2s	remaining: 4m 21s
# 400:	learn: 0.7089819	total: 1m 18s	remaining: 3m 42s
# 600:	learn: 0.6247775	total: 1m 57s	remaining: 3m 3s
# 800:	learn: 0.5993216	total: 2m 36s	remaining: 2m 24s
# 1000:	learn: 0.5886434	total: 3m 15s	remaining: 1m 45s
# 1200:	learn: 0.5825808	total: 3m 53s	remaining: 1m 6s
# 1400:	learn: 0.5786644	total: 4m 31s	remaining: 27.3s
# 1541:	learn: 0.5767213	total: 4m 58s	remaining: 0us
# Saved CatBoost model: final_model_1754994580.cbm
# Saved best params: best_params_1754994580.json

# %%
sub = pd.DataFrame(pred_test, columns=TARGET_COLS)
sub["ID"] = [ID for ID in range(1, len(pred_test) + 1)]  # IDs start from 1
sub_path = f"submission_anchor_{ts}.csv"
sub.to_csv(sub_path, index=False)
print("Saved submission:", sub_path)
# Out:
# Saved submission: submission_anchor_1754994580.csv
