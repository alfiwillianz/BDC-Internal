# %% [markdown]
# # PCA vs SVD Ensemble Pipeline
#
# This notebook implements a comprehensive pipeline that:
# 1. Tests both PCA and SVD dimensionality reduction (256 components)
# 2. Uses Optuna hyperparameter tuning for each method
# 3. Trains 5 different seeds for robustness
# 4. Ensembles predictions using multiple strategies
# 5. Compares correlation and performance between methods

# %%
# =========================
# 0) Imports & constants
# =========================
import os, re, glob, time, json
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA, TruncatedSVD
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from numpy.linalg import norm
import warnings
warnings.filterwarnings('ignore')

SEED = 42
TARGET_COLS = [
    "task_achievement",
    "coherence_and_cohesion", 
    "lexical_resource",
    "grammatical_range",
]
N_COMPONENTS = 256
ANCHOR_DIR = "./Anchors"
OPTUNA_TRIALS = 200          # Reduced for efficiency
TEMP_SOFTMAX = 20.0
TOPK_ANCHORS = 5
VAL_SIZE = 0.2
N_SEEDS = 5                  # Number of seeds for bagging

# Load data
train_emb = pd.read_csv("train_embeddings.csv")
test_emb  = pd.read_csv("test_embeddings.csv")
train_df  = pd.read_csv("train_feature_eng.csv")
test_df   = pd.read_csv("test_feature_eng.csv")

print("Data loaded successfully!")
print(f"Train embeddings shape: {train_emb.shape}")
print(f"Test embeddings shape: {test_emb.shape}")
# Out:
# Data loaded successfully!
# Train embeddings shape: (9912, 4096)
# Test embeddings shape: (473, 4096)

# %%
# ...existing code for feature engineering...
import numpy as np
import pandas as pd
import re
import nltk
from nltk import word_tokenize, pos_tag
from collections import Counter
from sentence_transformers import SentenceTransformer, util
from nltk.corpus import wordnet as wn

nltk.download("wordnet", quiet=True)
nltk.download("omw-1.4", quiet=True)

# ---------- Helper: Lexical sophistication ----------
import requests

url = "https://raw.githubusercontent.com/first20hours/google-10000-english/master/20k.txt"
response = requests.get(url)
response.raise_for_status()
COMMON_WORDS = set(response.text.split()[:2000])

def lexical_sophistication(tokens):
    rare_words = [t for t in tokens if t.lower() not in COMMON_WORDS]
    return len(rare_words) / len(tokens) if tokens else 0

# ---------- Helper: Root & Corrected TTR ----------
def root_ttr(tokens):
    return len(set(tokens)) / np.sqrt(len(tokens)) if tokens else 0

def corrected_ttr(tokens):
    return len(set(tokens)) / np.sqrt(2 * len(tokens)) if tokens else 0

# ---------- Helper: MATTR ----------
def mattr(tokens, window_size=50):
    if len(tokens) < window_size:
        return len(set(tokens)) / len(tokens)
    scores = []
    for i in range(len(tokens) - window_size + 1):
        window = tokens[i:i+window_size]
        scores.append(len(set(window)) / window_size)
    return np.mean(scores)

# ...existing code for other helper functions...
def complex_sentence_ratio(text):
    sentences = nltk.sent_tokenize(text)
    complex_count = sum(1 for s in sentences if len(re.findall(r"\b(and|but|or|because|which|although)\b", s.lower())) >= 2)
    return complex_count / len(sentences) if sentences else 0

def avg_hypernym_depth(tokens):
    depths = []
    for t in tokens:
        synsets = wn.synsets(t)
        if synsets:
            depths.append(max((s.min_depth() for s in synsets), default=0))
    return np.mean(depths) if depths else 0

def topic_drift(text, model):
    paras = [p.strip() for p in text.split("\n") if p.strip()]
    if len(paras) < 2:
        return 0
    emb_start = model.encode([paras[0]], convert_to_tensor=True)
    emb_end = model.encode([paras[-1]], convert_to_tensor=True)
    return 1 - util.cos_sim(emb_start, emb_end).item()

def alliteration_ratio(tokens):
    if len(tokens) < 2:
        return 0
    count = sum(1 for i in range(len(tokens)-1) if tokens[i][0].lower() == tokens[i+1][0].lower())
    return count / (len(tokens)-1)

HEDGING_WORDS = {"might", "maybe", "perhaps", "possibly", "could", "should"}
def hedging_count(tokens):
    return sum(1 for t in tokens if t.lower() in HEDGING_WORDS)

EMOTIVE_WORDS = {"love", "hate", "happy", "sad", "angry", "excited", "worried", "proud"}
def emotive_count(tokens):
    return sum(1 for t in tokens if t.lower() in EMOTIVE_WORDS)

def add_extra_features(df, text_col="essay_clean", prompt_col="prompt_clean"):
    sbert = SentenceTransformer("sentence-transformers/paraphrase-MiniLM-L6-v2")
    new_feats = {
        "root_ttr": [], "corrected_ttr": [], "mattr": [], "lexical_sophistication": [],
        "complex_sentence_ratio": [], "avg_hypernym_depth": [], "topic_drift": [],
        "alliteration_ratio": [], "hedging_count": [], "emotive_count": []
    }

    for text, prompt in zip(df[text_col], df[prompt_col]):
        tokens = [t for t in word_tokenize(text) if t.isalpha()]
        new_feats["root_ttr"].append(root_ttr(tokens))
        new_feats["corrected_ttr"].append(corrected_ttr(tokens))
        new_feats["mattr"].append(mattr(tokens))
        new_feats["lexical_sophistication"].append(lexical_sophistication(tokens))
        new_feats["complex_sentence_ratio"].append(complex_sentence_ratio(text))
        new_feats["avg_hypernym_depth"].append(avg_hypernym_depth(tokens))
        new_feats["topic_drift"].append(topic_drift(text, sbert))
        new_feats["alliteration_ratio"].append(alliteration_ratio(tokens))
        new_feats["hedging_count"].append(hedging_count(tokens))
        new_feats["emotive_count"].append(emotive_count(tokens))

    return pd.concat([df, pd.DataFrame(new_feats)], axis=1)

print("Adding extra features...")
train_df = add_extra_features(train_df)
test_df = add_extra_features(test_df)
print("Extra features added!")
# Out:
# Adding extra features...
# Extra features added!
# Extra features added!

# %%
# =========================
# 1) Dimensionality Reduction Functions
# =========================

def apply_pca_reduction(train_emb, test_emb, n_components=N_COMPONENTS):
    """Apply PCA dimensionality reduction"""
    pca = PCA(n_components=n_components, random_state=SEED)
    train_reduced = pca.fit_transform(train_emb)
    test_reduced = pca.transform(test_emb)
    explained_var = pca.explained_variance_ratio_.sum()
    print(f"[PCA] explained_variance_sum = {explained_var:.4f}")
    return train_reduced, test_reduced, explained_var

def apply_svd_reduction(train_emb, test_emb, n_components=N_COMPONENTS):
    """Apply SVD dimensionality reduction"""
    svd = TruncatedSVD(n_components=n_components, random_state=SEED)
    train_reduced = svd.fit_transform(train_emb)
    test_reduced = svd.transform(test_emb)
    explained_var = svd.explained_variance_ratio_.sum()
    print(f"[SVD] explained_variance_sum = {explained_var:.4f}")
    return train_reduced, test_reduced, explained_var

def prepare_dataset(train_df, test_df, train_emb_reduced, test_emb_reduced, method_name="emb"):
    """Prepare dataset with reduced embeddings"""
    y = train_df[TARGET_COLS].copy()
    drop_cols = ["prompt","essay","essay_clean","prompt_clean","merged_text"] + TARGET_COLS
    
    X_train_core = train_df.drop(columns=drop_cols, errors="ignore").reset_index(drop=True)
    X_test_core = test_df.drop(columns=drop_cols, errors="ignore").reset_index(drop=True)
    
    train_emb_df = pd.DataFrame(train_emb_reduced, columns=[f"{method_name}_{i}" for i in range(N_COMPONENTS)])
    test_emb_df = pd.DataFrame(test_emb_reduced, columns=[f"{method_name}_{i}" for i in range(N_COMPONENTS)])
    
    train_combined = pd.concat([X_train_core, train_emb_df], axis=1)
    test_combined = pd.concat([X_test_core, test_emb_df], axis=1)
    
    X_mat = train_combined.values.astype(np.float32)
    Y_mat = y.values.astype(np.float32)
    X_test = test_combined.values.astype(np.float32)
    
    return X_mat, Y_mat, X_test

print("Dimensionality reduction functions ready!")
# Out:
# Dimensionality reduction functions ready!

# %%
# =========================
# 2) Load anchors and utility functions
# =========================

def _read_pred_vec(path: str, n_expected_rows: int = None) -> np.ndarray:
    df = pd.read_csv(path)
    drop_unnamed = [c for c in df.columns if str(c).startswith("Unnamed")]
    if drop_unnamed:
        df = df.drop(columns=drop_unnamed)
    cols = [c for c in TARGET_COLS if c in df.columns]
    if len(cols) == 4:
        df = df[cols]
    else:
        df = df.iloc[:, -4:]
        df.columns = TARGET_COLS
    
    # Only validate row count if n_expected_rows is provided
    if n_expected_rows is not None and len(df) != n_expected_rows:
        raise ValueError(f"{os.path.basename(path)} rows={len(df)} != expected {n_expected_rows}")
    
    return df.values.astype(np.float32).ravel()

def load_anchor_submissions(anchor_dir=ANCHOR_DIR, n_expected_rows=None):
    anchors = []
    for p in sorted(glob.glob(os.path.join(anchor_dir, "*.csv"))):
        m = re.match(r"(\d+)\.csv$", os.path.basename(p))
        if not m:
            continue
        lb = float(m.group(1)) / 100.0
        try:
            vec = _read_pred_vec(p, n_expected_rows)  # Pass through the expected rows
            anchors.append({"name": os.path.basename(p), "lb": lb, "vec": vec})
        except Exception as e:
            print(f"Skipping {p}: {e}")
    
    if len(anchors) < 3:
        print(f"Found only {len(anchors)} valid anchors, need at least 3")
        return []  # Return empty list instead of raising error
    
    return anchors

def mean_rmse_across_targets(y_true, y_pred):
    rmses = []
    for i in range(y_true.shape[1]):
        m = ~np.isnan(y_true[:, i])
        if m.any():
            rmses.append(np.sqrt(mean_squared_error(y_true[m, i], y_pred[m, i])))
    return float(np.mean(rmses)) if rmses else float("inf")

def predict_lb_from_anchors(test_vec: np.ndarray, anchors, temp: float, k: int):
    tvn = norm(test_vec) + 1e-12
    sims = []
    for a in anchors:
        avn = norm(a["vec"]) + 1e-12
        sims.append(float(np.dot(test_vec, a["vec"]) / (tvn * avn)))
    sims = np.array(sims, dtype=np.float32)
    idx = np.argsort(-sims)[:min(k, len(sims))]
    sims_k = sims[idx]
    lbs_k = np.array([anchors[i]["lb"] for i in idx], dtype=np.float32)
    w = np.exp(sims_k * temp); w /= w.sum()
    pred_lb = float((w * lbs_k).sum())
    top_info = list(zip([anchors[i]["name"] for i in idx], sims_k, lbs_k))
    return pred_lb, top_info

# Load anchors without row validation initially
print("Loading anchors...")
ANCHORS = load_anchor_submissions()
if ANCHORS:
    print(f"✅ Loaded {len(ANCHORS)} anchors successfully")
    for a in ANCHORS[:3]:  # Show first 3
        print(f"  - {a['name']}: LB={a['lb']:.3f}, vec_len={len(a['vec'])}")
else:
    print("⚠️ No valid anchors loaded - will use validation RMSE for optimization")
# Out:
# Loading anchors...
# ✅ Loaded 6 anchors successfully
#   - 11.csv: LB=0.110, vec_len=1892
#   - 15.csv: LB=0.150, vec_len=1892
#   - 17.csv: LB=0.170, vec_len=1892

# %%
# =========================
# 3) Training and Optuna functions  
# =========================
from catboost import CatBoostRegressor, Pool
import optuna

BASE_PARAMS_GPU = dict(
    loss_function="MultiRMSE",
    eval_metric="MultiRMSE",
    task_type="GPU",
    devices="0",
    iterations=2000,
    learning_rate=0.05,
    depth=8,
    l2_leaf_reg=3.0,
    bootstrap_type="Bayesian",
    bagging_temperature=1.0,
    border_count=128,
    min_data_in_leaf=5,
    random_seed=SEED,
    use_best_model=True,
    verbose=False,
)

def train_val_and_test_once(params, X_tr, Y_tr, X_va, Y_va, X_test, es_rounds=200, gpu=True):
    base = BASE_PARAMS_GPU.copy() if gpu else {**BASE_PARAMS_GPU, "task_type": "CPU"}
    m = CatBoostRegressor(**{**base, **params})
    tr_pool = Pool(X_tr, label=Y_tr)
    va_pool = Pool(X_va, label=Y_va)
    m.fit(tr_pool, eval_set=va_pool, early_stopping_rounds=es_rounds, use_best_model=True)
    va_pred = m.predict(X_va)
    val_rmse = mean_rmse_across_targets(Y_va, va_pred)
    test_pred = m.predict(X_test).astype(np.float32).ravel()
    return val_rmse, test_pred

def tune_with_optuna(X_tr, Y_tr, X_va, Y_va, X_test, n_trials=OPTUNA_TRIALS, use_anchors=True):
    """Run Optuna hyperparameter tuning"""
    study = optuna.create_study(direction="minimize")
    
    # Validate anchor compatibility once
    anchors_valid = False
    if use_anchors and ANCHORS:
        # Get expected length from a test prediction
        test_params = {"iterations": 100, "depth": 6, "learning_rate": 0.1}
        try:
            _, test_vec = train_val_and_test_once(test_params, X_tr[:100], Y_tr[:100], 
                                                X_va[:50], Y_va[:50], X_test, gpu=True)
            expected_len = len(test_vec)
            valid_anchors = [a for a in ANCHORS if len(a["vec"]) == expected_len]
            if len(valid_anchors) >= 3:
                anchors_valid = True
                print(f"✅ Found {len(valid_anchors)} compatible anchors (vec_len={expected_len})")
            else:
                print(f"⚠️ Only {len(valid_anchors)} anchors match expected length {expected_len}")
        except Exception as e:
            print(f"⚠️ Anchor validation failed: {e}")
    
    def objective(trial: optuna.Trial):
        params = {
            "iterations": trial.suggest_int("iterations", 800, 3000),
            "depth": trial.suggest_int("depth", 4, 10),
            "learning_rate": trial.suggest_float("learning_rate", 1e-3, 0.2, log=True),
            "l2_leaf_reg": trial.suggest_float("l2_leaf_reg", 1e-2, 30.0, log=True),
            "bagging_temperature": trial.suggest_float("bagging_temperature", 0.1, 2.0),
            "boosting_type": "Plain",
            "bootstrap_type": "Poisson",
            "loss_function": "MultiRMSE",
        }
        
        try:
            val_rmse, test_vec = train_val_and_test_once(params, X_tr, Y_tr, X_va, Y_va, X_test, gpu=True)
        except Exception as e:
            print(f"[GPU failed, falling back to CPU]: {e}")
            val_rmse, test_vec = train_val_and_test_once(params, X_tr, Y_tr, X_va, Y_va, X_test, gpu=False)
        
        trial.set_user_attr("val_rmse", float(val_rmse))
        
        # Use anchor-based objective if available and compatible
        if anchors_valid:
            try:
                pred_lb, top = predict_lb_from_anchors(test_vec, valid_anchors, temp=TEMP_SOFTMAX, k=TOPK_ANCHORS)
                trial.set_user_attr("anchor_similar", top)
                trial.set_user_attr("pred_lb", float(pred_lb))
                return float(pred_lb)
            except Exception as e:
                print(f"Anchor prediction failed: {e}")
                return float(val_rmse)
        else:
            return float(val_rmse)
    
    print(f"🚀 Starting optimization with {'anchor-based' if anchors_valid else 'RMSE-based'} objective")
    study.optimize(objective, n_trials=n_trials, show_progress_bar=True)
    return study

print("Training functions ready!")
# Out:
# Training functions ready!

# %%
# =========================
# 4) Multi-seed training function
# =========================

def train_multiple_seeds(X_mat, Y_mat, X_test, best_params, method_name, n_seeds=N_SEEDS, use_gpu_final=False):
    """Train model with multiple seeds and return predictions"""
    predictions = []
    seeds = [42, 1, 26, 5, 2005][:n_seeds]  # Updated seeds
    
    print(f"\n[{method_name}] Training with {n_seeds} seeds...")
    
    for i, seed in enumerate(seeds):
        print(f"  Seed {i+1}/{n_seeds}: {seed}")
        
        if use_gpu_final:
            # GPU-compatible final parameters
            final_params = {
                "loss_function": "MultiRMSE",  # GPU compatible
                "eval_metric": "MultiRMSE",
                "task_type": "GPU",
                "devices": "0",
                "iterations": best_params.get("iterations", 2000),
                "learning_rate": best_params.get("learning_rate", 0.05),
                "depth": best_params.get("depth", 8),
                "l2_leaf_reg": best_params.get("l2_leaf_reg", 3.0),
                "bootstrap_type": "Poisson",  # GPU safe
                "bagging_temperature": best_params.get("bagging_temperature", 1.0),
                "border_count": 128,
                "min_data_in_leaf": 5,
                "random_seed": seed,
                "use_best_model": False,
                "verbose": False,
            }
        else:
            # CPU-optimized final parameters with advanced features
            final_params = {
                "loss_function": "MultiRMSEWithMissingValues",
                "eval_metric": "MultiRMSEWithMissingValues", 
                "task_type": "CPU",
                "iterations": best_params.get("iterations", 2000),
                "learning_rate": best_params.get("learning_rate", 0.05),
                "depth": best_params.get("depth", 8),
                "l2_leaf_reg": best_params.get("l2_leaf_reg", 3.0),
                "rsm": 0.93,  # CPU-only parameter
                "grow_policy": "SymmetricTree",  # CPU-only parameter
                "bootstrap_type": "Bayesian",
                "bagging_temperature": best_params.get("bagging_temperature", 1.0),
                "border_count": 128,
                "feature_border_type": "GreedyLogSum",  # CPU-only parameter
                "min_data_in_leaf": 5,
                "random_seed": seed,
                "use_best_model": False,
                "verbose": False,
            }
        
        try:
            model = CatBoostRegressor(**final_params)
            model.fit(Pool(X_mat, label=Y_mat))
            pred = model.predict(X_test)
            predictions.append(pred)
            device_used = "GPU" if use_gpu_final else "CPU"
            print(f"    ✅ Seed {seed} completed on {device_used}")
        except Exception as e:
            if use_gpu_final:
                print(f"    ⚠️ GPU failed for seed {seed}, falling back to CPU: {e}")
                # Fallback to CPU parameters
                cpu_params = {
                    "loss_function": "MultiRMSEWithMissingValues",
                    "eval_metric": "MultiRMSEWithMissingValues", 
                    "task_type": "CPU",
                    "iterations": best_params.get("iterations", 2000),
                    "learning_rate": best_params.get("learning_rate", 0.05),
                    "depth": best_params.get("depth", 8),
                    "l2_leaf_reg": best_params.get("l2_leaf_reg", 3.0),
                    "rsm": 0.93,
                    "grow_policy": "SymmetricTree",
                    "bootstrap_type": "Bayesian",
                    "bagging_temperature": best_params.get("bagging_temperature", 1.0),
                    "border_count": 128,
                    "feature_border_type": "GreedyLogSum",
                    "min_data_in_leaf": 5,
                    "random_seed": seed,
                    "use_best_model": False,
                    "verbose": False,
                }
                model = CatBoostRegressor(**cpu_params)
                model.fit(Pool(X_mat, label=Y_mat))
                pred = model.predict(X_test)
                predictions.append(pred)
                print(f"    ✅ Seed {seed} completed on CPU (fallback)")
            else:
                print(f"    ❌ CPU training failed for seed {seed}: {e}")
                raise e
    
    # Average predictions across seeds
    avg_pred = np.mean(predictions, axis=0)
    
    # Save individual seed predictions
    ts = int(time.time())
    for i, (pred, seed) in enumerate(zip(predictions, seeds)):
        pred_df = pd.DataFrame(pred, columns=TARGET_COLS)
        pred_df["ID"] = range(1, len(pred) + 1)
        pred_path = f"{method_name}_seed{seed}_{ts}.csv"
        pred_df.to_csv(pred_path, index=False)
        print(f"    Saved: {pred_path}")
    
    # Save averaged prediction
    avg_df = pd.DataFrame(avg_pred, columns=TARGET_COLS)
    avg_df["ID"] = range(1, len(avg_pred) + 1)
    avg_path = f"{method_name}_averaged_{ts}.csv"
    avg_df.to_csv(avg_path, index=False)
    print(f"  Saved averaged: {avg_path}")
    
    return avg_pred, predictions

print("Multi-seed training function ready!")
# Out:
# Multi-seed training function ready!

# %%
# =========================
# 5) Main Pipeline Execution
# =========================

print("="*60)
print("STARTING PCA vs SVD ENSEMBLE PIPELINE")
print("="*60)

# Prepare train/val split (reuse same split for both methods)
y = train_df[TARGET_COLS].copy()
mask_cc = ~np.isnan(y.values).any(axis=1)  # Complete cases only for Optuna (GPU requires no missing values)

results = {}

# ===== PCA PIPELINE =====
print("\n" + "="*40)
print("PCA PIPELINE")
print("="*40)

print("Applying PCA reduction...")
train_pca, test_pca, pca_var = apply_pca_reduction(train_emb, test_emb)
X_mat_pca, Y_mat_pca, X_test_pca = prepare_dataset(train_df, test_df, train_pca, test_pca, "pca")

print(f"PCA dataset shapes: X={X_mat_pca.shape}, Y={Y_mat_pca.shape}, X_test={X_test_pca.shape}")
print(f"Complete cases for Optuna: {mask_cc.sum()}/{len(mask_cc)} ({mask_cc.mean()*100:.1f}%)")

# Prepare consistent train/val split (complete cases only for GPU Optuna)
X_cc_pca = X_mat_pca[mask_cc]
Y_cc_pca = Y_mat_pca[mask_cc]
X_tr_pca, X_va_pca, Y_tr_pca, Y_va_pca = train_test_split(
    X_cc_pca, Y_cc_pca, test_size=VAL_SIZE, random_state=SEED, shuffle=True
)

print("Running PCA Optuna tuning...")
study_pca = tune_with_optuna(X_tr_pca, Y_tr_pca, X_va_pca, Y_va_pca, X_test_pca)
print(f"PCA Best objective: {study_pca.best_value:.6f}")
print(f"PCA Best params: {study_pca.best_trial.params}")

# Train PCA with multiple seeds on FULL dataset (CPU can handle missing values)
print("Training PCA on full dataset (including missing target values)...")
pca_pred, pca_seeds = train_multiple_seeds(X_mat_pca, Y_mat_pca, X_test_pca, 
                                          study_pca.best_trial.params, "pca", 
                                          use_gpu_final=False)  # CPU uses MultiRMSEWithMissingValues

results['pca'] = {
    'predictions': pca_pred,
    'seed_predictions': pca_seeds,
    'best_params': study_pca.best_trial.params,
    'best_score': study_pca.best_value,
    'explained_variance': pca_var
}
# Out:
# ============================================================
# STARTING PCA vs SVD ENSEMBLE PIPELINE
# ============================================================
#
# ========================================
# PCA PIPELINE
# ========================================
# Applying PCA reduction...
# [I 2025-08-12 20:51:19,482] A new study created in memory with name: no-name-6373c256-1160-4018-94a3-a68abab0fa06
# [PCA] explained_variance_sum = 0.9116
# PCA dataset shapes: X=(9912, 321), Y=(9912, 4), X_test=(473, 321)
# Complete cases for Optuna: 8866/9912 (89.4%)
# Running PCA Optuna tuning...
# ✅ Found 6 compatible anchors (vec_len=1892)
# 🚀 Starting optimization with anchor-based objective
# ✅ Found 6 compatible anchors (vec_len=1892)
# 🚀 Starting optimization with anchor-based objective
#   0%|          | 0/200 [00:00<?, ?it/s]
# [I 2025-08-12 20:51:40,835] Trial 0 finished with value: 0.4970618784427643 and parameters: {'iterations': 2375, 'depth': 7, 'learning_rate': 0.008652485177391358, 'l2_leaf_reg': 0.07127734417018772, 'bagging_temperature': 1.416541673530918}. Best is trial 0 with value: 0.4970618784427643.
# [I 2025-08-12 20:53:16,419] Trial 1 finished with value: 0.4975072741508484 and parameters: {'iterations': 2090, 'depth': 10, 'learning_rate': 0.0038460940471333476, 'l2_leaf_reg': 0.14910853076146235, 'bagging_temperature': 1.8435787559880488}. Best is trial 0 with value: 0.4970618784427643.
# [I 2025-08-12 20:53:16,419] Trial 1 finished with value: 0.4975072741508484 and parameters: {'iterations': 2090, 'depth': 10, 'learning_rate': 0.0038460940471333476, 'l2_leaf_reg': 0.14910853076146235, 'bagging_temperature': 1.8435787559880488}. Best is trial 0 with value: 0.4970618784427643.
# [I 2025-08-12 20:53:41,169] Trial 2 finished with value: 0.4977587163448334 and parameters: {'iterations': 878, 'depth': 9, 'learning_rate': 0.010331108542011799, 'l2_leaf_reg': 0.011291851933865801, 'bagging_temperature': 1.6194415293972702}. Best is trial 0 with value: 0.4970618784427643.
# [I 2025-08-12 20:53:41,169] Trial 2 finished with value: 0.4977587163448334 and parameters: {'iterations': 878, 'depth': 9, 'learning_rate': 0.010331108542011799, 'l2_leaf_reg': 0.011291851933865801, 'bagging_temperature': 1.6194415293972702}. Best is trial 0 with value: 0.4970618784427643.
# [I 2025-08-12 20:53:44,505] Trial 3 finished with value: 0.49846944212913513 and parameters: {'iterations': 2326, 'depth': 4, 'learning_rate': 0.04240796967665256, 'l2_leaf_reg': 0.07377268910247951, 'bagging_temperature': 0.5200472981703067}. Best is trial 0 with value: 0.4970618784427643.
# [I 2025-08-12 20:53:44,505] Trial 3 finished with value: 0.49846944212913513 and parameters: {'iterations': 2326, 'depth': 4, 'learning_rate': 0.04240796967665256, 'l2_leaf_reg': 0.07377268910247951, 'bagging_temperature': 0.5200472981703067}. Best is trial 0 with value: 0.4970618784427643.
# [I 2025-08-12 20:53:49,454] Trial 4 finished with value: 0.49995550513267517 and parameters: {'iterations': 981, 'depth': 8, 'learning_rate': 0.14455396301660525, 'l2_leaf_reg': 9.508098248218808, 'bagging_temperature': 1.5194564623721785}. Best is trial 0 with value: 0.4970618784427643.
# [I 2025-08-12 20:53:49,454] Trial 4 finished with value: 0.49995550513267517 and parameters: {'iterations': 981, 'depth': 8, 'learning_rate': 0.14455396301660525, 'l2_leaf_reg': 9.508098248218808, 'bagging_temperature': 1.5194564623721785}. Best is trial 0 with value: 0.4970618784427643.
# [I 2025-08-12 20:54:09,952] Trial 5 finished with value: 0.5042600035667419 and parameters: {'iterations': 2256, 'depth': 7, 'learning_rate': 0.002003906754858003, 'l2_leaf_reg': 1.4040069621716726, 'bagging_temperature': 0.9096791991616565}. Best is trial 0 with value: 0.4970618784427643.
# [I 2025-08-12 20:54:09,952] Trial 5 finished with value: 0.5042600035667419 and parameters: {'iterations': 2256, 'depth': 7, 'learning_rate': 0.002003906754858003, 'l2_leaf_reg': 1.4040069621716726, 'bagging_temperature': 0.9096791991616565}. Best is trial 0 with value: 0.4970618784427643.
# [I 2025-08-12 20:55:45,087] Trial 6 finished with value: 0.5043431520462036 and parameters: {'iterations': 1840, 'depth': 10, 'learning_rate': 0.0010547533156070104, 'l2_leaf_reg': 0.29441359077909457, 'bagging_temperature': 1.78564186674166}. Best is trial 0 with value: 0.4970618784427643.
# [I 2025-08-12 20:55:45,087] Trial 6 finished with value: 0.5043431520462036 and parameters: {'iterations': 1840, 'depth': 10, 'learning_rate': 0.0010547533156070104, 'l2_leaf_reg': 0.29441359077909457, 'bagging_temperature': 1.78564186674166}. Best is trial 0 with value: 0.4970618784427643.
# [I 2025-08-12 20:56:27,770] Trial 7 finished with value: 0.5042468905448914 and parameters: {'iterations': 2682, 'depth': 8, 'learning_rate': 0.001023286517259543, 'l2_leaf_reg': 0.02083589004519606, 'bagging_temperature': 0.7155659402619224}. Best is trial 0 with value: 0.4970618784427643.
# [I 2025-08-12 20:56:27,770] Trial 7 finished with value: 0.5042468905448914 and parameters: {'iterations': 2682, 'depth': 8, 'learning_rate': 0.001023286517259543, 'l2_leaf_reg': 0.02083589004519606, 'bagging_temperature': 0.7155659402619224}. Best is trial 0 with value: 0.4970618784427643.
# [I 2025-08-12 20:56:31,767] Trial 8 finished with value: 0.4981609284877777 and parameters: {'iterations': 1457, 'depth': 5, 'learning_rate': 0.05509045796055323, 'l2_leaf_reg': 8.257415307947474, 'bagging_temperature': 1.910386085101818}. Best is trial 0 with value: 0.4970618784427643.
# [I 2025-08-12 20:56:31,767] Trial 8 finished with value: 0.4981609284877777 and parameters: {'iterations': 1457, 'depth': 5, 'learning_rate': 0.05509045796055323, 'l2_leaf_reg': 8.257415307947474, 'bagging_temperature': 1.910386085101818}. Best is trial 0 with value: 0.4970618784427643.
# [I 2025-08-12 20:56:38,439] Trial 9 finished with value: 0.5063782334327698 and parameters: {'iterations': 1892, 'depth': 5, 'learning_rate': 0.0013277276567555802, 'l2_leaf_reg': 0.12929378752859966, 'bagging_temperature': 1.361789823914792}. Best is trial 0 with value: 0.4970618784427643.
# [I 2025-08-12 20:56:38,439] Trial 9 finished with value: 0.5063782334327698 and parameters: {'iterations': 1892, 'depth': 5, 'learning_rate': 0.0013277276567555802, 'l2_leaf_reg': 0.12929378752859966, 'bagging_temperature': 1.361789823914792}. Best is trial 0 with value: 0.4970618784427643.
# [I 2025-08-12 20:56:53,798] Trial 10 finished with value: 0.4983901083469391 and parameters: {'iterations': 2908, 'depth': 6, 'learning_rate': 0.009709029992013606, 'l2_leaf_reg': 1.213365209210747, 'bagging_temperature': 1.1840615248165898}. Best is trial 0 with value: 0.4970618784427643.
# [I 2025-08-12 20:56:53,798] Trial 10 finished with value: 0.4983901083469391 and parameters: {'iterations': 2908, 'depth': 6, 'learning_rate': 0.009709029992013606, 'l2_leaf_reg': 1.213365209210747, 'bagging_temperature': 1.1840615248165898}. Best is trial 0 with value: 0.4970618784427643.
# [I 2025-08-12 20:58:26,237] Trial 11 finished with value: 0.49688446521759033 and parameters: {'iterations': 2398, 'depth': 10, 'learning_rate': 0.004198678035841851, 'l2_leaf_reg': 0.05536421018163228, 'bagging_temperature': 1.8980303695129512}. Best is trial 11 with value: 0.49688446521759033.
# [I 2025-08-12 20:58:26,237] Trial 11 finished with value: 0.49688446521759033 and parameters: {'iterations': 2398, 'depth': 10, 'learning_rate': 0.004198678035841851, 'l2_leaf_reg': 0.05536421018163228, 'bagging_temperature': 1.8980303695129512}. Best is trial 11 with value: 0.49688446521759033.
# [I 2025-08-12 20:58:50,029] Trial 12 finished with value: 0.4986634850502014 and parameters: {'iterations': 2640, 'depth': 7, 'learning_rate': 0.0053422219920923435, 'l2_leaf_reg': 0.035848954159856436, 'bagging_temperature': 0.13587755379718658}. Best is trial 11 with value: 0.49688446521759033.
# [I 2025-08-12 20:58:50,029] Trial 12 finished with value: 0.4986634850502014 and parameters: {'iterations': 2640, 'depth': 7, 'learning_rate': 0.0053422219920923435, 'l2_leaf_reg': 0.035848954159856436, 'bagging_temperature': 0.13587755379718658}. Best is trial 11 with value: 0.49688446521759033.
# [I 2025-08-12 20:59:03,462] Trial 13 finished with value: 0.49545711278915405 and parameters: {'iterations': 2471, 'depth': 8, 'learning_rate': 0.025985242865756618, 'l2_leaf_reg': 0.0452470320672641, 'bagging_temperature': 1.2872972993582112}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 20:59:03,462] Trial 13 finished with value: 0.49545711278915405 and parameters: {'iterations': 2471, 'depth': 8, 'learning_rate': 0.025985242865756618, 'l2_leaf_reg': 0.0452470320672641, 'bagging_temperature': 1.2872972993582112}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 20:59:18,562] Trial 14 finished with value: 0.4978339374065399 and parameters: {'iterations': 2982, 'depth': 9, 'learning_rate': 0.02818032567518422, 'l2_leaf_reg': 0.5132198447507358, 'bagging_temperature': 1.13361163222585}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 20:59:18,562] Trial 14 finished with value: 0.4978339374065399 and parameters: {'iterations': 2982, 'depth': 9, 'learning_rate': 0.02818032567518422, 'l2_leaf_reg': 0.5132198447507358, 'bagging_temperature': 1.13361163222585}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 20:59:32,543] Trial 15 finished with value: 0.4977687895298004 and parameters: {'iterations': 1558, 'depth': 9, 'learning_rate': 0.026761026397362067, 'l2_leaf_reg': 0.03164471768885999, 'bagging_temperature': 0.9052645331689355}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 20:59:32,543] Trial 15 finished with value: 0.4977687895298004 and parameters: {'iterations': 1558, 'depth': 9, 'learning_rate': 0.026761026397362067, 'l2_leaf_reg': 0.03164471768885999, 'bagging_temperature': 0.9052645331689355}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:01:10,504] Trial 16 finished with value: 0.4972974359989166 and parameters: {'iterations': 2560, 'depth': 10, 'learning_rate': 0.003691889793805681, 'l2_leaf_reg': 0.011704928518068937, 'bagging_temperature': 1.9779929338221311}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:01:10,504] Trial 16 finished with value: 0.4972974359989166 and parameters: {'iterations': 2560, 'depth': 10, 'learning_rate': 0.003691889793805681, 'l2_leaf_reg': 0.011704928518068937, 'bagging_temperature': 1.9779929338221311}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:01:14,566] Trial 17 finished with value: 0.5013612508773804 and parameters: {'iterations': 2059, 'depth': 8, 'learning_rate': 0.15365197475463582, 'l2_leaf_reg': 2.416682099916243, 'bagging_temperature': 1.6659408211293871}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:01:14,566] Trial 17 finished with value: 0.5013612508773804 and parameters: {'iterations': 2059, 'depth': 8, 'learning_rate': 0.15365197475463582, 'l2_leaf_reg': 2.416682099916243, 'bagging_temperature': 1.6659408211293871}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:01:33,002] Trial 18 finished with value: 0.4983570873737335 and parameters: {'iterations': 2503, 'depth': 9, 'learning_rate': 0.0175840831120169, 'l2_leaf_reg': 0.26457435094817344, 'bagging_temperature': 1.30547693927073}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:01:33,002] Trial 18 finished with value: 0.4983570873737335 and parameters: {'iterations': 2503, 'depth': 9, 'learning_rate': 0.0175840831120169, 'l2_leaf_reg': 0.26457435094817344, 'bagging_temperature': 1.30547693927073}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:01:42,005] Trial 19 finished with value: 0.507893443107605 and parameters: {'iterations': 1661, 'depth': 6, 'learning_rate': 0.0021599605812992143, 'l2_leaf_reg': 25.668206963460015, 'bagging_temperature': 0.43354742779483946}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:01:42,005] Trial 19 finished with value: 0.507893443107605 and parameters: {'iterations': 1661, 'depth': 6, 'learning_rate': 0.0021599605812992143, 'l2_leaf_reg': 25.668206963460015, 'bagging_temperature': 0.43354742779483946}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:01:46,554] Trial 20 finished with value: 0.5001329779624939 and parameters: {'iterations': 2787, 'depth': 8, 'learning_rate': 0.08606035260584023, 'l2_leaf_reg': 0.0558504254674751, 'bagging_temperature': 1.6943965277582664}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:01:46,554] Trial 20 finished with value: 0.5001329779624939 and parameters: {'iterations': 2787, 'depth': 8, 'learning_rate': 0.08606035260584023, 'l2_leaf_reg': 0.0558504254674751, 'bagging_temperature': 1.6943965277582664}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:02:08,182] Trial 21 finished with value: 0.49798524379730225 and parameters: {'iterations': 2397, 'depth': 7, 'learning_rate': 0.006788582760703394, 'l2_leaf_reg': 0.09628097392406688, 'bagging_temperature': 1.3986678370609804}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:02:08,182] Trial 21 finished with value: 0.49798524379730225 and parameters: {'iterations': 2397, 'depth': 7, 'learning_rate': 0.006788582760703394, 'l2_leaf_reg': 0.09628097392406688, 'bagging_temperature': 1.3986678370609804}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:02:16,455] Trial 22 finished with value: 0.4983609616756439 and parameters: {'iterations': 2240, 'depth': 6, 'learning_rate': 0.016008715530184132, 'l2_leaf_reg': 0.02601409563976228, 'bagging_temperature': 1.481629098898782}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:02:16,455] Trial 22 finished with value: 0.4983609616756439 and parameters: {'iterations': 2240, 'depth': 6, 'learning_rate': 0.016008715530184132, 'l2_leaf_reg': 0.02601409563976228, 'bagging_temperature': 1.481629098898782}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:02:35,349] Trial 23 finished with value: 0.497166246175766 and parameters: {'iterations': 2098, 'depth': 7, 'learning_rate': 0.008917803977906164, 'l2_leaf_reg': 0.22495799064915775, 'bagging_temperature': 1.0504907380888084}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:02:35,349] Trial 23 finished with value: 0.497166246175766 and parameters: {'iterations': 2098, 'depth': 7, 'learning_rate': 0.008917803977906164, 'l2_leaf_reg': 0.22495799064915775, 'bagging_temperature': 1.0504907380888084}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:02:45,748] Trial 24 finished with value: 0.4981367290019989 and parameters: {'iterations': 2437, 'depth': 8, 'learning_rate': 0.022808706709997833, 'l2_leaf_reg': 0.05873507524088917, 'bagging_temperature': 1.250501463283897}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:02:45,748] Trial 24 finished with value: 0.4981367290019989 and parameters: {'iterations': 2437, 'depth': 8, 'learning_rate': 0.022808706709997833, 'l2_leaf_reg': 0.05873507524088917, 'bagging_temperature': 1.250501463283897}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:04:18,874] Trial 25 finished with value: 0.49757301807403564 and parameters: {'iterations': 2792, 'depth': 10, 'learning_rate': 0.0045064439977011, 'l2_leaf_reg': 0.5480569896939969, 'bagging_temperature': 1.5402009945866775}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:04:18,874] Trial 25 finished with value: 0.49757301807403564 and parameters: {'iterations': 2792, 'depth': 10, 'learning_rate': 0.0045064439977011, 'l2_leaf_reg': 0.5480569896939969, 'bagging_temperature': 1.5402009945866775}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:04:31,254] Trial 26 finished with value: 0.5036219954490662 and parameters: {'iterations': 2255, 'depth': 6, 'learning_rate': 0.0025130000466354126, 'l2_leaf_reg': 0.050948272627589, 'bagging_temperature': 0.9628307448513433}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:04:31,254] Trial 26 finished with value: 0.5036219954490662 and parameters: {'iterations': 2255, 'depth': 6, 'learning_rate': 0.0025130000466354126, 'l2_leaf_reg': 0.050948272627589, 'bagging_temperature': 0.9628307448513433}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:04:54,346] Trial 27 finished with value: 0.4978988766670227 and parameters: {'iterations': 1760, 'depth': 9, 'learning_rate': 0.01318531274573047, 'l2_leaf_reg': 0.020207189569092156, 'bagging_temperature': 1.7819631340040196}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:04:54,346] Trial 27 finished with value: 0.4978988766670227 and parameters: {'iterations': 1760, 'depth': 9, 'learning_rate': 0.01318531274573047, 'l2_leaf_reg': 0.020207189569092156, 'bagging_temperature': 1.7819631340040196}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:05:00,368] Trial 28 finished with value: 0.4968297779560089 and parameters: {'iterations': 1138, 'depth': 7, 'learning_rate': 0.041851100744513044, 'l2_leaf_reg': 0.164088428230406, 'bagging_temperature': 0.7954898755804168}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:05:00,368] Trial 28 finished with value: 0.4968297779560089 and parameters: {'iterations': 1138, 'depth': 7, 'learning_rate': 0.041851100744513044, 'l2_leaf_reg': 0.164088428230406, 'bagging_temperature': 0.7954898755804168}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:05:05,244] Trial 29 finished with value: 0.49836254119873047 and parameters: {'iterations': 1294, 'depth': 7, 'learning_rate': 0.047050463542703244, 'l2_leaf_reg': 0.44281213017242027, 'bagging_temperature': 0.7357991698986226}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:05:05,244] Trial 29 finished with value: 0.49836254119873047 and parameters: {'iterations': 1294, 'depth': 7, 'learning_rate': 0.047050463542703244, 'l2_leaf_reg': 0.44281213017242027, 'bagging_temperature': 0.7357991698986226}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:05:07,160] Trial 30 finished with value: 0.49923479557037354 and parameters: {'iterations': 1091, 'depth': 5, 'learning_rate': 0.08621057631697374, 'l2_leaf_reg': 0.13768631042330642, 'bagging_temperature': 0.7399565547967721}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:05:07,160] Trial 30 finished with value: 0.49923479557037354 and parameters: {'iterations': 1091, 'depth': 5, 'learning_rate': 0.08621057631697374, 'l2_leaf_reg': 0.13768631042330642, 'bagging_temperature': 0.7399565547967721}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:05:14,495] Trial 31 finished with value: 0.4963013827800751 and parameters: {'iterations': 2082, 'depth': 7, 'learning_rate': 0.034225438835923695, 'l2_leaf_reg': 0.11081677584950754, 'bagging_temperature': 1.1020350715285536}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:05:14,495] Trial 31 finished with value: 0.4963013827800751 and parameters: {'iterations': 2082, 'depth': 7, 'learning_rate': 0.034225438835923695, 'l2_leaf_reg': 0.11081677584950754, 'bagging_temperature': 1.1020350715285536}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:05:21,437] Trial 32 finished with value: 0.49664345383644104 and parameters: {'iterations': 1970, 'depth': 7, 'learning_rate': 0.03568006825855922, 'l2_leaf_reg': 0.10160903810600384, 'bagging_temperature': 0.4891085387926588}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:05:21,437] Trial 32 finished with value: 0.49664345383644104 and parameters: {'iterations': 1970, 'depth': 7, 'learning_rate': 0.03568006825855922, 'l2_leaf_reg': 0.10160903810600384, 'bagging_temperature': 0.4891085387926588}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:05:28,393] Trial 33 finished with value: 0.4964391589164734 and parameters: {'iterations': 2000, 'depth': 7, 'learning_rate': 0.03652982232008941, 'l2_leaf_reg': 0.20000750559875208, 'bagging_temperature': 0.36536742950762946}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:05:28,393] Trial 33 finished with value: 0.4964391589164734 and parameters: {'iterations': 2000, 'depth': 7, 'learning_rate': 0.03652982232008941, 'l2_leaf_reg': 0.20000750559875208, 'bagging_temperature': 0.36536742950762946}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:05:36,464] Trial 34 finished with value: 0.4987146854400635 and parameters: {'iterations': 2083, 'depth': 8, 'learning_rate': 0.033515428069264545, 'l2_leaf_reg': 0.10476693967576146, 'bagging_temperature': 0.1850926125367039}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:05:36,464] Trial 34 finished with value: 0.4987146854400635 and parameters: {'iterations': 2083, 'depth': 8, 'learning_rate': 0.033515428069264545, 'l2_leaf_reg': 0.10476693967576146, 'bagging_temperature': 0.1850926125367039}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:05:39,278] Trial 35 finished with value: 0.4987224042415619 and parameters: {'iterations': 1997, 'depth': 6, 'learning_rate': 0.06644270807221679, 'l2_leaf_reg': 0.19030173955884958, 'bagging_temperature': 0.33699128453196736}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:05:39,278] Trial 35 finished with value: 0.4987224042415619 and parameters: {'iterations': 1997, 'depth': 6, 'learning_rate': 0.06644270807221679, 'l2_leaf_reg': 0.19030173955884958, 'bagging_temperature': 0.33699128453196736}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:05:51,142] Trial 36 finished with value: 0.49695128202438354 and parameters: {'iterations': 1962, 'depth': 7, 'learning_rate': 0.02031452418133546, 'l2_leaf_reg': 0.8501210749867405, 'bagging_temperature': 0.5110455789578655}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:05:51,142] Trial 36 finished with value: 0.49695128202438354 and parameters: {'iterations': 1962, 'depth': 7, 'learning_rate': 0.02031452418133546, 'l2_leaf_reg': 0.8501210749867405, 'bagging_temperature': 0.5110455789578655}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:05:56,546] Trial 37 finished with value: 0.49880874156951904 and parameters: {'iterations': 1778, 'depth': 7, 'learning_rate': 0.03461246626369174, 'l2_leaf_reg': 0.0884044230217951, 'bagging_temperature': 0.6358167816698296}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:05:56,546] Trial 37 finished with value: 0.49880874156951904 and parameters: {'iterations': 1778, 'depth': 7, 'learning_rate': 0.03461246626369174, 'l2_leaf_reg': 0.0884044230217951, 'bagging_temperature': 0.6358167816698296}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:06:01,863] Trial 38 finished with value: 0.4965299069881439 and parameters: {'iterations': 2137, 'depth': 8, 'learning_rate': 0.1050921284400339, 'l2_leaf_reg': 0.322596432182357, 'bagging_temperature': 0.3409030398288193}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:06:01,863] Trial 38 finished with value: 0.4965299069881439 and parameters: {'iterations': 2137, 'depth': 8, 'learning_rate': 0.1050921284400339, 'l2_leaf_reg': 0.322596432182357, 'bagging_temperature': 0.3409030398288193}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:06:06,533] Trial 39 finished with value: 0.4998537600040436 and parameters: {'iterations': 2235, 'depth': 8, 'learning_rate': 0.10183265054784542, 'l2_leaf_reg': 0.37422930034719337, 'bagging_temperature': 0.2684626508645284}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:06:06,533] Trial 39 finished with value: 0.4998537600040436 and parameters: {'iterations': 2235, 'depth': 8, 'learning_rate': 0.10183265054784542, 'l2_leaf_reg': 0.37422930034719337, 'bagging_temperature': 0.2684626508645284}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:06:11,471] Trial 40 finished with value: 0.4997559189796448 and parameters: {'iterations': 2208, 'depth': 8, 'learning_rate': 0.12230152706573866, 'l2_leaf_reg': 2.2852117711590907, 'bagging_temperature': 0.5996527973853661}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:06:11,471] Trial 40 finished with value: 0.4997559189796448 and parameters: {'iterations': 2208, 'depth': 8, 'learning_rate': 0.12230152706573866, 'l2_leaf_reg': 2.2852117711590907, 'bagging_temperature': 0.5996527973853661}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:06:14,454] Trial 41 finished with value: 0.4966890215873718 and parameters: {'iterations': 1916, 'depth': 7, 'learning_rate': 0.18923318664348796, 'l2_leaf_reg': 0.7046232691023971, 'bagging_temperature': 0.3795558632080529}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:06:14,454] Trial 41 finished with value: 0.4966890215873718 and parameters: {'iterations': 1916, 'depth': 7, 'learning_rate': 0.18923318664348796, 'l2_leaf_reg': 0.7046232691023971, 'bagging_temperature': 0.3795558632080529}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:06:21,738] Trial 42 finished with value: 0.49722403287887573 and parameters: {'iterations': 2152, 'depth': 8, 'learning_rate': 0.05473997833319629, 'l2_leaf_reg': 0.30934097845590636, 'bagging_temperature': 0.47557787882642844}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:06:21,738] Trial 42 finished with value: 0.49722403287887573 and parameters: {'iterations': 2152, 'depth': 8, 'learning_rate': 0.05473997833319629, 'l2_leaf_reg': 0.30934097845590636, 'bagging_temperature': 0.47557787882642844}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:06:34,534] Trial 43 finished with value: 0.49788081645965576 and parameters: {'iterations': 1659, 'depth': 7, 'learning_rate': 0.01380919087809954, 'l2_leaf_reg': 0.1813871978309964, 'bagging_temperature': 0.2327930322393607}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:06:34,534] Trial 43 finished with value: 0.49788081645965576 and parameters: {'iterations': 1659, 'depth': 7, 'learning_rate': 0.01380919087809954, 'l2_leaf_reg': 0.1813871978309964, 'bagging_temperature': 0.2327930322393607}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:06:36,900] Trial 44 finished with value: 0.49982231855392456 and parameters: {'iterations': 2326, 'depth': 6, 'learning_rate': 0.07251235198273208, 'l2_leaf_reg': 0.04065605446669655, 'bagging_temperature': 0.6036386204382209}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:06:36,900] Trial 44 finished with value: 0.49982231855392456 and parameters: {'iterations': 2326, 'depth': 6, 'learning_rate': 0.07251235198273208, 'l2_leaf_reg': 0.04065605446669655, 'bagging_temperature': 0.6036386204382209}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:06:49,813] Trial 45 finished with value: 0.4971480965614319 and parameters: {'iterations': 1838, 'depth': 9, 'learning_rate': 0.036780862137449286, 'l2_leaf_reg': 0.11922730597726049, 'bagging_temperature': 0.31109548188052366}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:06:49,813] Trial 45 finished with value: 0.4971480965614319 and parameters: {'iterations': 1838, 'depth': 9, 'learning_rate': 0.036780862137449286, 'l2_leaf_reg': 0.11922730597726049, 'bagging_temperature': 0.31109548188052366}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:07:00,167] Trial 46 finished with value: 0.4979822635650635 and parameters: {'iterations': 1998, 'depth': 8, 'learning_rate': 0.024204607046837415, 'l2_leaf_reg': 0.016518992197940185, 'bagging_temperature': 1.1297153824018549}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:07:00,167] Trial 46 finished with value: 0.4979822635650635 and parameters: {'iterations': 1998, 'depth': 8, 'learning_rate': 0.024204607046837415, 'l2_leaf_reg': 0.016518992197940185, 'bagging_temperature': 1.1297153824018549}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:07:03,795] Trial 47 finished with value: 0.4998982846736908 and parameters: {'iterations': 2125, 'depth': 7, 'learning_rate': 0.0562810919015059, 'l2_leaf_reg': 0.07666275484176598, 'bagging_temperature': 0.8313591016489779}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:07:03,795] Trial 47 finished with value: 0.4998982846736908 and parameters: {'iterations': 2125, 'depth': 7, 'learning_rate': 0.0562810919015059, 'l2_leaf_reg': 0.07666275484176598, 'bagging_temperature': 0.8313591016489779}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:07:09,995] Trial 48 finished with value: 0.5007404088973999 and parameters: {'iterations': 2588, 'depth': 4, 'learning_rate': 0.01182069055778496, 'l2_leaf_reg': 0.2891810635702349, 'bagging_temperature': 0.9920560841357025}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:07:09,995] Trial 48 finished with value: 0.5007404088973999 and parameters: {'iterations': 2588, 'depth': 4, 'learning_rate': 0.01182069055778496, 'l2_leaf_reg': 0.2891810635702349, 'bagging_temperature': 0.9920560841357025}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:07:20,198] Trial 49 finished with value: 0.4976658821105957 and parameters: {'iterations': 2346, 'depth': 8, 'learning_rate': 0.02781825966963074, 'l2_leaf_reg': 0.07308640180620271, 'bagging_temperature': 0.3932937766694101}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:07:20,198] Trial 49 finished with value: 0.4976658821105957 and parameters: {'iterations': 2346, 'depth': 8, 'learning_rate': 0.02781825966963074, 'l2_leaf_reg': 0.07308640180620271, 'bagging_temperature': 0.3932937766694101}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:07:40,883] Trial 50 finished with value: 0.49753332138061523 and parameters: {'iterations': 1394, 'depth': 9, 'learning_rate': 0.020274760931884968, 'l2_leaf_reg': 1.0316426072475862, 'bagging_temperature': 0.14297175570518192}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:07:40,883] Trial 50 finished with value: 0.49753332138061523 and parameters: {'iterations': 1394, 'depth': 9, 'learning_rate': 0.020274760931884968, 'l2_leaf_reg': 1.0316426072475862, 'bagging_temperature': 0.14297175570518192}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:07:43,821] Trial 51 finished with value: 0.49855560064315796 and parameters: {'iterations': 1931, 'depth': 7, 'learning_rate': 0.14325527798112858, 'l2_leaf_reg': 0.7407156044868882, 'bagging_temperature': 0.3869197761040512}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:07:43,821] Trial 51 finished with value: 0.49855560064315796 and parameters: {'iterations': 1931, 'depth': 7, 'learning_rate': 0.14325527798112858, 'l2_leaf_reg': 0.7407156044868882, 'bagging_temperature': 0.3869197761040512}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:07:46,351] Trial 52 finished with value: 0.5015048980712891 and parameters: {'iterations': 1871, 'depth': 7, 'learning_rate': 0.17637228301921645, 'l2_leaf_reg': 1.623308784665048, 'bagging_temperature': 0.5542221695108369}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:07:46,351] Trial 52 finished with value: 0.5015048980712891 and parameters: {'iterations': 1871, 'depth': 7, 'learning_rate': 0.17637228301921645, 'l2_leaf_reg': 1.623308784665048, 'bagging_temperature': 0.5542221695108369}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:07:48,043] Trial 53 finished with value: 0.5011193752288818 and parameters: {'iterations': 1641, 'depth': 6, 'learning_rate': 0.18568448204235422, 'l2_leaf_reg': 0.6632101318493492, 'bagging_temperature': 1.1731760754614302}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:07:48,043] Trial 53 finished with value: 0.5011193752288818 and parameters: {'iterations': 1641, 'depth': 6, 'learning_rate': 0.18568448204235422, 'l2_leaf_reg': 0.6632101318493492, 'bagging_temperature': 1.1731760754614302}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:07:50,752] Trial 54 finished with value: 0.5004627108573914 and parameters: {'iterations': 1758, 'depth': 7, 'learning_rate': 0.11682074620087912, 'l2_leaf_reg': 0.3992638733773939, 'bagging_temperature': 1.2986076821850536}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:07:50,752] Trial 54 finished with value: 0.5004627108573914 and parameters: {'iterations': 1758, 'depth': 7, 'learning_rate': 0.11682074620087912, 'l2_leaf_reg': 0.3992638733773939, 'bagging_temperature': 1.2986076821850536}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:07:58,403] Trial 55 finished with value: 0.49783074855804443 and parameters: {'iterations': 2001, 'depth': 8, 'learning_rate': 0.07196156474118907, 'l2_leaf_reg': 6.024768810013425, 'bagging_temperature': 0.23146728177052606}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:07:58,403] Trial 55 finished with value: 0.49783074855804443 and parameters: {'iterations': 2001, 'depth': 8, 'learning_rate': 0.07196156474118907, 'l2_leaf_reg': 6.024768810013425, 'bagging_temperature': 0.23146728177052606}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:08:04,098] Trial 56 finished with value: 0.49711135029792786 and parameters: {'iterations': 2175, 'depth': 7, 'learning_rate': 0.04815208512381367, 'l2_leaf_reg': 0.22642307001336262, 'bagging_temperature': 0.426182350002486}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:08:04,098] Trial 56 finished with value: 0.49711135029792786 and parameters: {'iterations': 2175, 'depth': 7, 'learning_rate': 0.04815208512381367, 'l2_leaf_reg': 0.22642307001336262, 'bagging_temperature': 0.426182350002486}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:08:14,069] Trial 57 finished with value: 0.4970856308937073 and parameters: {'iterations': 2517, 'depth': 8, 'learning_rate': 0.03155730817277495, 'l2_leaf_reg': 0.14835313971915073, 'bagging_temperature': 1.0577445049929102}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:08:14,069] Trial 57 finished with value: 0.4970856308937073 and parameters: {'iterations': 2517, 'depth': 8, 'learning_rate': 0.03155730817277495, 'l2_leaf_reg': 0.14835313971915073, 'bagging_temperature': 1.0577445049929102}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:08:18,107] Trial 58 finished with value: 0.4982120096683502 and parameters: {'iterations': 1824, 'depth': 6, 'learning_rate': 0.04167015795614314, 'l2_leaf_reg': 0.031131238353490263, 'bagging_temperature': 0.32063536161338785}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:08:18,107] Trial 58 finished with value: 0.4982120096683502 and parameters: {'iterations': 1824, 'depth': 6, 'learning_rate': 0.04167015795614314, 'l2_leaf_reg': 0.031131238353490263, 'bagging_temperature': 0.32063536161338785}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:08:21,982] Trial 59 finished with value: 0.49705973267555237 and parameters: {'iterations': 2051, 'depth': 7, 'learning_rate': 0.09217711039006882, 'l2_leaf_reg': 0.05170168602825962, 'bagging_temperature': 0.10791317865314431}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:08:21,982] Trial 59 finished with value: 0.49705973267555237 and parameters: {'iterations': 2051, 'depth': 7, 'learning_rate': 0.09217711039006882, 'l2_leaf_reg': 0.05170168602825962, 'bagging_temperature': 0.10791317865314431}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:08:33,341] Trial 60 finished with value: 0.49738842248916626 and parameters: {'iterations': 2448, 'depth': 7, 'learning_rate': 0.01716715574960916, 'l2_leaf_reg': 0.10918007729573373, 'bagging_temperature': 0.6761529277397036}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:08:33,341] Trial 60 finished with value: 0.49738842248916626 and parameters: {'iterations': 2448, 'depth': 7, 'learning_rate': 0.01716715574960916, 'l2_leaf_reg': 0.10918007729573373, 'bagging_temperature': 0.6761529277397036}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:08:39,120] Trial 61 finished with value: 0.49782025814056396 and parameters: {'iterations': 912, 'depth': 7, 'learning_rate': 0.038527137621476616, 'l2_leaf_reg': 0.16296350230023993, 'bagging_temperature': 0.8251618527189959}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:08:39,120] Trial 61 finished with value: 0.49782025814056396 and parameters: {'iterations': 912, 'depth': 7, 'learning_rate': 0.038527137621476616, 'l2_leaf_reg': 0.16296350230023993, 'bagging_temperature': 0.8251618527189959}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:08:45,192] Trial 62 finished with value: 0.4966332018375397 and parameters: {'iterations': 1096, 'depth': 6, 'learning_rate': 0.029043300426762408, 'l2_leaf_reg': 0.22397536419832687, 'bagging_temperature': 0.48070386162535156}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:08:45,192] Trial 62 finished with value: 0.4966332018375397 and parameters: {'iterations': 1096, 'depth': 6, 'learning_rate': 0.029043300426762408, 'l2_leaf_reg': 0.22397536419832687, 'bagging_temperature': 0.48070386162535156}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:08:49,895] Trial 63 finished with value: 0.49842652678489685 and parameters: {'iterations': 1521, 'depth': 5, 'learning_rate': 0.02799528912994659, 'l2_leaf_reg': 0.23275310227687537, 'bagging_temperature': 0.5265042113276539}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:08:49,895] Trial 63 finished with value: 0.49842652678489685 and parameters: {'iterations': 1521, 'depth': 5, 'learning_rate': 0.02799528912994659, 'l2_leaf_reg': 0.23275310227687537, 'bagging_temperature': 0.5265042113276539}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:08:54,503] Trial 64 finished with value: 0.49941426515579224 and parameters: {'iterations': 827, 'depth': 6, 'learning_rate': 0.022553125889467236, 'l2_leaf_reg': 0.5298623753695466, 'bagging_temperature': 0.3878855857016143}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:08:54,503] Trial 64 finished with value: 0.49941426515579224 and parameters: {'iterations': 827, 'depth': 6, 'learning_rate': 0.022553125889467236, 'l2_leaf_reg': 0.5298623753695466, 'bagging_temperature': 0.3878855857016143}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:08:57,807] Trial 65 finished with value: 0.4988357424736023 and parameters: {'iterations': 1908, 'depth': 6, 'learning_rate': 0.05347016931206763, 'l2_leaf_reg': 0.34925778537707897, 'bagging_temperature': 0.4683617436568007}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:08:57,807] Trial 65 finished with value: 0.4988357424736023 and parameters: {'iterations': 1908, 'depth': 6, 'learning_rate': 0.05347016931206763, 'l2_leaf_reg': 0.34925778537707897, 'bagging_temperature': 0.4683617436568007}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:09:01,512] Trial 66 finished with value: 0.5009320378303528 and parameters: {'iterations': 2303, 'depth': 8, 'learning_rate': 0.1995322063199989, 'l2_leaf_reg': 0.04183969870998799, 'bagging_temperature': 1.2327331584018368}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:09:01,512] Trial 66 finished with value: 0.5009320378303528 and parameters: {'iterations': 2303, 'depth': 8, 'learning_rate': 0.1995322063199989, 'l2_leaf_reg': 0.04183969870998799, 'bagging_temperature': 1.2327331584018368}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:09:02,995] Trial 67 finished with value: 0.49875879287719727 and parameters: {'iterations': 2681, 'depth': 5, 'learning_rate': 0.14843767059309299, 'l2_leaf_reg': 0.06600347821115755, 'bagging_temperature': 1.3581673331281592}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:09:02,995] Trial 67 finished with value: 0.49875879287719727 and parameters: {'iterations': 2681, 'depth': 5, 'learning_rate': 0.14843767059309299, 'l2_leaf_reg': 0.06600347821115755, 'bagging_temperature': 1.3581673331281592}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:09:14,099] Trial 68 finished with value: 0.5007800459861755 and parameters: {'iterations': 2034, 'depth': 6, 'learning_rate': 0.006625578879048073, 'l2_leaf_reg': 0.2130895463928933, 'bagging_temperature': 1.463140708256617}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:09:14,099] Trial 68 finished with value: 0.5007800459861755 and parameters: {'iterations': 2034, 'depth': 6, 'learning_rate': 0.006625578879048073, 'l2_leaf_reg': 0.2130895463928933, 'bagging_temperature': 1.463140708256617}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:09:20,118] Trial 69 finished with value: 0.49808377027511597 and parameters: {'iterations': 1694, 'depth': 8, 'learning_rate': 0.06369949912651007, 'l2_leaf_reg': 0.0942269834729567, 'bagging_temperature': 0.26551062419413174}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:09:20,118] Trial 69 finished with value: 0.49808377027511597 and parameters: {'iterations': 1694, 'depth': 8, 'learning_rate': 0.06369949912651007, 'l2_leaf_reg': 0.0942269834729567, 'bagging_temperature': 0.26551062419413174}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:09:27,174] Trial 70 finished with value: 0.49782609939575195 and parameters: {'iterations': 2774, 'depth': 7, 'learning_rate': 0.03097547587369233, 'l2_leaf_reg': 0.26071232331762223, 'bagging_temperature': 0.1948280809720889}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:09:27,174] Trial 70 finished with value: 0.49782609939575195 and parameters: {'iterations': 2774, 'depth': 7, 'learning_rate': 0.03097547587369233, 'l2_leaf_reg': 0.26071232331762223, 'bagging_temperature': 0.1948280809720889}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:09:32,966] Trial 71 finished with value: 0.497802734375 and parameters: {'iterations': 1106, 'depth': 7, 'learning_rate': 0.038595795799684654, 'l2_leaf_reg': 0.1575460317562568, 'bagging_temperature': 0.8286197109333322}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:09:32,966] Trial 71 finished with value: 0.497802734375 and parameters: {'iterations': 1106, 'depth': 7, 'learning_rate': 0.038595795799684654, 'l2_leaf_reg': 0.1575460317562568, 'bagging_temperature': 0.8286197109333322}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:09:38,394] Trial 72 finished with value: 0.4978601038455963 and parameters: {'iterations': 1339, 'depth': 7, 'learning_rate': 0.04470805871060329, 'l2_leaf_reg': 0.11878275658590323, 'bagging_temperature': 0.3610328924573039}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:09:38,394] Trial 72 finished with value: 0.4978601038455963 and parameters: {'iterations': 1339, 'depth': 7, 'learning_rate': 0.04470805871060329, 'l2_leaf_reg': 0.11878275658590323, 'bagging_temperature': 0.3610328924573039}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:09:48,397] Trial 73 finished with value: 0.498005211353302 and parameters: {'iterations': 1214, 'depth': 7, 'learning_rate': 0.019755832129010806, 'l2_leaf_reg': 0.5215110195845027, 'bagging_temperature': 0.4613540587615173}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:09:48,397] Trial 73 finished with value: 0.498005211353302 and parameters: {'iterations': 1214, 'depth': 7, 'learning_rate': 0.019755832129010806, 'l2_leaf_reg': 0.5215110195845027, 'bagging_temperature': 0.4613540587615173}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:09:55,706] Trial 74 finished with value: 0.4986419975757599 and parameters: {'iterations': 1146, 'depth': 7, 'learning_rate': 0.023764064472238847, 'l2_leaf_reg': 0.08427677200426523, 'bagging_temperature': 0.5727053101408442}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:09:55,706] Trial 74 finished with value: 0.4986419975757599 and parameters: {'iterations': 1146, 'depth': 7, 'learning_rate': 0.023764064472238847, 'l2_leaf_reg': 0.08427677200426523, 'bagging_temperature': 0.5727053101408442}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:09:57,597] Trial 75 finished with value: 0.5005067586898804 and parameters: {'iterations': 1037, 'depth': 6, 'learning_rate': 0.12773597946304033, 'l2_leaf_reg': 0.18902166714476404, 'bagging_temperature': 1.1043424125707273}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:09:57,597] Trial 75 finished with value: 0.5005067586898804 and parameters: {'iterations': 1037, 'depth': 6, 'learning_rate': 0.12773597946304033, 'l2_leaf_reg': 0.18902166714476404, 'bagging_temperature': 1.1043424125707273}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:10:05,823] Trial 76 finished with value: 0.4987636208534241 and parameters: {'iterations': 2109, 'depth': 8, 'learning_rate': 0.033060000752509776, 'l2_leaf_reg': 0.31123243276266405, 'bagging_temperature': 0.8866569566136491}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:10:05,823] Trial 76 finished with value: 0.4987636208534241 and parameters: {'iterations': 2109, 'depth': 8, 'learning_rate': 0.033060000752509776, 'l2_leaf_reg': 0.31123243276266405, 'bagging_temperature': 0.8866569566136491}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:10:26,809] Trial 77 finished with value: 0.4985009431838989 and parameters: {'iterations': 2185, 'depth': 9, 'learning_rate': 0.01536734705150581, 'l2_leaf_reg': 0.44972106908233633, 'bagging_temperature': 0.6466840959827513}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:10:26,809] Trial 77 finished with value: 0.4985009431838989 and parameters: {'iterations': 2185, 'depth': 9, 'learning_rate': 0.01536734705150581, 'l2_leaf_reg': 0.44972106908233633, 'bagging_temperature': 0.6466840959827513}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:10:30,278] Trial 78 finished with value: 0.4972974359989166 and parameters: {'iterations': 998, 'depth': 7, 'learning_rate': 0.10102561685554216, 'l2_leaf_reg': 0.13348000465685583, 'bagging_temperature': 0.9876654492514363}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:10:30,278] Trial 78 finished with value: 0.4972974359989166 and parameters: {'iterations': 998, 'depth': 7, 'learning_rate': 0.10102561685554216, 'l2_leaf_reg': 0.13348000465685583, 'bagging_temperature': 0.9876654492514363}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:10:32,218] Trial 79 finished with value: 0.4993608593940735 and parameters: {'iterations': 1953, 'depth': 4, 'learning_rate': 0.07619670302983189, 'l2_leaf_reg': 0.6860057980987516, 'bagging_temperature': 0.7690931586257486}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:10:32,218] Trial 79 finished with value: 0.4993608593940735 and parameters: {'iterations': 1953, 'depth': 4, 'learning_rate': 0.07619670302983189, 'l2_leaf_reg': 0.6860057980987516, 'bagging_temperature': 0.7690931586257486}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:10:39,486] Trial 80 finished with value: 0.4981207847595215 and parameters: {'iterations': 1597, 'depth': 8, 'learning_rate': 0.05071326551028346, 'l2_leaf_reg': 0.9897617799570274, 'bagging_temperature': 0.29069423484127604}. Best is trial 13 with value: 0.49545711278915405.
# ...
# [I 2025-08-12 21:40:33,214] Trial 175 finished with value: 0.5027397871017456 and parameters: {'iterations': 2359, 'depth': 7, 'learning_rate': 0.19945893110095309, 'l2_leaf_reg': 1.0170311324675259, 'bagging_temperature': 0.5280117354189525}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:40:46,642] Trial 176 finished with value: 0.497267484664917 and parameters: {'iterations': 2576, 'depth': 9, 'learning_rate': 0.037266664341379624, 'l2_leaf_reg': 0.5806739189937996, 'bagging_temperature': 0.5676847320784514}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:40:46,642] Trial 176 finished with value: 0.497267484664917 and parameters: {'iterations': 2576, 'depth': 9, 'learning_rate': 0.037266664341379624, 'l2_leaf_reg': 0.5806739189937996, 'bagging_temperature': 0.5676847320784514}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:41:13,953] Trial 177 finished with value: 0.49803364276885986 and parameters: {'iterations': 2251, 'depth': 10, 'learning_rate': 0.024320122053147375, 'l2_leaf_reg': 1.281496173852766, 'bagging_temperature': 0.3726095853217219}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:41:13,953] Trial 177 finished with value: 0.49803364276885986 and parameters: {'iterations': 2251, 'depth': 10, 'learning_rate': 0.024320122053147375, 'l2_leaf_reg': 1.281496173852766, 'bagging_temperature': 0.3726095853217219}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:41:19,436] Trial 178 finished with value: 0.4970937669277191 and parameters: {'iterations': 2856, 'depth': 5, 'learning_rate': 0.028042213058729924, 'l2_leaf_reg': 0.03958222181295823, 'bagging_temperature': 0.4307696410861459}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:41:19,436] Trial 178 finished with value: 0.4970937669277191 and parameters: {'iterations': 2856, 'depth': 5, 'learning_rate': 0.028042213058729924, 'l2_leaf_reg': 0.03958222181295823, 'bagging_temperature': 0.4307696410861459}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:41:29,230] Trial 179 finished with value: 0.49757352471351624 and parameters: {'iterations': 2112, 'depth': 8, 'learning_rate': 0.03168758830555243, 'l2_leaf_reg': 0.29234632079037215, 'bagging_temperature': 0.3225218636679378}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:41:29,230] Trial 179 finished with value: 0.49757352471351624 and parameters: {'iterations': 2112, 'depth': 8, 'learning_rate': 0.03168758830555243, 'l2_leaf_reg': 0.29234632079037215, 'bagging_temperature': 0.3225218636679378}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:41:40,162] Trial 180 finished with value: 0.49697113037109375 and parameters: {'iterations': 2310, 'depth': 7, 'learning_rate': 0.04083201818859947, 'l2_leaf_reg': 14.362106271018217, 'bagging_temperature': 0.5934786834343234}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:41:40,162] Trial 180 finished with value: 0.49697113037109375 and parameters: {'iterations': 2310, 'depth': 7, 'learning_rate': 0.04083201818859947, 'l2_leaf_reg': 14.362106271018217, 'bagging_temperature': 0.5934786834343234}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:41:50,046] Trial 181 finished with value: 0.49715539813041687 and parameters: {'iterations': 1886, 'depth': 7, 'learning_rate': 0.02351002302076362, 'l2_leaf_reg': 0.886125621053081, 'bagging_temperature': 0.49993017642465404}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:41:50,046] Trial 181 finished with value: 0.49715539813041687 and parameters: {'iterations': 1886, 'depth': 7, 'learning_rate': 0.02351002302076362, 'l2_leaf_reg': 0.886125621053081, 'bagging_temperature': 0.49993017642465404}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:42:00,939] Trial 182 finished with value: 0.49730515480041504 and parameters: {'iterations': 2020, 'depth': 7, 'learning_rate': 0.020948611090939283, 'l2_leaf_reg': 0.7920651516861382, 'bagging_temperature': 0.470052684268732}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:42:00,939] Trial 182 finished with value: 0.49730515480041504 and parameters: {'iterations': 2020, 'depth': 7, 'learning_rate': 0.020948611090939283, 'l2_leaf_reg': 0.7920651516861382, 'bagging_temperature': 0.470052684268732}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:42:10,687] Trial 183 finished with value: 0.498509019613266 and parameters: {'iterations': 2511, 'depth': 7, 'learning_rate': 0.01839152860344162, 'l2_leaf_reg': 0.4579630880304918, 'bagging_temperature': 0.6339847367079953}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:42:10,687] Trial 183 finished with value: 0.498509019613266 and parameters: {'iterations': 2511, 'depth': 7, 'learning_rate': 0.01839152860344162, 'l2_leaf_reg': 0.4579630880304918, 'bagging_temperature': 0.6339847367079953}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:42:18,945] Trial 184 finished with value: 0.49797922372817993 and parameters: {'iterations': 2068, 'depth': 7, 'learning_rate': 0.02696259271799489, 'l2_leaf_reg': 1.053450282332159, 'bagging_temperature': 0.5268604256843494}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:42:18,945] Trial 184 finished with value: 0.49797922372817993 and parameters: {'iterations': 2068, 'depth': 7, 'learning_rate': 0.02696259271799489, 'l2_leaf_reg': 1.053450282332159, 'bagging_temperature': 0.5268604256843494}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:42:25,831] Trial 185 finished with value: 0.49813151359558105 and parameters: {'iterations': 1599, 'depth': 7, 'learning_rate': 0.034368462135475605, 'l2_leaf_reg': 0.6911085769933174, 'bagging_temperature': 1.5690580626826827}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:42:25,831] Trial 185 finished with value: 0.49813151359558105 and parameters: {'iterations': 1599, 'depth': 7, 'learning_rate': 0.034368462135475605, 'l2_leaf_reg': 0.6911085769933174, 'bagging_temperature': 1.5690580626826827}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:42:42,577] Trial 186 finished with value: 0.49908924102783203 and parameters: {'iterations': 1058, 'depth': 8, 'learning_rate': 0.008764403385614437, 'l2_leaf_reg': 0.14654277010985844, 'bagging_temperature': 1.8228726921160514}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:42:42,577] Trial 186 finished with value: 0.49908924102783203 and parameters: {'iterations': 1058, 'depth': 8, 'learning_rate': 0.008764403385614437, 'l2_leaf_reg': 0.14654277010985844, 'bagging_temperature': 1.8228726921160514}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:42:49,237] Trial 187 finished with value: 0.4981788098812103 and parameters: {'iterations': 2169, 'depth': 7, 'learning_rate': 0.029820129169824298, 'l2_leaf_reg': 0.24106550334663215, 'bagging_temperature': 0.43116210008106537}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:42:49,237] Trial 187 finished with value: 0.4981788098812103 and parameters: {'iterations': 2169, 'depth': 7, 'learning_rate': 0.029820129169824298, 'l2_leaf_reg': 0.24106550334663215, 'bagging_temperature': 0.43116210008106537}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:42:54,373] Trial 188 finished with value: 0.49974483251571655 and parameters: {'iterations': 1846, 'depth': 8, 'learning_rate': 0.0991867719986348, 'l2_leaf_reg': 2.553678311843076, 'bagging_temperature': 1.0710294450616609}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:42:54,373] Trial 188 finished with value: 0.49974483251571655 and parameters: {'iterations': 1846, 'depth': 8, 'learning_rate': 0.0991867719986348, 'l2_leaf_reg': 2.553678311843076, 'bagging_temperature': 1.0710294450616609}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:43:05,622] Trial 189 finished with value: 0.4982941150665283 and parameters: {'iterations': 2710, 'depth': 10, 'learning_rate': 0.13953435490727628, 'l2_leaf_reg': 0.06885292377754866, 'bagging_temperature': 0.3994489958591767}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:43:05,622] Trial 189 finished with value: 0.4982941150665283 and parameters: {'iterations': 2710, 'depth': 10, 'learning_rate': 0.13953435490727628, 'l2_leaf_reg': 0.06885292377754866, 'bagging_temperature': 0.3994489958591767}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:43:11,017] Trial 190 finished with value: 0.4979709982872009 and parameters: {'iterations': 2198, 'depth': 7, 'learning_rate': 0.04577118409062935, 'l2_leaf_reg': 0.849696993042379, 'bagging_temperature': 1.1982423656240568}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:43:11,017] Trial 190 finished with value: 0.4979709982872009 and parameters: {'iterations': 2198, 'depth': 7, 'learning_rate': 0.04577118409062935, 'l2_leaf_reg': 0.849696993042379, 'bagging_temperature': 1.1982423656240568}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:43:17,571] Trial 191 finished with value: 0.4968254566192627 and parameters: {'iterations': 2285, 'depth': 7, 'learning_rate': 0.04062376168927191, 'l2_leaf_reg': 0.18191957545267226, 'bagging_temperature': 0.6090192647934796}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:43:17,571] Trial 191 finished with value: 0.4968254566192627 and parameters: {'iterations': 2285, 'depth': 7, 'learning_rate': 0.04062376168927191, 'l2_leaf_reg': 0.18191957545267226, 'bagging_temperature': 0.6090192647934796}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:43:24,144] Trial 192 finished with value: 0.49680179357528687 and parameters: {'iterations': 2282, 'depth': 7, 'learning_rate': 0.037902614007303256, 'l2_leaf_reg': 0.17365206136809044, 'bagging_temperature': 0.6824691491279365}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:43:24,144] Trial 192 finished with value: 0.49680179357528687 and parameters: {'iterations': 2282, 'depth': 7, 'learning_rate': 0.037902614007303256, 'l2_leaf_reg': 0.17365206136809044, 'bagging_temperature': 0.6824691491279365}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:43:28,266] Trial 193 finished with value: 0.49810677766799927 and parameters: {'iterations': 2291, 'depth': 6, 'learning_rate': 0.04253976444352788, 'l2_leaf_reg': 0.19229673404868328, 'bagging_temperature': 0.7029541002493299}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:43:28,266] Trial 193 finished with value: 0.49810677766799927 and parameters: {'iterations': 2291, 'depth': 6, 'learning_rate': 0.04253976444352788, 'l2_leaf_reg': 0.19229673404868328, 'bagging_temperature': 0.7029541002493299}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:43:36,331] Trial 194 finished with value: 0.49800533056259155 and parameters: {'iterations': 2362, 'depth': 8, 'learning_rate': 0.03786687813030837, 'l2_leaf_reg': 0.1647198757458141, 'bagging_temperature': 0.6004863686105438}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:43:36,331] Trial 194 finished with value: 0.49800533056259155 and parameters: {'iterations': 2362, 'depth': 8, 'learning_rate': 0.03786687813030837, 'l2_leaf_reg': 0.1647198757458141, 'bagging_temperature': 0.6004863686105438}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:43:40,489] Trial 195 finished with value: 0.49948281049728394 and parameters: {'iterations': 2247, 'depth': 7, 'learning_rate': 0.0511237644018471, 'l2_leaf_reg': 0.1293432625779977, 'bagging_temperature': 0.6778147289746858}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:43:40,489] Trial 195 finished with value: 0.49948281049728394 and parameters: {'iterations': 2247, 'depth': 7, 'learning_rate': 0.0511237644018471, 'l2_leaf_reg': 0.1293432625779977, 'bagging_temperature': 0.6778147289746858}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:43:48,384] Trial 196 finished with value: 0.4985100328922272 and parameters: {'iterations': 2231, 'depth': 8, 'learning_rate': 0.03462875898706622, 'l2_leaf_reg': 0.10314225755882622, 'bagging_temperature': 0.5529799739308799}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:43:48,384] Trial 196 finished with value: 0.4985100328922272 and parameters: {'iterations': 2231, 'depth': 8, 'learning_rate': 0.03462875898706622, 'l2_leaf_reg': 0.10314225755882622, 'bagging_temperature': 0.5529799739308799}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:43:54,305] Trial 197 finished with value: 0.49792927503585815 and parameters: {'iterations': 2740, 'depth': 7, 'learning_rate': 0.03797528024184707, 'l2_leaf_reg': 0.21922360014609324, 'bagging_temperature': 0.7307554490711831}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:43:54,305] Trial 197 finished with value: 0.49792927503585815 and parameters: {'iterations': 2740, 'depth': 7, 'learning_rate': 0.03797528024184707, 'l2_leaf_reg': 0.21922360014609324, 'bagging_temperature': 0.7307554490711831}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:44:11,491] Trial 198 finished with value: 0.49569234251976013 and parameters: {'iterations': 2405, 'depth': 10, 'learning_rate': 0.056970458767019734, 'l2_leaf_reg': 0.18874827489432938, 'bagging_temperature': 0.6428095878047801}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:44:11,491] Trial 198 finished with value: 0.49569234251976013 and parameters: {'iterations': 2405, 'depth': 10, 'learning_rate': 0.056970458767019734, 'l2_leaf_reg': 0.18874827489432938, 'bagging_temperature': 0.6428095878047801}. Best is trial 13 with value: 0.49545711278915405.
# [I 2025-08-12 21:44:24,512] Trial 199 finished with value: 0.4993830919265747 and parameters: {'iterations': 2384, 'depth': 10, 'learning_rate': 0.08227837950382057, 'l2_leaf_reg': 0.170472502975225, 'bagging_temperature': 0.6681685158491042}. Best is trial 13 with value: 0.49545711278915405.
# PCA Best objective: 0.495457
# PCA Best params: {'iterations': 2471, 'depth': 8, 'learning_rate': 0.025985242865756618, 'l2_leaf_reg': 0.0452470320672641, 'bagging_temperature': 1.2872972993582112}
# Training PCA on full dataset (including missing target values)...
#
# [pca] Training with 5 seeds...
#   Seed 1/5: 42
# [I 2025-08-12 21:44:24,512] Trial 199 finished with value: 0.4993830919265747 and parameters: {'iterations': 2384, 'depth': 10, 'learning_rate': 0.08227837950382057, 'l2_leaf_reg': 0.170472502975225, 'bagging_temperature': 0.6681685158491042}. Best is trial 13 with value: 0.49545711278915405.
# PCA Best objective: 0.495457
# PCA Best params: {'iterations': 2471, 'depth': 8, 'learning_rate': 0.025985242865756618, 'l2_leaf_reg': 0.0452470320672641, 'bagging_temperature': 1.2872972993582112}
# Training PCA on full dataset (including missing target values)...
#
# [pca] Training with 5 seeds...
#   Seed 1/5: 42
#     ✅ Seed 42 completed on CPU
#   Seed 2/5: 1
#     ✅ Seed 42 completed on CPU
#   Seed 2/5: 1
#     ✅ Seed 1 completed on CPU
#   Seed 3/5: 26
#     ✅ Seed 1 completed on CPU
#   Seed 3/5: 26
#     ✅ Seed 26 completed on CPU
#   Seed 4/5: 5
#     ✅ Seed 26 completed on CPU
#   Seed 4/5: 5
#     ✅ Seed 5 completed on CPU
#   Seed 5/5: 2005
#     ✅ Seed 5 completed on CPU
#   Seed 5/5: 2005
#     ✅ Seed 2005 completed on CPU
#     Saved: pca_seed42_1755010447.csv
#     Saved: pca_seed1_1755010447.csv
#     Saved: pca_seed26_1755010447.csv
#     Saved: pca_seed5_1755010447.csv
#     Saved: pca_seed2005_1755010447.csv
#   Saved averaged: pca_averaged_1755010447.csv
#     ✅ Seed 2005 completed on CPU
#     Saved: pca_seed42_1755010447.csv
#     Saved: pca_seed1_1755010447.csv
#     Saved: pca_seed26_1755010447.csv
#     Saved: pca_seed5_1755010447.csv
#     Saved: pca_seed2005_1755010447.csv
#   Saved averaged: pca_averaged_1755010447.csv

# %%
# ===== SVD PIPELINE =====
print("\n" + "="*40)
print("SVD PIPELINE") 
print("="*40)

print("Applying SVD reduction...")
train_svd, test_svd, svd_var = apply_svd_reduction(train_emb, test_emb)
X_mat_svd, Y_mat_svd, X_test_svd = prepare_dataset(train_df, test_df, train_svd, test_svd, "svd")

print(f"SVD dataset shapes: X={X_mat_svd.shape}, Y={Y_mat_svd.shape}, X_test={X_test_svd.shape}")

# Use same mask for consistency (complete cases for GPU Optuna)
X_cc_svd = X_mat_svd[mask_cc]
Y_cc_svd = Y_mat_svd[mask_cc]  
X_tr_svd, X_va_svd, Y_tr_svd, Y_va_svd = train_test_split(
    X_cc_svd, Y_cc_svd, test_size=VAL_SIZE, random_state=SEED, shuffle=True
)

print("Running SVD Optuna tuning...")
study_svd = tune_with_optuna(X_tr_svd, Y_tr_svd, X_va_svd, Y_va_svd, X_test_svd)
print(f"SVD Best objective: {study_svd.best_value:.6f}")
print(f"SVD Best params: {study_svd.best_trial.params}")

# Train SVD with multiple seeds on FULL dataset (CPU can handle missing values)
print("Training SVD on full dataset (including missing target values)...")
svd_pred, svd_seeds = train_multiple_seeds(X_mat_svd, Y_mat_svd, X_test_svd,
                                          study_svd.best_trial.params, "svd",
                                          use_gpu_final=False)  # CPU uses MultiRMSEWithMissingValues

results['svd'] = {
    'predictions': svd_pred,
    'seed_predictions': svd_seeds,
    'best_params': study_svd.best_trial.params,
    'best_score': study_svd.best_value,
    'explained_variance': svd_var
}

print("\nBoth pipelines completed!")
# Out:
# ========================================
# SVD PIPELINE
# ========================================
# Applying SVD reduction...
# [I 2025-08-12 21:54:09,242] A new study created in memory with name: no-name-69e360c2-cdd7-40a2-9fe7-25a3b41042b2
# [SVD] explained_variance_sum = 0.9113
# SVD dataset shapes: X=(9912, 321), Y=(9912, 4), X_test=(473, 321)
# Running SVD Optuna tuning...
# ✅ Found 6 compatible anchors (vec_len=1892)
# 🚀 Starting optimization with anchor-based objective
# ✅ Found 6 compatible anchors (vec_len=1892)
# 🚀 Starting optimization with anchor-based objective
#   0%|          | 0/200 [00:00<?, ?it/s]
# [I 2025-08-12 21:54:15,799] Trial 0 finished with value: 0.5026648044586182 and parameters: {'iterations': 1705, 'depth': 5, 'learning_rate': 0.006756413390203931, 'l2_leaf_reg': 0.10821415899066898, 'bagging_temperature': 0.34564721528115194}. Best is trial 0 with value: 0.5026648044586182.
# [I 2025-08-12 21:54:17,916] Trial 1 finished with value: 0.499750018119812 and parameters: {'iterations': 2018, 'depth': 5, 'learning_rate': 0.06211599801130484, 'l2_leaf_reg': 0.3589754277678872, 'bagging_temperature': 0.353720843210666}. Best is trial 1 with value: 0.499750018119812.
# [I 2025-08-12 21:54:17,916] Trial 1 finished with value: 0.499750018119812 and parameters: {'iterations': 2018, 'depth': 5, 'learning_rate': 0.06211599801130484, 'l2_leaf_reg': 0.3589754277678872, 'bagging_temperature': 0.353720843210666}. Best is trial 1 with value: 0.499750018119812.
# [I 2025-08-12 21:54:22,010] Trial 2 finished with value: 0.49863606691360474 and parameters: {'iterations': 2131, 'depth': 7, 'learning_rate': 0.05994404172595798, 'l2_leaf_reg': 0.013699848532716163, 'bagging_temperature': 1.004959677168019}. Best is trial 2 with value: 0.49863606691360474.
# [I 2025-08-12 21:54:22,010] Trial 2 finished with value: 0.49863606691360474 and parameters: {'iterations': 2131, 'depth': 7, 'learning_rate': 0.05994404172595798, 'l2_leaf_reg': 0.013699848532716163, 'bagging_temperature': 1.004959677168019}. Best is trial 2 with value: 0.49863606691360474.
# [I 2025-08-12 21:54:25,219] Trial 3 finished with value: 0.4993702173233032 and parameters: {'iterations': 904, 'depth': 5, 'learning_rate': 0.04139868262264253, 'l2_leaf_reg': 5.088347093526239, 'bagging_temperature': 1.5587368094526495}. Best is trial 2 with value: 0.49863606691360474.
# [I 2025-08-12 21:54:25,219] Trial 3 finished with value: 0.4993702173233032 and parameters: {'iterations': 904, 'depth': 5, 'learning_rate': 0.04139868262264253, 'l2_leaf_reg': 5.088347093526239, 'bagging_temperature': 1.5587368094526495}. Best is trial 2 with value: 0.49863606691360474.
# [I 2025-08-12 21:54:39,381] Trial 4 finished with value: 0.49591177701950073 and parameters: {'iterations': 2376, 'depth': 10, 'learning_rate': 0.08608160328607586, 'l2_leaf_reg': 0.09850011123668867, 'bagging_temperature': 1.5140128061321236}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 21:54:39,381] Trial 4 finished with value: 0.49591177701950073 and parameters: {'iterations': 2376, 'depth': 10, 'learning_rate': 0.08608160328607586, 'l2_leaf_reg': 0.09850011123668867, 'bagging_temperature': 1.5140128061321236}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 21:54:47,543] Trial 5 finished with value: 0.49814921617507935 and parameters: {'iterations': 2045, 'depth': 7, 'learning_rate': 0.024692450037374143, 'l2_leaf_reg': 0.9486899065248885, 'bagging_temperature': 1.4374422158634177}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 21:54:47,543] Trial 5 finished with value: 0.49814921617507935 and parameters: {'iterations': 2045, 'depth': 7, 'learning_rate': 0.024692450037374143, 'l2_leaf_reg': 0.9486899065248885, 'bagging_temperature': 1.4374422158634177}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 21:54:49,356] Trial 6 finished with value: 0.4987916350364685 and parameters: {'iterations': 2524, 'depth': 5, 'learning_rate': 0.09664057698752099, 'l2_leaf_reg': 0.05094761805642542, 'bagging_temperature': 1.959863342696967}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 21:54:49,356] Trial 6 finished with value: 0.4987916350364685 and parameters: {'iterations': 2524, 'depth': 5, 'learning_rate': 0.09664057698752099, 'l2_leaf_reg': 0.05094761805642542, 'bagging_temperature': 1.959863342696967}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 21:54:53,359] Trial 7 finished with value: 0.502466082572937 and parameters: {'iterations': 1124, 'depth': 5, 'learning_rate': 0.010286092347234927, 'l2_leaf_reg': 0.04097789841935731, 'bagging_temperature': 1.7843245730182207}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 21:54:53,359] Trial 7 finished with value: 0.502466082572937 and parameters: {'iterations': 1124, 'depth': 5, 'learning_rate': 0.010286092347234927, 'l2_leaf_reg': 0.04097789841935731, 'bagging_temperature': 1.7843245730182207}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 21:55:12,343] Trial 8 finished with value: 0.49678462743759155 and parameters: {'iterations': 2635, 'depth': 10, 'learning_rate': 0.06998006838183854, 'l2_leaf_reg': 3.3537568624199343, 'bagging_temperature': 1.2689861682719454}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 21:55:12,343] Trial 8 finished with value: 0.49678462743759155 and parameters: {'iterations': 2635, 'depth': 10, 'learning_rate': 0.06998006838183854, 'l2_leaf_reg': 3.3537568624199343, 'bagging_temperature': 1.2689861682719454}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 21:56:16,083] Trial 9 finished with value: 0.503101110458374 and parameters: {'iterations': 1254, 'depth': 10, 'learning_rate': 0.0026730183746083115, 'l2_leaf_reg': 1.3736249350435472, 'bagging_temperature': 1.1242586826615444}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 21:56:16,083] Trial 9 finished with value: 0.503101110458374 and parameters: {'iterations': 1254, 'depth': 10, 'learning_rate': 0.0026730183746083115, 'l2_leaf_reg': 1.3736249350435472, 'bagging_temperature': 1.1242586826615444}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 21:56:24,610] Trial 10 finished with value: 0.5010483860969543 and parameters: {'iterations': 2953, 'depth': 9, 'learning_rate': 0.15061589691652097, 'l2_leaf_reg': 16.113105506904084, 'bagging_temperature': 0.8356773525280855}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 21:56:24,610] Trial 10 finished with value: 0.5010483860969543 and parameters: {'iterations': 2953, 'depth': 9, 'learning_rate': 0.15061589691652097, 'l2_leaf_reg': 16.113105506904084, 'bagging_temperature': 0.8356773525280855}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 21:56:37,754] Trial 11 finished with value: 0.49875181913375854 and parameters: {'iterations': 2629, 'depth': 10, 'learning_rate': 0.1957581760721109, 'l2_leaf_reg': 6.720001360310689, 'bagging_temperature': 1.3290617814016445}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 21:56:37,754] Trial 11 finished with value: 0.49875181913375854 and parameters: {'iterations': 2629, 'depth': 10, 'learning_rate': 0.1957581760721109, 'l2_leaf_reg': 6.720001360310689, 'bagging_temperature': 1.3290617814016445}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 21:57:48,622] Trial 12 finished with value: 0.5039771795272827 and parameters: {'iterations': 2496, 'depth': 9, 'learning_rate': 0.001006713111109212, 'l2_leaf_reg': 0.2610617513230743, 'bagging_temperature': 0.7143614966628338}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 21:57:48,622] Trial 12 finished with value: 0.5039771795272827 and parameters: {'iterations': 2496, 'depth': 9, 'learning_rate': 0.001006713111109212, 'l2_leaf_reg': 0.2610617513230743, 'bagging_temperature': 0.7143614966628338}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 21:58:02,293] Trial 13 finished with value: 0.49778473377227783 and parameters: {'iterations': 2876, 'depth': 8, 'learning_rate': 0.022499455801016272, 'l2_leaf_reg': 1.669384771427691, 'bagging_temperature': 1.6329560827949543}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 21:58:02,293] Trial 13 finished with value: 0.49778473377227783 and parameters: {'iterations': 2876, 'depth': 8, 'learning_rate': 0.022499455801016272, 'l2_leaf_reg': 1.669384771427691, 'bagging_temperature': 1.6329560827949543}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 21:58:18,708] Trial 14 finished with value: 0.4982987940311432 and parameters: {'iterations': 2406, 'depth': 9, 'learning_rate': 0.033717725986115124, 'l2_leaf_reg': 3.8481741427745506, 'bagging_temperature': 1.2136326027699769}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 21:58:18,708] Trial 14 finished with value: 0.4982987940311432 and parameters: {'iterations': 2406, 'depth': 9, 'learning_rate': 0.033717725986115124, 'l2_leaf_reg': 3.8481741427745506, 'bagging_temperature': 1.2136326027699769}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 21:58:31,742] Trial 15 finished with value: 0.49980291724205017 and parameters: {'iterations': 1712, 'depth': 10, 'learning_rate': 0.07308198916095505, 'l2_leaf_reg': 0.2080758101558987, 'bagging_temperature': 0.7120687302711023}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 21:58:31,742] Trial 15 finished with value: 0.49980291724205017 and parameters: {'iterations': 1712, 'depth': 10, 'learning_rate': 0.07308198916095505, 'l2_leaf_reg': 0.2080758101558987, 'bagging_temperature': 0.7120687302711023}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 21:58:38,464] Trial 16 finished with value: 0.5001012086868286 and parameters: {'iterations': 2267, 'depth': 8, 'learning_rate': 0.11908248237823464, 'l2_leaf_reg': 24.29235075680524, 'bagging_temperature': 1.7840749672360938}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 21:58:38,464] Trial 16 finished with value: 0.5001012086868286 and parameters: {'iterations': 2267, 'depth': 8, 'learning_rate': 0.11908248237823464, 'l2_leaf_reg': 24.29235075680524, 'bagging_temperature': 1.7840749672360938}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 21:58:53,641] Trial 17 finished with value: 0.49814578890800476 and parameters: {'iterations': 2732, 'depth': 8, 'learning_rate': 0.013810890655089114, 'l2_leaf_reg': 0.01718644595938352, 'bagging_temperature': 0.9770178194669868}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 21:58:53,641] Trial 17 finished with value: 0.49814578890800476 and parameters: {'iterations': 2732, 'depth': 8, 'learning_rate': 0.013810890655089114, 'l2_leaf_reg': 0.01718644595938352, 'bagging_temperature': 0.9770178194669868}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 21:59:03,113] Trial 18 finished with value: 0.503494918346405 and parameters: {'iterations': 1731, 'depth': 6, 'learning_rate': 0.003777857420107956, 'l2_leaf_reg': 0.6836580350069005, 'bagging_temperature': 1.4432058271346002}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 21:59:03,113] Trial 18 finished with value: 0.503494918346405 and parameters: {'iterations': 1731, 'depth': 6, 'learning_rate': 0.003777857420107956, 'l2_leaf_reg': 0.6836580350069005, 'bagging_temperature': 1.4432058271346002}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 21:59:15,390] Trial 19 finished with value: 0.49678075313568115 and parameters: {'iterations': 2294, 'depth': 9, 'learning_rate': 0.042379843986762714, 'l2_leaf_reg': 0.12002184639638507, 'bagging_temperature': 0.11436437893351215}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 21:59:15,390] Trial 19 finished with value: 0.49678075313568115 and parameters: {'iterations': 2294, 'depth': 9, 'learning_rate': 0.042379843986762714, 'l2_leaf_reg': 0.12002184639638507, 'bagging_temperature': 0.11436437893351215}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 21:59:26,694] Trial 20 finished with value: 0.4986949563026428 and parameters: {'iterations': 1493, 'depth': 9, 'learning_rate': 0.03644311481917897, 'l2_leaf_reg': 0.09477216344924909, 'bagging_temperature': 0.11507866969976077}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 21:59:26,694] Trial 20 finished with value: 0.4986949563026428 and parameters: {'iterations': 1493, 'depth': 9, 'learning_rate': 0.03644311481917897, 'l2_leaf_reg': 0.09477216344924909, 'bagging_temperature': 0.11507866969976077}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 21:59:38,544] Trial 21 finished with value: 0.49930739402770996 and parameters: {'iterations': 2320, 'depth': 10, 'learning_rate': 0.10374964744701598, 'l2_leaf_reg': 0.11761925154175458, 'bagging_temperature': 1.2514294061496043}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 21:59:38,544] Trial 21 finished with value: 0.49930739402770996 and parameters: {'iterations': 2320, 'depth': 10, 'learning_rate': 0.10374964744701598, 'l2_leaf_reg': 0.11761925154175458, 'bagging_temperature': 1.2514294061496043}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 21:59:53,228] Trial 22 finished with value: 0.4988728165626526 and parameters: {'iterations': 2760, 'depth': 10, 'learning_rate': 0.05417861823071142, 'l2_leaf_reg': 0.027980018258110823, 'bagging_temperature': 0.42596427371547}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 21:59:53,228] Trial 22 finished with value: 0.4988728165626526 and parameters: {'iterations': 2760, 'depth': 10, 'learning_rate': 0.05417861823071142, 'l2_leaf_reg': 0.027980018258110823, 'bagging_temperature': 0.42596427371547}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:00:12,969] Trial 23 finished with value: 0.4986279010772705 and parameters: {'iterations': 2231, 'depth': 9, 'learning_rate': 0.020808100470064882, 'l2_leaf_reg': 2.276440053429714, 'bagging_temperature': 1.5769837762289556}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:00:12,969] Trial 23 finished with value: 0.4986279010772705 and parameters: {'iterations': 2231, 'depth': 9, 'learning_rate': 0.020808100470064882, 'l2_leaf_reg': 2.276440053429714, 'bagging_temperature': 1.5769837762289556}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:00:17,865] Trial 24 finished with value: 0.49982380867004395 and parameters: {'iterations': 1901, 'depth': 8, 'learning_rate': 0.0811013068959332, 'l2_leaf_reg': 0.46211831862083963, 'bagging_temperature': 1.3823728124292547}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:00:17,865] Trial 24 finished with value: 0.49982380867004395 and parameters: {'iterations': 1901, 'depth': 8, 'learning_rate': 0.0811013068959332, 'l2_leaf_reg': 0.46211831862083963, 'bagging_temperature': 1.3823728124292547}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:00:28,088] Trial 25 finished with value: 0.5008464455604553 and parameters: {'iterations': 2588, 'depth': 10, 'learning_rate': 0.17499382083314932, 'l2_leaf_reg': 0.1369590701514684, 'bagging_temperature': 0.15401897902375838}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:00:28,088] Trial 25 finished with value: 0.5008464455604553 and parameters: {'iterations': 2588, 'depth': 10, 'learning_rate': 0.17499382083314932, 'l2_leaf_reg': 0.1369590701514684, 'bagging_temperature': 0.15401897902375838}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:00:38,164] Trial 26 finished with value: 0.4984225332736969 and parameters: {'iterations': 2396, 'depth': 9, 'learning_rate': 0.04634518494931077, 'l2_leaf_reg': 0.053623007115217204, 'bagging_temperature': 0.5245244945199271}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:00:38,164] Trial 26 finished with value: 0.4984225332736969 and parameters: {'iterations': 2396, 'depth': 9, 'learning_rate': 0.04634518494931077, 'l2_leaf_reg': 0.053623007115217204, 'bagging_temperature': 0.5245244945199271}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:01:13,606] Trial 27 finished with value: 0.497999370098114 and parameters: {'iterations': 2747, 'depth': 10, 'learning_rate': 0.029930107555285006, 'l2_leaf_reg': 7.930447496631037, 'bagging_temperature': 1.1250566255482393}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:01:13,606] Trial 27 finished with value: 0.497999370098114 and parameters: {'iterations': 2747, 'depth': 10, 'learning_rate': 0.029930107555285006, 'l2_leaf_reg': 7.930447496631037, 'bagging_temperature': 1.1250566255482393}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:01:21,811] Trial 28 finished with value: 0.49827420711517334 and parameters: {'iterations': 2170, 'depth': 6, 'learning_rate': 0.016998365302918386, 'l2_leaf_reg': 0.2249096980078757, 'bagging_temperature': 0.8865008611289547}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:01:21,811] Trial 28 finished with value: 0.49827420711517334 and parameters: {'iterations': 2170, 'depth': 6, 'learning_rate': 0.016998365302918386, 'l2_leaf_reg': 0.2249096980078757, 'bagging_temperature': 0.8865008611289547}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:01:26,464] Trial 29 finished with value: 0.5024229288101196 and parameters: {'iterations': 1936, 'depth': 4, 'learning_rate': 0.00835126924319412, 'l2_leaf_reg': 0.07512723073962269, 'bagging_temperature': 1.766824243910304}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:01:26,464] Trial 29 finished with value: 0.5024229288101196 and parameters: {'iterations': 1936, 'depth': 4, 'learning_rate': 0.00835126924319412, 'l2_leaf_reg': 0.07512723073962269, 'bagging_temperature': 1.766824243910304}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:01:33,332] Trial 30 finished with value: 0.49819397926330566 and parameters: {'iterations': 2443, 'depth': 9, 'learning_rate': 0.13327624323528128, 'l2_leaf_reg': 0.026228255989813123, 'bagging_temperature': 0.58056692163107}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:01:33,332] Trial 30 finished with value: 0.49819397926330566 and parameters: {'iterations': 2443, 'depth': 9, 'learning_rate': 0.13327624323528128, 'l2_leaf_reg': 0.026228255989813123, 'bagging_temperature': 0.58056692163107}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:01:46,913] Trial 31 finished with value: 0.49844613671302795 and parameters: {'iterations': 2976, 'depth': 8, 'learning_rate': 0.020069985952849638, 'l2_leaf_reg': 1.7252044499918417, 'bagging_temperature': 1.599370953988257}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:01:46,913] Trial 31 finished with value: 0.49844613671302795 and parameters: {'iterations': 2976, 'depth': 8, 'learning_rate': 0.020069985952849638, 'l2_leaf_reg': 1.7252044499918417, 'bagging_temperature': 1.599370953988257}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:01:51,411] Trial 32 finished with value: 0.49808385968208313 and parameters: {'iterations': 2830, 'depth': 7, 'learning_rate': 0.07203802296451484, 'l2_leaf_reg': 2.765300466233986, 'bagging_temperature': 1.6533957184637638}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:01:51,411] Trial 32 finished with value: 0.49808385968208313 and parameters: {'iterations': 2830, 'depth': 7, 'learning_rate': 0.07203802296451484, 'l2_leaf_reg': 2.765300466233986, 'bagging_temperature': 1.6533957184637638}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:02:09,798] Trial 33 finished with value: 0.4981215298175812 and parameters: {'iterations': 2858, 'depth': 8, 'learning_rate': 0.0129059086442207, 'l2_leaf_reg': 0.8182540599784338, 'bagging_temperature': 1.942524492903912}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:02:09,798] Trial 33 finished with value: 0.4981215298175812 and parameters: {'iterations': 2858, 'depth': 8, 'learning_rate': 0.0129059086442207, 'l2_leaf_reg': 0.8182540599784338, 'bagging_temperature': 1.942524492903912}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:02:19,876] Trial 34 finished with value: 0.4983248710632324 and parameters: {'iterations': 2634, 'depth': 9, 'learning_rate': 0.05334541191347336, 'l2_leaf_reg': 0.4873791957996834, 'bagging_temperature': 1.488330216125859}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:02:19,876] Trial 34 finished with value: 0.4983248710632324 and parameters: {'iterations': 2634, 'depth': 9, 'learning_rate': 0.05334541191347336, 'l2_leaf_reg': 0.4873791957996834, 'bagging_temperature': 1.488330216125859}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:02:29,786] Trial 35 finished with value: 0.4983464181423187 and parameters: {'iterations': 2098, 'depth': 8, 'learning_rate': 0.030103678715679025, 'l2_leaf_reg': 1.1828427730287807, 'bagging_temperature': 1.2838512154863306}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:02:29,786] Trial 35 finished with value: 0.4983464181423187 and parameters: {'iterations': 2098, 'depth': 8, 'learning_rate': 0.030103678715679025, 'l2_leaf_reg': 1.1828427730287807, 'bagging_temperature': 1.2838512154863306}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:03:00,332] Trial 36 finished with value: 0.4979228079319 and parameters: {'iterations': 2668, 'depth': 10, 'learning_rate': 0.044892057712116455, 'l2_leaf_reg': 11.80314086417399, 'bagging_temperature': 0.24558861346945185}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:03:00,332] Trial 36 finished with value: 0.4979228079319 and parameters: {'iterations': 2668, 'depth': 10, 'learning_rate': 0.044892057712116455, 'l2_leaf_reg': 11.80314086417399, 'bagging_temperature': 0.24558861346945185}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:03:21,281] Trial 37 finished with value: 0.49793973565101624 and parameters: {'iterations': 2887, 'depth': 9, 'learning_rate': 0.02405793620295074, 'l2_leaf_reg': 3.3555325296241523, 'bagging_temperature': 1.6581526441319498}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:03:21,281] Trial 37 finished with value: 0.49793973565101624 and parameters: {'iterations': 2887, 'depth': 9, 'learning_rate': 0.02405793620295074, 'l2_leaf_reg': 3.3555325296241523, 'bagging_temperature': 1.6581526441319498}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:03:24,862] Trial 38 finished with value: 0.4979070723056793 and parameters: {'iterations': 2320, 'depth': 7, 'learning_rate': 0.0921230716710455, 'l2_leaf_reg': 0.32192635396420083, 'bagging_temperature': 1.123185141673137}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:03:24,862] Trial 38 finished with value: 0.4979070723056793 and parameters: {'iterations': 2320, 'depth': 7, 'learning_rate': 0.0921230716710455, 'l2_leaf_reg': 0.32192635396420083, 'bagging_temperature': 1.123185141673137}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:03:38,508] Trial 39 finished with value: 0.4992527961730957 and parameters: {'iterations': 2537, 'depth': 10, 'learning_rate': 0.06557265616220466, 'l2_leaf_reg': 0.16669716381347888, 'bagging_temperature': 1.8600758793763597}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:03:38,508] Trial 39 finished with value: 0.4992527961730957 and parameters: {'iterations': 2537, 'depth': 10, 'learning_rate': 0.06557265616220466, 'l2_leaf_reg': 0.16669716381347888, 'bagging_temperature': 1.8600758793763597}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:03:43,535] Trial 40 finished with value: 0.4973917305469513 and parameters: {'iterations': 2009, 'depth': 6, 'learning_rate': 0.04090643468664788, 'l2_leaf_reg': 1.6322965349055343, 'bagging_temperature': 1.4161472885056352}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:03:43,535] Trial 40 finished with value: 0.4973917305469513 and parameters: {'iterations': 2009, 'depth': 6, 'learning_rate': 0.04090643468664788, 'l2_leaf_reg': 1.6322965349055343, 'bagging_temperature': 1.4161472885056352}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:03:47,785] Trial 41 finished with value: 0.4987398087978363 and parameters: {'iterations': 1982, 'depth': 6, 'learning_rate': 0.042190727783184945, 'l2_leaf_reg': 1.8807668252074192, 'bagging_temperature': 1.5180454646979444}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:03:47,785] Trial 41 finished with value: 0.4987398087978363 and parameters: {'iterations': 1982, 'depth': 6, 'learning_rate': 0.042190727783184945, 'l2_leaf_reg': 1.8807668252074192, 'bagging_temperature': 1.5180454646979444}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:03:53,536] Trial 42 finished with value: 0.49893394112586975 and parameters: {'iterations': 2071, 'depth': 6, 'learning_rate': 0.027563721562268703, 'l2_leaf_reg': 1.2700830023198866, 'bagging_temperature': 1.401641892782643}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:03:53,536] Trial 42 finished with value: 0.49893394112586975 and parameters: {'iterations': 2071, 'depth': 6, 'learning_rate': 0.027563721562268703, 'l2_leaf_reg': 1.2700830023198866, 'bagging_temperature': 1.401641892782643}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:03:55,756] Trial 43 finished with value: 0.5002341270446777 and parameters: {'iterations': 1802, 'depth': 4, 'learning_rate': 0.0582184713964616, 'l2_leaf_reg': 4.277111761933047, 'bagging_temperature': 1.7134841773857958}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:03:55,756] Trial 43 finished with value: 0.5002341270446777 and parameters: {'iterations': 1802, 'depth': 4, 'learning_rate': 0.0582184713964616, 'l2_leaf_reg': 4.277111761933047, 'bagging_temperature': 1.7134841773857958}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:04:02,617] Trial 44 finished with value: 0.5000824332237244 and parameters: {'iterations': 1552, 'depth': 7, 'learning_rate': 0.03577543773058826, 'l2_leaf_reg': 7.212771097114392, 'bagging_temperature': 1.3302741810573906}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:04:02,617] Trial 44 finished with value: 0.5000824332237244 and parameters: {'iterations': 1552, 'depth': 7, 'learning_rate': 0.03577543773058826, 'l2_leaf_reg': 7.212771097114392, 'bagging_temperature': 1.3302741810573906}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:04:10,331] Trial 45 finished with value: 0.502484142780304 and parameters: {'iterations': 2202, 'depth': 5, 'learning_rate': 0.005755269165328562, 'l2_leaf_reg': 0.7901347183518469, 'bagging_temperature': 1.188875376190474}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:04:10,331] Trial 45 finished with value: 0.502484142780304 and parameters: {'iterations': 2202, 'depth': 5, 'learning_rate': 0.005755269165328562, 'l2_leaf_reg': 0.7901347183518469, 'bagging_temperature': 1.188875376190474}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:04:20,331] Trial 46 finished with value: 0.498577356338501 and parameters: {'iterations': 2466, 'depth': 9, 'learning_rate': 0.0927961741371421, 'l2_leaf_reg': 5.217158854137249, 'bagging_temperature': 1.0070114133927708}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:04:20,331] Trial 46 finished with value: 0.498577356338501 and parameters: {'iterations': 2466, 'depth': 9, 'learning_rate': 0.0927961741371421, 'l2_leaf_reg': 5.217158854137249, 'bagging_temperature': 1.0070114133927708}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:04:53,106] Trial 47 finished with value: 0.49658575654029846 and parameters: {'iterations': 2394, 'depth': 10, 'learning_rate': 0.017476148285219196, 'l2_leaf_reg': 0.39921496740226187, 'bagging_temperature': 1.4886190188485657}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:04:53,106] Trial 47 finished with value: 0.49658575654029846 and parameters: {'iterations': 2394, 'depth': 10, 'learning_rate': 0.017476148285219196, 'l2_leaf_reg': 0.39921496740226187, 'bagging_temperature': 1.4886190188485657}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:05:38,796] Trial 48 finished with value: 0.49690327048301697 and parameters: {'iterations': 2354, 'depth': 10, 'learning_rate': 0.010883414751995196, 'l2_leaf_reg': 0.36787880118315947, 'bagging_temperature': 1.5188360772055542}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:05:38,796] Trial 48 finished with value: 0.49690327048301697 and parameters: {'iterations': 2354, 'depth': 10, 'learning_rate': 0.010883414751995196, 'l2_leaf_reg': 0.36787880118315947, 'bagging_temperature': 1.5188360772055542}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:06:23,220] Trial 49 finished with value: 0.49655795097351074 and parameters: {'iterations': 871, 'depth': 10, 'learning_rate': 0.010363610368834172, 'l2_leaf_reg': 0.3001829560577885, 'bagging_temperature': 1.4816833356535393}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:06:23,220] Trial 49 finished with value: 0.49655795097351074 and parameters: {'iterations': 871, 'depth': 10, 'learning_rate': 0.010363610368834172, 'l2_leaf_reg': 0.3001829560577885, 'bagging_temperature': 1.4816833356535393}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:07:15,647] Trial 50 finished with value: 0.49866366386413574 and parameters: {'iterations': 1020, 'depth': 10, 'learning_rate': 0.004988327960138143, 'l2_leaf_reg': 0.06347307314369514, 'bagging_temperature': 1.3277123367253332}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:07:15,647] Trial 50 finished with value: 0.49866366386413574 and parameters: {'iterations': 1020, 'depth': 10, 'learning_rate': 0.004988327960138143, 'l2_leaf_reg': 0.06347307314369514, 'bagging_temperature': 1.3277123367253332}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:08:01,563] Trial 51 finished with value: 0.49716776609420776 and parameters: {'iterations': 1318, 'depth': 10, 'learning_rate': 0.010017203004284492, 'l2_leaf_reg': 0.31725928646267126, 'bagging_temperature': 1.5287876817998554}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:08:01,563] Trial 51 finished with value: 0.49716776609420776 and parameters: {'iterations': 1318, 'depth': 10, 'learning_rate': 0.010017203004284492, 'l2_leaf_reg': 0.31725928646267126, 'bagging_temperature': 1.5287876817998554}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:08:47,400] Trial 52 finished with value: 0.4978541135787964 and parameters: {'iterations': 892, 'depth': 10, 'learning_rate': 0.007274196881354595, 'l2_leaf_reg': 0.17183318893982433, 'bagging_temperature': 1.5010368251507251}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:08:47,400] Trial 52 finished with value: 0.4978541135787964 and parameters: {'iterations': 892, 'depth': 10, 'learning_rate': 0.007274196881354595, 'l2_leaf_reg': 0.17183318893982433, 'bagging_temperature': 1.5010368251507251}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:09:32,238] Trial 53 finished with value: 0.4966145157814026 and parameters: {'iterations': 2352, 'depth': 10, 'learning_rate': 0.011661611459277845, 'l2_leaf_reg': 0.42666507745571536, 'bagging_temperature': 1.6941969115102165}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:09:32,238] Trial 53 finished with value: 0.4966145157814026 and parameters: {'iterations': 2352, 'depth': 10, 'learning_rate': 0.011661611459277845, 'l2_leaf_reg': 0.42666507745571536, 'bagging_temperature': 1.6941969115102165}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:10:07,386] Trial 54 finished with value: 0.4964148998260498 and parameters: {'iterations': 2546, 'depth': 10, 'learning_rate': 0.014869566364302322, 'l2_leaf_reg': 0.10590260862391303, 'bagging_temperature': 1.8577608852403062}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:10:07,386] Trial 54 finished with value: 0.4964148998260498 and parameters: {'iterations': 2546, 'depth': 10, 'learning_rate': 0.014869566364302322, 'l2_leaf_reg': 0.10590260862391303, 'bagging_temperature': 1.8577608852403062}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:10:37,401] Trial 55 finished with value: 0.4972742199897766 and parameters: {'iterations': 2277, 'depth': 10, 'learning_rate': 0.016418735325081025, 'l2_leaf_reg': 0.09711184450489804, 'bagging_temperature': 1.8745275641991126}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:10:37,401] Trial 55 finished with value: 0.4972742199897766 and parameters: {'iterations': 2277, 'depth': 10, 'learning_rate': 0.016418735325081025, 'l2_leaf_reg': 0.09711184450489804, 'bagging_temperature': 1.8745275641991126}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:11:48,969] Trial 56 finished with value: 0.49944669008255005 and parameters: {'iterations': 2539, 'depth': 9, 'learning_rate': 0.0023935913782032903, 'l2_leaf_reg': 0.04016422303113913, 'bagging_temperature': 1.8479014758064662}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:11:48,969] Trial 56 finished with value: 0.49944669008255005 and parameters: {'iterations': 2539, 'depth': 9, 'learning_rate': 0.0023935913782032903, 'l2_leaf_reg': 0.04016422303113913, 'bagging_temperature': 1.8479014758064662}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:12:28,012] Trial 57 finished with value: 0.49715545773506165 and parameters: {'iterations': 2170, 'depth': 10, 'learning_rate': 0.012181645122896892, 'l2_leaf_reg': 0.250775633606737, 'bagging_temperature': 1.7401492049316132}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:12:28,012] Trial 57 finished with value: 0.49715545773506165 and parameters: {'iterations': 2170, 'depth': 10, 'learning_rate': 0.012181645122896892, 'l2_leaf_reg': 0.250775633606737, 'bagging_temperature': 1.7401492049316132}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:12:49,066] Trial 58 finished with value: 0.4983059763908386 and parameters: {'iterations': 2377, 'depth': 9, 'learning_rate': 0.016166265370995084, 'l2_leaf_reg': 0.6103434732285323, 'bagging_temperature': 1.9879452270008422}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:12:49,066] Trial 58 finished with value: 0.4983059763908386 and parameters: {'iterations': 2377, 'depth': 9, 'learning_rate': 0.016166265370995084, 'l2_leaf_reg': 0.6103434732285323, 'bagging_temperature': 1.9879452270008422}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:13:38,331] Trial 59 finished with value: 0.49714910984039307 and parameters: {'iterations': 2487, 'depth': 10, 'learning_rate': 0.008905958598061495, 'l2_leaf_reg': 0.16489455030708788, 'bagging_temperature': 1.8383704530138691}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:13:38,331] Trial 59 finished with value: 0.49714910984039307 and parameters: {'iterations': 2487, 'depth': 10, 'learning_rate': 0.008905958598061495, 'l2_leaf_reg': 0.16489455030708788, 'bagging_temperature': 1.8383704530138691}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:14:54,540] Trial 60 finished with value: 0.49759912490844727 and parameters: {'iterations': 1791, 'depth': 10, 'learning_rate': 0.004783148853956899, 'l2_leaf_reg': 0.13207453383234585, 'bagging_temperature': 1.6323840607901976}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:14:54,540] Trial 60 finished with value: 0.49759912490844727 and parameters: {'iterations': 1791, 'depth': 10, 'learning_rate': 0.004783148853956899, 'l2_leaf_reg': 0.13207453383234585, 'bagging_temperature': 1.6323840607901976}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:15:05,688] Trial 61 finished with value: 0.5004070401191711 and parameters: {'iterations': 2670, 'depth': 10, 'learning_rate': 0.11481502795254557, 'l2_leaf_reg': 0.08094547087834116, 'bagging_temperature': 1.6877296390620014}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:15:05,688] Trial 61 finished with value: 0.5004070401191711 and parameters: {'iterations': 2670, 'depth': 10, 'learning_rate': 0.11481502795254557, 'l2_leaf_reg': 0.08094547087834116, 'bagging_temperature': 1.6877296390620014}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:16:06,986] Trial 62 finished with value: 0.49689140915870667 and parameters: {'iterations': 2548, 'depth': 10, 'learning_rate': 0.00771922622571743, 'l2_leaf_reg': 0.4020092572431043, 'bagging_temperature': 1.4540931450967274}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:16:06,986] Trial 62 finished with value: 0.49689140915870667 and parameters: {'iterations': 2548, 'depth': 10, 'learning_rate': 0.00771922622571743, 'l2_leaf_reg': 0.4020092572431043, 'bagging_temperature': 1.4540931450967274}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:16:29,334] Trial 63 finished with value: 0.4959612190723419 and parameters: {'iterations': 810, 'depth': 9, 'learning_rate': 0.018846479568765336, 'l2_leaf_reg': 0.21620255335698724, 'bagging_temperature': 1.6042726037588435}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:16:29,334] Trial 63 finished with value: 0.4959612190723419 and parameters: {'iterations': 810, 'depth': 9, 'learning_rate': 0.018846479568765336, 'l2_leaf_reg': 0.21620255335698724, 'bagging_temperature': 1.6042726037588435}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:16:49,256] Trial 64 finished with value: 0.4965541958808899 and parameters: {'iterations': 1129, 'depth': 9, 'learning_rate': 0.019847611551480248, 'l2_leaf_reg': 0.2287091922563406, 'bagging_temperature': 1.579833687794227}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:16:49,256] Trial 64 finished with value: 0.4965541958808899 and parameters: {'iterations': 1129, 'depth': 9, 'learning_rate': 0.019847611551480248, 'l2_leaf_reg': 0.2287091922563406, 'bagging_temperature': 1.579833687794227}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:17:05,604] Trial 65 finished with value: 0.4985494315624237 and parameters: {'iterations': 813, 'depth': 9, 'learning_rate': 0.019882660151114593, 'l2_leaf_reg': 0.26959708611367755, 'bagging_temperature': 1.5654374316923112}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:17:05,604] Trial 65 finished with value: 0.4985494315624237 and parameters: {'iterations': 813, 'depth': 9, 'learning_rate': 0.019882660151114593, 'l2_leaf_reg': 0.26959708611367755, 'bagging_temperature': 1.5654374316923112}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:17:26,682] Trial 66 finished with value: 0.4981428384780884 and parameters: {'iterations': 1055, 'depth': 9, 'learning_rate': 0.014795612059598373, 'l2_leaf_reg': 0.1965507892778057, 'bagging_temperature': 1.9110977610131028}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:17:26,682] Trial 66 finished with value: 0.4981428384780884 and parameters: {'iterations': 1055, 'depth': 9, 'learning_rate': 0.014795612059598373, 'l2_leaf_reg': 0.1965507892778057, 'bagging_temperature': 1.9110977610131028}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:18:14,825] Trial 67 finished with value: 0.49640750885009766 and parameters: {'iterations': 1183, 'depth': 10, 'learning_rate': 0.011428635559428314, 'l2_leaf_reg': 0.6006325165404903, 'bagging_temperature': 1.7655371072499457}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:18:14,825] Trial 67 finished with value: 0.49640750885009766 and parameters: {'iterations': 1183, 'depth': 10, 'learning_rate': 0.011428635559428314, 'l2_leaf_reg': 0.6006325165404903, 'bagging_temperature': 1.7655371072499457}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:18:50,327] Trial 68 finished with value: 0.49607929587364197 and parameters: {'iterations': 1208, 'depth': 10, 'learning_rate': 0.01817419432739433, 'l2_leaf_reg': 0.6399935746392317, 'bagging_temperature': 1.617905733327237}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:18:50,327] Trial 68 finished with value: 0.49607929587364197 and parameters: {'iterations': 1208, 'depth': 10, 'learning_rate': 0.01817419432739433, 'l2_leaf_reg': 0.6399935746392317, 'bagging_temperature': 1.617905733327237}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:19:24,680] Trial 69 finished with value: 0.49703699350357056 and parameters: {'iterations': 1233, 'depth': 9, 'learning_rate': 0.009478779897775505, 'l2_leaf_reg': 0.5714335070306252, 'bagging_temperature': 1.7958313660266254}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:19:24,680] Trial 69 finished with value: 0.49703699350357056 and parameters: {'iterations': 1233, 'depth': 9, 'learning_rate': 0.009478779897775505, 'l2_leaf_reg': 0.5714335070306252, 'bagging_temperature': 1.7958313660266254}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:20:23,885] Trial 70 finished with value: 0.49785366654396057 and parameters: {'iterations': 1164, 'depth': 10, 'learning_rate': 0.006527977851486859, 'l2_leaf_reg': 0.9860381703674364, 'bagging_temperature': 1.5996792596802432}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:20:23,885] Trial 70 finished with value: 0.49785366654396057 and parameters: {'iterations': 1164, 'depth': 10, 'learning_rate': 0.006527977851486859, 'l2_leaf_reg': 0.9860381703674364, 'bagging_temperature': 1.5996792596802432}. Best is trial 4 with value: 0.49591177701950073.
# [I 2025-08-12 22:20:59,222] Trial 71 finished with value: 0.4953094720840454 and parameters: {'iterations': 954, 'depth': 10, 'learning_rate': 0.018588163726181217, 'l2_leaf_reg': 0.2824688102167141, 'bagging_temperature': 1.7832724153348096}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 22:20:59,222] Trial 71 finished with value: 0.4953094720840454 and parameters: {'iterations': 954, 'depth': 10, 'learning_rate': 0.018588163726181217, 'l2_leaf_reg': 0.2824688102167141, 'bagging_temperature': 1.7832724153348096}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 22:21:38,073] Trial 72 finished with value: 0.4965890944004059 and parameters: {'iterations': 1007, 'depth': 10, 'learning_rate': 0.013890775009913175, 'l2_leaf_reg': 0.3046295654219241, 'bagging_temperature': 1.7515248803933912}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 22:21:38,073] Trial 72 finished with value: 0.4965890944004059 and parameters: {'iterations': 1007, 'depth': 10, 'learning_rate': 0.013890775009913175, 'l2_leaf_reg': 0.3046295654219241, 'bagging_temperature': 1.7515248803933912}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 22:22:00,589] Trial 73 finished with value: 0.49812051653862 and parameters: {'iterations': 916, 'depth': 10, 'learning_rate': 0.026247474392136386, 'l2_leaf_reg': 0.23592076229355205, 'bagging_temperature': 1.8188476534489897}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 22:22:00,589] Trial 73 finished with value: 0.49812051653862 and parameters: {'iterations': 916, 'depth': 10, 'learning_rate': 0.026247474392136386, 'l2_leaf_reg': 0.23592076229355205, 'bagging_temperature': 1.8188476534489897}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 22:22:27,459] Trial 74 finished with value: 0.49587246775627136 and parameters: {'iterations': 1344, 'depth': 10, 'learning_rate': 0.024508039864031512, 'l2_leaf_reg': 0.11375971845108872, 'bagging_temperature': 1.9281511866650263}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 22:22:27,459] Trial 74 finished with value: 0.49587246775627136 and parameters: {'iterations': 1344, 'depth': 10, 'learning_rate': 0.024508039864031512, 'l2_leaf_reg': 0.11375971845108872, 'bagging_temperature': 1.9281511866650263}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 22:22:45,261] Trial 75 finished with value: 0.49654635787010193 and parameters: {'iterations': 1376, 'depth': 9, 'learning_rate': 0.022778860905010644, 'l2_leaf_reg': 0.12334225383660444, 'bagging_temperature': 1.9220663206712119}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 22:22:45,261] Trial 75 finished with value: 0.49654635787010193 and parameters: {'iterations': 1376, 'depth': 9, 'learning_rate': 0.022778860905010644, 'l2_leaf_reg': 0.12334225383660444, 'bagging_temperature': 1.9220663206712119}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 22:23:10,844] Trial 76 finished with value: 0.49642515182495117 and parameters: {'iterations': 1402, 'depth': 10, 'learning_rate': 0.023696338524289044, 'l2_leaf_reg': 0.10531716689455899, 'bagging_temperature': 1.9257828465458504}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 22:23:10,844] Trial 76 finished with value: 0.49642515182495117 and parameters: {'iterations': 1402, 'depth': 10, 'learning_rate': 0.023696338524289044, 'l2_leaf_reg': 0.10531716689455899, 'bagging_temperature': 1.9257828465458504}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 22:23:30,113] Trial 77 finished with value: 0.4978395104408264 and parameters: {'iterations': 1467, 'depth': 10, 'learning_rate': 0.031325483056202606, 'l2_leaf_reg': 0.05259445122963612, 'bagging_temperature': 1.8980948770531159}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 22:23:30,113] Trial 77 finished with value: 0.4978395104408264 and parameters: {'iterations': 1467, 'depth': 10, 'learning_rate': 0.031325483056202606, 'l2_leaf_reg': 0.05259445122963612, 'bagging_temperature': 1.8980948770531159}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 22:24:05,562] Trial 78 finished with value: 0.496408075094223 and parameters: {'iterations': 1609, 'depth': 10, 'learning_rate': 0.01418872344505642, 'l2_leaf_reg': 0.0314229390166703, 'bagging_temperature': 1.9585849525299917}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 22:24:05,562] Trial 78 finished with value: 0.496408075094223 and parameters: {'iterations': 1609, 'depth': 10, 'learning_rate': 0.01418872344505642, 'l2_leaf_reg': 0.0314229390166703, 'bagging_temperature': 1.9585849525299917}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 22:24:30,326] Trial 79 finished with value: 0.49833935499191284 and parameters: {'iterations': 1231, 'depth': 10, 'learning_rate': 0.018208920211625762, 'l2_leaf_reg': 0.010495003500185068, 'bagging_temperature': 1.9860035315156481}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 22:24:30,326] Trial 79 finished with value: 0.49833935499191284 and parameters: {'iterations': 1231, 'depth': 10, 'learning_rate': 0.018208920211625762, 'l2_leaf_reg': 0.010495003500185068, 'bagging_temperature': 1.9860035315156481}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 22:25:03,410] Trial 80 finished with value: 0.49731311202049255 and parameters: {'iterations': 1589, 'depth': 10, 'learning_rate': 0.014185262972055194, 'l2_leaf_reg': 0.021723330804643805, 'bagging_temperature': 1.7872865688240438}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 22:25:03,410] Trial 80 finished with value: 0.49731311202049255 and parameters: {'iterations': 1589, 'depth': 10, 'learning_rate': 0.014185262972055194, 'l2_leaf_reg': 0.021723330804643805, 'bagging_temperature': 1.7872865688240438}. Best is trial 71 with value: 0.4953094720840454.
# ...
# [I 2025-08-12 23:16:08,291] Trial 176 finished with value: 0.4969605505466461 and parameters: {'iterations': 1697, 'depth': 10, 'learning_rate': 0.017638055483851566, 'l2_leaf_reg': 0.09116041860093435, 'bagging_temperature': 1.7362448757562947}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 23:16:08,291] Trial 176 finished with value: 0.4969605505466461 and parameters: {'iterations': 1697, 'depth': 10, 'learning_rate': 0.017638055483851566, 'l2_leaf_reg': 0.09116041860093435, 'bagging_temperature': 1.7362448757562947}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 23:16:53,850] Trial 177 finished with value: 0.4968249201774597 and parameters: {'iterations': 1503, 'depth': 10, 'learning_rate': 0.011245474352421807, 'l2_leaf_reg': 0.5206065174297364, 'bagging_temperature': 1.6786060591032463}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 23:16:53,850] Trial 177 finished with value: 0.4968249201774597 and parameters: {'iterations': 1503, 'depth': 10, 'learning_rate': 0.011245474352421807, 'l2_leaf_reg': 0.5206065174297364, 'bagging_temperature': 1.6786060591032463}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 23:16:59,674] Trial 178 finished with value: 0.49963703751564026 and parameters: {'iterations': 1285, 'depth': 6, 'learning_rate': 0.02291192128748926, 'l2_leaf_reg': 0.7590738803341024, 'bagging_temperature': 1.6177602182508697}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 23:16:59,674] Trial 178 finished with value: 0.49963703751564026 and parameters: {'iterations': 1285, 'depth': 6, 'learning_rate': 0.02291192128748926, 'l2_leaf_reg': 0.7590738803341024, 'bagging_temperature': 1.6177602182508697}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 23:17:54,781] Trial 179 finished with value: 0.4977417290210724 and parameters: {'iterations': 1083, 'depth': 10, 'learning_rate': 0.007043481252807131, 'l2_leaf_reg': 0.9649981360788824, 'bagging_temperature': 1.7783610177416442}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 23:17:54,781] Trial 179 finished with value: 0.4977417290210724 and parameters: {'iterations': 1083, 'depth': 10, 'learning_rate': 0.007043481252807131, 'l2_leaf_reg': 0.9649981360788824, 'bagging_temperature': 1.7783610177416442}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 23:18:32,113] Trial 180 finished with value: 0.4965173900127411 and parameters: {'iterations': 1001, 'depth': 10, 'learning_rate': 0.013566015053281926, 'l2_leaf_reg': 0.013940772647137861, 'bagging_temperature': 1.9033354250261127}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 23:18:32,113] Trial 180 finished with value: 0.4965173900127411 and parameters: {'iterations': 1001, 'depth': 10, 'learning_rate': 0.013566015053281926, 'l2_leaf_reg': 0.013940772647137861, 'bagging_temperature': 1.9033354250261127}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 23:19:09,215] Trial 181 finished with value: 0.4961971044540405 and parameters: {'iterations': 1612, 'depth': 10, 'learning_rate': 0.014401889842034192, 'l2_leaf_reg': 0.028081837361411073, 'bagging_temperature': 1.962062268030988}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 23:19:09,215] Trial 181 finished with value: 0.4961971044540405 and parameters: {'iterations': 1612, 'depth': 10, 'learning_rate': 0.014401889842034192, 'l2_leaf_reg': 0.028081837361411073, 'bagging_temperature': 1.962062268030988}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 23:19:37,102] Trial 182 finished with value: 0.4986189007759094 and parameters: {'iterations': 1370, 'depth': 10, 'learning_rate': 0.014768158145424669, 'l2_leaf_reg': 0.03423481931967496, 'bagging_temperature': 1.9327420350261053}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 23:19:37,102] Trial 182 finished with value: 0.4986189007759094 and parameters: {'iterations': 1370, 'depth': 10, 'learning_rate': 0.014768158145424669, 'l2_leaf_reg': 0.03423481931967496, 'bagging_temperature': 1.9327420350261053}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 23:20:12,619] Trial 183 finished with value: 0.4974888861179352 and parameters: {'iterations': 1566, 'depth': 10, 'learning_rate': 0.012112041095355186, 'l2_leaf_reg': 0.025912294422425812, 'bagging_temperature': 1.989128488718834}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 23:20:12,619] Trial 183 finished with value: 0.4974888861179352 and parameters: {'iterations': 1566, 'depth': 10, 'learning_rate': 0.012112041095355186, 'l2_leaf_reg': 0.025912294422425812, 'bagging_temperature': 1.989128488718834}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 23:20:49,741] Trial 184 finished with value: 0.495597779750824 and parameters: {'iterations': 1517, 'depth': 10, 'learning_rate': 0.016217205646895057, 'l2_leaf_reg': 0.219054025194171, 'bagging_temperature': 1.857849174373015}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 23:20:49,741] Trial 184 finished with value: 0.495597779750824 and parameters: {'iterations': 1517, 'depth': 10, 'learning_rate': 0.016217205646895057, 'l2_leaf_reg': 0.219054025194171, 'bagging_temperature': 1.857849174373015}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 23:21:20,033] Trial 185 finished with value: 0.4963586926460266 and parameters: {'iterations': 1614, 'depth': 10, 'learning_rate': 0.01917935285538915, 'l2_leaf_reg': 0.22237263780686, 'bagging_temperature': 1.9629965436805672}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 23:21:20,033] Trial 185 finished with value: 0.4963586926460266 and parameters: {'iterations': 1614, 'depth': 10, 'learning_rate': 0.01917935285538915, 'l2_leaf_reg': 0.22237263780686, 'bagging_temperature': 1.9629965436805672}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 23:21:52,525] Trial 186 finished with value: 0.49664443731307983 and parameters: {'iterations': 1472, 'depth': 10, 'learning_rate': 0.016604554679154764, 'l2_leaf_reg': 0.1441267114978752, 'bagging_temperature': 1.8564172994896255}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 23:21:52,525] Trial 186 finished with value: 0.49664443731307983 and parameters: {'iterations': 1472, 'depth': 10, 'learning_rate': 0.016604554679154764, 'l2_leaf_reg': 0.1441267114978752, 'bagging_temperature': 1.8564172994896255}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 23:22:03,909] Trial 187 finished with value: 0.4983457326889038 and parameters: {'iterations': 1531, 'depth': 8, 'learning_rate': 0.021501600976235137, 'l2_leaf_reg': 0.17604834830423302, 'bagging_temperature': 1.9074788221674286}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 23:22:03,909] Trial 187 finished with value: 0.4983457326889038 and parameters: {'iterations': 1531, 'depth': 8, 'learning_rate': 0.021501600976235137, 'l2_leaf_reg': 0.17604834830423302, 'bagging_temperature': 1.9074788221674286}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 23:22:25,508] Trial 188 finished with value: 0.4983929693698883 and parameters: {'iterations': 1406, 'depth': 10, 'learning_rate': 0.026121906270396695, 'l2_leaf_reg': 0.0773748491263653, 'bagging_temperature': 1.9534526867413913}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 23:22:25,508] Trial 188 finished with value: 0.4983929693698883 and parameters: {'iterations': 1406, 'depth': 10, 'learning_rate': 0.026121906270396695, 'l2_leaf_reg': 0.0773748491263653, 'bagging_temperature': 1.9534526867413913}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 23:22:58,333] Trial 189 finished with value: 0.4969409704208374 and parameters: {'iterations': 1437, 'depth': 10, 'learning_rate': 0.016187693500638284, 'l2_leaf_reg': 0.23988495443989566, 'bagging_temperature': 1.8592365469729926}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 23:22:58,333] Trial 189 finished with value: 0.4969409704208374 and parameters: {'iterations': 1437, 'depth': 10, 'learning_rate': 0.016187693500638284, 'l2_leaf_reg': 0.23988495443989566, 'bagging_temperature': 1.8592365469729926}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 23:23:04,980] Trial 190 finished with value: 0.5004339218139648 and parameters: {'iterations': 1562, 'depth': 9, 'learning_rate': 0.12117086066311054, 'l2_leaf_reg': 0.021637737224096697, 'bagging_temperature': 1.5704501457237854}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 23:23:04,980] Trial 190 finished with value: 0.5004339218139648 and parameters: {'iterations': 1562, 'depth': 9, 'learning_rate': 0.12117086066311054, 'l2_leaf_reg': 0.021637737224096697, 'bagging_temperature': 1.5704501457237854}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 23:23:36,256] Trial 191 finished with value: 0.49599385261535645 and parameters: {'iterations': 1653, 'depth': 10, 'learning_rate': 0.019511867574376167, 'l2_leaf_reg': 0.24982076530415018, 'bagging_temperature': 1.955037213174601}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 23:23:36,256] Trial 191 finished with value: 0.49599385261535645 and parameters: {'iterations': 1653, 'depth': 10, 'learning_rate': 0.019511867574376167, 'l2_leaf_reg': 0.24982076530415018, 'bagging_temperature': 1.955037213174601}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 23:24:03,431] Trial 192 finished with value: 0.49773555994033813 and parameters: {'iterations': 1640, 'depth': 10, 'learning_rate': 0.019373028049333545, 'l2_leaf_reg': 0.2866953778500583, 'bagging_temperature': 1.9982673236485702}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 23:24:03,431] Trial 192 finished with value: 0.49773555994033813 and parameters: {'iterations': 1640, 'depth': 10, 'learning_rate': 0.019373028049333545, 'l2_leaf_reg': 0.2866953778500583, 'bagging_temperature': 1.9982673236485702}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 23:24:33,235] Trial 193 finished with value: 0.4969799816608429 and parameters: {'iterations': 1703, 'depth': 10, 'learning_rate': 0.01781682052345256, 'l2_leaf_reg': 0.21071704455778983, 'bagging_temperature': 1.0738668819018637}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 23:24:33,235] Trial 193 finished with value: 0.4969799816608429 and parameters: {'iterations': 1703, 'depth': 10, 'learning_rate': 0.01781682052345256, 'l2_leaf_reg': 0.21071704455778983, 'bagging_temperature': 1.0738668819018637}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 23:24:56,719] Trial 194 finished with value: 0.4978269040584564 and parameters: {'iterations': 1522, 'depth': 10, 'learning_rate': 0.022862621020492108, 'l2_leaf_reg': 0.16184908954285476, 'bagging_temperature': 1.9171041072802573}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 23:24:56,719] Trial 194 finished with value: 0.4978269040584564 and parameters: {'iterations': 1522, 'depth': 10, 'learning_rate': 0.022862621020492108, 'l2_leaf_reg': 0.16184908954285476, 'bagging_temperature': 1.9171041072802573}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 23:25:30,057] Trial 195 finished with value: 0.49810534715652466 and parameters: {'iterations': 1660, 'depth': 10, 'learning_rate': 0.014129378231583618, 'l2_leaf_reg': 0.3609473483527647, 'bagging_temperature': 1.8778834019852884}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 23:25:30,057] Trial 195 finished with value: 0.49810534715652466 and parameters: {'iterations': 1660, 'depth': 10, 'learning_rate': 0.014129378231583618, 'l2_leaf_reg': 0.3609473483527647, 'bagging_temperature': 1.8778834019852884}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 23:26:02,501] Trial 196 finished with value: 0.49715152382850647 and parameters: {'iterations': 1483, 'depth': 10, 'learning_rate': 0.016124707749551367, 'l2_leaf_reg': 0.2702115573001045, 'bagging_temperature': 1.9521990533725249}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 23:26:02,501] Trial 196 finished with value: 0.49715152382850647 and parameters: {'iterations': 1483, 'depth': 10, 'learning_rate': 0.016124707749551367, 'l2_leaf_reg': 0.2702115573001045, 'bagging_temperature': 1.9521990533725249}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 23:26:26,352] Trial 197 finished with value: 0.498147189617157 and parameters: {'iterations': 1788, 'depth': 10, 'learning_rate': 0.020668957354793425, 'l2_leaf_reg': 0.018094042442628813, 'bagging_temperature': 1.8020688916294123}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 23:26:26,352] Trial 197 finished with value: 0.498147189617157 and parameters: {'iterations': 1788, 'depth': 10, 'learning_rate': 0.020668957354793425, 'l2_leaf_reg': 0.018094042442628813, 'bagging_temperature': 1.8020688916294123}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 23:26:45,190] Trial 198 finished with value: 0.49933183193206787 and parameters: {'iterations': 1592, 'depth': 10, 'learning_rate': 0.02747576473973246, 'l2_leaf_reg': 0.01217851566579144, 'bagging_temperature': 1.8349368669348194}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 23:26:45,190] Trial 198 finished with value: 0.49933183193206787 and parameters: {'iterations': 1592, 'depth': 10, 'learning_rate': 0.02747576473973246, 'l2_leaf_reg': 0.01217851566579144, 'bagging_temperature': 1.8349368669348194}. Best is trial 71 with value: 0.4953094720840454.
# [I 2025-08-12 23:27:13,042] Trial 199 finished with value: 0.49704986810684204 and parameters: {'iterations': 1856, 'depth': 10, 'learning_rate': 0.018415927348479896, 'l2_leaf_reg': 0.01440491805268126, 'bagging_temperature': 1.518600603142143}. Best is trial 71 with value: 0.4953094720840454.
# SVD Best objective: 0.495309
# SVD Best params: {'iterations': 954, 'depth': 10, 'learning_rate': 0.018588163726181217, 'l2_leaf_reg': 0.2824688102167141, 'bagging_temperature': 1.7832724153348096}
# Training SVD on full dataset (including missing target values)...
#
# [svd] Training with 5 seeds...
#   Seed 1/5: 42
# [I 2025-08-12 23:27:13,042] Trial 199 finished with value: 0.49704986810684204 and parameters: {'iterations': 1856, 'depth': 10, 'learning_rate': 0.018415927348479896, 'l2_leaf_reg': 0.01440491805268126, 'bagging_temperature': 1.518600603142143}. Best is trial 71 with value: 0.4953094720840454.
# SVD Best objective: 0.495309
# SVD Best params: {'iterations': 954, 'depth': 10, 'learning_rate': 0.018588163726181217, 'l2_leaf_reg': 0.2824688102167141, 'bagging_temperature': 1.7832724153348096}
# Training SVD on full dataset (including missing target values)...
#
# [svd] Training with 5 seeds...
#   Seed 1/5: 42
#     ✅ Seed 42 completed on CPU
#   Seed 2/5: 1
#     ✅ Seed 42 completed on CPU
#   Seed 2/5: 1
#     ✅ Seed 1 completed on CPU
#   Seed 3/5: 26
#     ✅ Seed 1 completed on CPU
#   Seed 3/5: 26
#     ✅ Seed 26 completed on CPU
#   Seed 4/5: 5
#     ✅ Seed 26 completed on CPU
#   Seed 4/5: 5
#     ✅ Seed 5 completed on CPU
#   Seed 5/5: 2005
#     ✅ Seed 5 completed on CPU
#   Seed 5/5: 2005
#     ✅ Seed 2005 completed on CPU
#     Saved: svd_seed42_1755016989.csv
#     Saved: svd_seed1_1755016989.csv
#     Saved: svd_seed26_1755016989.csv
#     Saved: svd_seed5_1755016989.csv
#     Saved: svd_seed2005_1755016989.csv
#   Saved averaged: svd_averaged_1755016989.csv
#
# Both pipelines completed!
#     ✅ Seed 2005 completed on CPU
#     Saved: svd_seed42_1755016989.csv
#     Saved: svd_seed1_1755016989.csv
#     Saved: svd_seed26_1755016989.csv
#     Saved: svd_seed5_1755016989.csv
#     Saved: svd_seed2005_1755016989.csv
#   Saved averaged: svd_averaged_1755016989.csv
#
# Both pipelines completed!

# %%
# =========================
# 6) Ensemble Analysis and Creation
# =========================

print("\n" + "="*40)
print("ENSEMBLE ANALYSIS")
print("="*40)

# Calculate correlation between PCA and SVD predictions
pca_flat = results['pca']['predictions'].flatten()
svd_flat = results['svd']['predictions'].flatten()
correlation = np.corrcoef(pca_flat, svd_flat)[0, 1]

print(f"Correlation between PCA and SVD predictions: {correlation:.6f}")

# Simple ensemble (50-50 average)
ensemble_simple = (results['pca']['predictions'] + results['svd']['predictions']) / 2

# Weighted ensemble based on best scores (lower is better)
pca_score = results['pca']['best_score']
svd_score = results['svd']['best_score'] 

# Convert to weights (inverse of scores)
pca_weight = 1 / (pca_score + 1e-8)
svd_weight = 1 / (svd_score + 1e-8)
total_weight = pca_weight + svd_weight

pca_weight_norm = pca_weight / total_weight
svd_weight_norm = svd_weight / total_weight

ensemble_weighted = (pca_weight_norm * results['pca']['predictions'] + 
                    svd_weight_norm * results['svd']['predictions'])

print(f"Weighted ensemble - PCA weight: {pca_weight_norm:.3f}, SVD weight: {svd_weight_norm:.3f}")

# Anchor-based ensemble (if anchors available)
if ANCHORS and len(ANCHORS) > 0:
    print("\nCalculating anchor-based ensemble...")
    
    # Validate anchor dimensions
    expected_len = len(pca_flat)
    valid_anchors = [a for a in ANCHORS if len(a["vec"]) == expected_len]
    
    if valid_anchors:
        pca_lb, _ = predict_lb_from_anchors(pca_flat, valid_anchors, TEMP_SOFTMAX, TOPK_ANCHORS)
        svd_lb, _ = predict_lb_from_anchors(svd_flat, valid_anchors, TEMP_SOFTMAX, TOPK_ANCHORS)
        
        print(f"PCA predicted LB: {pca_lb:.6f}")
        print(f"SVD predicted LB: {svd_lb:.6f}")
        
        # Anchor-based weights (higher LB = lower weight since we want lower scores)
        anchor_pca_weight = 1 / (pca_lb + 1e-8)
        anchor_svd_weight = 1 / (svd_lb + 1e-8)
        anchor_total = anchor_pca_weight + anchor_svd_weight
        
        anchor_pca_norm = anchor_pca_weight / anchor_total
        anchor_svd_norm = anchor_svd_weight / anchor_total
        
        ensemble_anchor = (anchor_pca_norm * results['pca']['predictions'] + 
                          anchor_svd_norm * results['svd']['predictions'])
        
        print(f"Anchor ensemble - PCA weight: {anchor_pca_norm:.3f}, SVD weight: {anchor_svd_norm:.3f}")
    else:
        ensemble_anchor = ensemble_simple
        print("No valid anchors found, using simple ensemble")
else:
    ensemble_anchor = ensemble_simple
    print("No anchors available, using simple ensemble")
# Out:
# ========================================
# ENSEMBLE ANALYSIS
# ========================================
# Correlation between PCA and SVD predictions: 0.994248
# Weighted ensemble - PCA weight: 0.500, SVD weight: 0.500
#
# Calculating anchor-based ensemble...
# PCA predicted LB: 0.334075
# SVD predicted LB: 0.337420
# Anchor ensemble - PCA weight: 0.502, SVD weight: 0.498

# %%
# =========================
# 7) Save All Results
# =========================

ts = int(time.time())

print(f"\n" + "="*40)
print("SAVING RESULTS")
print("="*40)

# Save ensemble predictions
ensembles = {
    'simple': ensemble_simple,
    'weighted': ensemble_weighted, 
    'anchor': ensemble_anchor
}

for ensemble_name, predictions in ensembles.items():
    df = pd.DataFrame(predictions, columns=TARGET_COLS)
    df["ID"] = range(1, len(predictions) + 1)
    path = f"ensemble_{ensemble_name}_{ts}.csv"
    df.to_csv(path, index=False)
    print(f"Saved: {path}")

# Save results summary
summary = {
    'timestamp': ts,
    'correlation_pca_svd': float(correlation),
    'pca_explained_variance': float(results['pca']['explained_variance']),
    'svd_explained_variance': float(results['svd']['explained_variance']),
    'pca_best_score': float(results['pca']['best_score']),
    'svd_best_score': float(results['svd']['best_score']),
    'pca_best_params': results['pca']['best_params'],
    'svd_best_params': results['svd']['best_params'],
    'ensemble_weights': {
        'score_based': {'pca': float(pca_weight_norm), 'svd': float(svd_weight_norm)},
    },
    'optuna_trials': OPTUNA_TRIALS,
    'n_seeds': N_SEEDS,
    'n_components': N_COMPONENTS
}

summary_path = f"pipeline_summary_{ts}.json"
with open(summary_path, 'w') as f:
    json.dump(summary, f, indent=2)
print(f"Saved: {summary_path}")

# Print final summary
print(f"\n" + "="*60)
print("PIPELINE SUMMARY")
print("="*60)
print(f"PCA explained variance: {results['pca']['explained_variance']:.4f}")
print(f"SVD explained variance: {results['svd']['explained_variance']:.4f}")
print(f"PCA best score: {results['pca']['best_score']:.6f}")
print(f"SVD best score: {results['svd']['best_score']:.6f}")
print(f"Correlation: {correlation:.6f}")
print(f"Ensemble diversity: {'Good' if correlation < 0.995 else 'Limited'}")

if correlation < 0.995:
    print("\n✅ Low correlation detected - ensemble should be beneficial!")
    print("📊 Recommended: Use weighted or anchor-based ensemble")
else:
    print("\n⚠️ High correlation - ensemble may provide limited benefit")
    print("🎯 Recommended: Use the better performing individual model")

print(f"\n🎉 Pipeline completed! All results saved with timestamp {ts}")
# Out:
# ========================================
# SAVING RESULTS
# ========================================
# Saved: ensemble_simple_1755016989.csv
# Saved: ensemble_weighted_1755016989.csv
# Saved: ensemble_anchor_1755016989.csv
# Saved: pipeline_summary_1755016989.json
#
# ============================================================
# PIPELINE SUMMARY
# ============================================================
# PCA explained variance: 0.9116
# SVD explained variance: 0.9113
# PCA best score: 0.495457
# SVD best score: 0.495309
# Correlation: 0.994248
# Ensemble diversity: Good
#
# ✅ Low correlation detected - ensemble should be beneficial!
# 📊 Recommended: Use weighted or anchor-based ensemble
#
# 🎉 Pipeline completed! All results saved with timestamp 1755016989

# %%
d
